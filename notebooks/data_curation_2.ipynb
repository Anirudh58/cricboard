# %%
# Basic
from collections import Counter
import datetime
import math
import numpy as np
import os
import pprint
import sys

# yaml specific
import yaml

# Data handling
from fuzzywuzzy import fuzz, process
import pandas as pd
from tqdm import tqdm

# Appending root folder to path for easy importing
sys.path.append("../")

# my library
from src.db_utils import update_player, add_player

# %%
# Config variables
raw_data_path = os.path.join("..", "raw_data") 
clean_data_path = os.path.join("..", "clean_data") 

# ingest each tournament sequentially
tournament_name = "IPL"
#tournament_name = "BBL"

# %% [markdown]
# ### Utility functions.

# %%
def find_players_not_mapped(matches):
    """
    Utility function to quickly run through all deliveries of every match and see if there is any exception coming (if there is any player unmapped)
    Args:
        matches - a list of match objects parsed from the yaml files
    """
    players_not_found_or_mapped = []
    for match in tqdm(matches):
        try:
            for inning in match['innings']:
                for inning_number in inning:
                    for ball in inning[inning_number]['deliveries']:
                        for ball_number in ball:

                            batsman = player_id_map[ball[ball_number]['batsman']]
                            bowler = player_id_map[ball[ball_number]['bowler']]
                            non_striker = player_id_map[ball[ball_number]['non_striker']]

                            if "wicket" in ball[ball_number]:
                                player_dismissed = player_id_map[ball[ball_number]["wicket"]["player_out"]]
                                dismissal_type = ball[ball_number]["wicket"]["kind"]

                                if "fielders" in ball[ball_number]["wicket"]:
                                    # There is "(sub)" when a substitute fielder is involved in a wicket
                                    fielders = ",".join([str(player_id_map[fielder.replace(" (sub)", "")]) for fielder in ball[ball_number]["wicket"]["fielders"]])
        except Exception as e:
            print(f"Exception {e} happened in ball number {ball_number} ")
            print(f"ball {ball[ball_number]}")
            print(f"match info: {match['info']}")
            players_not_found_or_mapped.append(e.args[0])
            
    return players_not_found_or_mapped

# %%
def parse_yaml(path):
    """
    Parses a given yaml file and returns the object
    Args:
        path - path of the yaml file to be parsed
    """
    with open(path, 'r') as stream:
        try:
            data = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            print(exc)
    return data

# %%
def get_all_matches_raw_data(tournament_name):
    """
        Parses all the matches inside the tournament_name folder and returns a list of dicts
        Args:
            tournament_name - Name of tournament to be parsed
    """
    
    tournament_path = os.path.join(raw_data_path, tournament_name)
    match_files = os.listdir(tournament_path)
    matches = []
    print(f"Parsing {len(match_files)} matches for {tournament_name}")
    for match_file in tqdm(match_files):
        if ".yaml" not in match_file:
            continue
        match_path = os.path.join(tournament_path, match_file)
        match = parse_yaml(match_path)
        matches.append(match)
    return matches

# %%
def get_best_possible_name_match(query_name, players_with_same_surname):
    """
    This function does a fuzzy match to find where to insert query_name in the players database. It returns the best matched player_name. 
    eg: DA Warner needs to be mapped to David Warner  
    Args:
        query_name - query name to be checked with
        players_with_same_surname - a subset of the players dataframe for checking with the query_name
    """
    
    #print(f"Getting best match for {query_name}")
    
    # collecting all capital letters in the name to be stored as initials
    initials = [c for c in query_name if c.isupper()]
    
    # creating a hash map between the player_name and player_full_name for easy access
    name_full_name_map = {}
    for index, row in players_with_same_surname.iterrows():
        name_full_name_map[row["player_name"]] = row["player_full_name"]
    
    # List of all choices for the fuzzy algorithm to run on. 
    choices_name = np.array(players_with_same_surname.player_name)
    potential_matches = process.extract(query_name, choices_name, processor=None, limit=50)
    
    # IF no potential match was found, return null string
    if len(potential_matches) == 0:
        return ""
    
    #print(f"All matches: {potential_matches}")
    top_score = potential_matches[0][1]
    best_match = ""
    for potential_match in potential_matches:
        score = potential_match[1]
        match_name = potential_match[0]
    
        # if you get a perfect score, that should definitely be the correct match
        if score == 100:
            best_match = match_name
            break
        
        # if you dont get a perfect score, check if all the initials are present in the players full name, that should be the best match
        initial_bool = []
        #char_index = []
        for initial in initials:
            #print(f"Checking if {initial} is present in {name_full_name_map[match_name]}")
            if initial in name_full_name_map[match_name]:
                initial_bool.append(True)
                #char_index.append(name_full_name_map[match_name].index(initial))
            else:
                initial_bool.append(False)
            name_full_name_map[match_name] = name_full_name_map[match_name].replace(initial, '', 1)
        
        is_initials_index_increasing = True
        
        # This logic is unfortunately failing for players like "CV Varun" that needs to be mapped to "Varun Chakravarthy"
        '''
        for i in range(1, len(char_index)):
            if char_index[i] < char_index[i-1]:
                is_initials_index_increasing = False
        '''
        
        if all(initial_bool) and is_initials_index_increasing:
            best_match = match_name
            break
        
        # if either of methods fail, return the best match the fuzzy scoring algo returned
        if score > top_score:
            top_score = score
            best_match = match_name

    return best_match

# %% [markdown]
# # This notebook will be used to curate 3 tables.
# ## 1) Venue 2) Match 3) Ball

# %%
matches = get_all_matches_raw_data(tournament_name)
# Out:
#   0%|                                                                                          | 0/818 [00:00<?, ?it/s]
# Parsing 818 matches for IPL
# 100%|████████████████████████████████████████████████████████████████████████████████| 818/818 [03:54<00:00,  3.49it/s]

# %%
matches[0]['innings'][0]['1st innings']['deliveries'][0][0.1]
# Out:
# {'batsman': 'DA Warner',
#  'bowler': 'TS Mills',
#  'non_striker': 'S Dhawan',
#  'runs': {'batsman': 0, 'extras': 0, 'total': 0}}

# %% [markdown]
# #### We need to first match all player names found in this dataset to the player_ids we have. Our player table contains full names (eg: David Warner) while this dataset has only the short names typically used in score cards (eg. DA Warner). So using a combination of fuzzy and boolean matching to map these

# %%
players = pd.read_csv(os.path.join(clean_data_path, "player.csv"))

# %% [markdown]
# ### Creating a unique player names set with information from each ball of all the 817 IPL matches. Considering batsman bowler and non-striker

# %%
unique_player_names = set()
for match in tqdm(matches):
    for inning in match['innings']:
        for inning_number in inning:
            for ball in inning[inning_number]['deliveries']:
                for ball_number in ball:
                    unique_player_names.add(ball[ball_number]['batsman'])
                    unique_player_names.add(ball[ball_number]['bowler'])
                    unique_player_names.add(ball[ball_number]['non_striker'])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 816/816 [00:00<00:00, 3551.83it/s]

# %%
unique_player_names
# Out:
# {'A Ashish Reddy',
#  'A Chandila',
#  'A Chopra',
#  'A Choudhary',
#  'A Dananjaya',
#  'A Flintoff',
#  'A Kumble',
#  'A Mishra',
#  'A Mithun',
#  'A Mukund',
#  'A Nehra',
#  'A Nel',
#  'A Nortje',
#  'A Singh',
#  'A Symonds',
#  'A Uniyal',
#  'A Zampa',
#  'AA Bilakhia',
#  'AA Chavan',
#  'AA Jhunjhunwala',
#  'AA Kazi',
#  'AA Noffke',
#  'AB Agarkar',
#  'AB Barath',
#  'AB Dinda',
#  'AB McDonald',
#  'AB de Villiers',
#  'AC Blizzard',
#  'AC Gilchrist',
#  'AC Thomas',
#  'AC Voges',
#  'AD Hales',
#  'AD Mascarenhas',
#  'AD Mathews',
#  'AD Nath',
#  'AD Russell',
#  'AF Milne',
#  'AG Murtaza',
#  'AG Paunikar',
#  'AJ Finch',
#  'AJ Turner',
#  'AJ Tye',
#  'AL Menaria',
#  'AM Nayar',
#  'AM Rahane',
#  'AM Salvi',
#  'AN Ahmed',
#  'AN Ghosh',
#  'AP Dole',
#  'AP Majumdar',
#  'AP Tare',
#  'AR Bawne',
#  'AR Patel',
#  'AS Joseph',
#  'AS Rajpoot',
#  'AS Raut',
#  'AS Roy',
#  'AS Yadav',
#  'AT Carey',
#  'AT Rayudu',
#  'AUK Pathan',
#  'Abdul Samad',
#  'Abdur Razzak',
#  'Abhishek Sharma',
#  'Anand Rajan',
#  'Anirudh Singh',
#  'Ankit Sharma',
#  'Ankit Soni',
#  'Anureet Singh',
#  'Arshdeep Singh',
#  'Avesh Khan',
#  'Azhar Mahmood',
#  'B Akhil',
#  'B Chipli',
#  'B Geeves',
#  'B Kumar',
#  'B Laughlin',
#  'B Lee',
#  'B Stanlake',
#  'B Sumanth',
#  'BA Bhatt',
#  'BA Stokes',
#  'BAW Mendis',
#  'BB McCullum',
#  'BB Samantray',
#  'BB Sran',
#  'BCJ Cutting',
#  'BE Hendricks',
#  'BJ Haddin',
#  'BJ Hodge',
#  'BJ Rohrer',
#  'BMAJ Mendis',
#  'BR Dunk',
#  'BW Hilfenhaus',
#  'Basil Thampi',
#  'Bipul Sharma',
#  'C Ganapathy',
#  'C Madan',
#  'C Munro',
#  'C Nanda',
#  'C de Grandhomme',
#  'CA Ingram',
#  'CA Lynn',
#  'CA Pujara',
#  'CH Gayle',
#  'CH Morris',
#  'CJ Anderson',
#  'CJ Dala',
#  'CJ Ferguson',
#  'CJ Green',
#  'CJ Jordan',
#  'CJ McKay',
#  'CK Kapugedera',
#  'CK Langeveldt',
#  'CL White',
#  'CM Gautam',
#  'CR Brathwaite',
#  'CR Woakes',
#  'CRD Fernando',
#  'CV Varun',
#  'D Kalyankrishna',
#  'D Padikkal',
#  'D Salunkhe',
#  'D Wiese',
#  'D du Preez',
#  'DA Miller',
#  'DA Warner',
#  'DAJ Bracewell',
#  'DB Das',
#  'DB Ravi Teja',
#  'DE Bollinger',
#  'DH Yagnik',
#  'DJ Bravo',
#  'DJ Harris',
#  'DJ Hooda',
#  'DJ Hussey',
#  'DJ Jacobs',
#  'DJ Muthuswami',
#  'DJ Thornely',
#  'DJ Willey',
#  'DJG Sammy',
#  'DJM Short',
#  'DL Chahar',
#  'DL Vettori',
#  'DM Bravo',
#  'DNT Zoysa',
#  'DP Nannes',
#  'DP Vijaykumar',
#  'DPMD Jayawardene',
#  'DR Martyn',
#  'DR Sams',
#  'DR Shorey',
#  'DR Smith',
#  'DS Kulkarni',
#  'DS Lehmann',
#  'DT Christian',
#  'DT Patil',
#  'DW Steyn',
#  'E Lewis',
#  'EJG Morgan',
#  'ER Dwivedi',
#  'F Behardien',
#  'F du Plessis',
#  'FH Edwards',
#  'FY Fazal',
#  'G Gambhir',
#  'GB Hogg',
#  'GC Smith',
#  'GC Viljoen',
#  'GD McGrath',
#  'GH Vihari',
#  'GJ Bailey',
#  'GJ Maxwell',
#  'GR Napier',
#  'GS Sandhu',
#  'Gagandeep Singh',
#  'Gurkeerat Singh',
#  'H Das',
#  'H Klaasen',
#  'HF Gurney',
#  'HH Gibbs',
#  'HH Pandya',
#  'HM Amla',
#  'HV Patel',
#  'Harbhajan Singh',
#  'Harmeet Singh',
#  'Harmeet Singh (2)',
#  'Harpreet Brar',
#  'Harpreet Singh',
#  'I Malhotra',
#  'I Sharma',
#  'I Udana',
#  'IC Pandey',
#  'IK Pathan',
#  'IR Jaggi',
#  'IS Sodhi',
#  'Imran Tahir',
#  'Iqbal Abdulla',
#  'Ishan Kishan',
#  'J Arunkumar',
#  'J Botha',
#  'J Suchith',
#  'J Syed Mohammad',
#  'J Theron',
#  'J Yadav',
#  'JA Morkel',
#  'JC Archer',
#  'JC Buttler',
#  'JD Ryder',
#  'JD Unadkat',
#  'JDP Oram',
#  'JDS Neesham',
#  'JE Taylor',
#  'JEC Franklin',
#  'JH Kallis',
#  'JJ Bumrah',
#  'JJ Roy',
#  'JJ van der Wath',
#  'JL Denly',
#  'JL Pattinson',
#  'JM Bairstow',
#  'JM Kemp',
#  'JO Holder',
#  'JP Behrendorff',
#  'JP Duminy',
#  'JP Faulkner',
#  'JPR Scantlebury-Searles',
#  'JR Hazlewood',
#  'JR Hopes',
#  'JR Philippe',
#  'JW Hastings',
#  'Jaskaran Singh',
#  'Joginder Sharma',
#  'K Goel',
#  'K Gowtham',
#  'K Khejroliya',
#  'K Rabada',
#  'K Santokie',
#  'K Upadhyay',
#  'KA Pollard',
#  'KAJ Roach',
#  'KB Arun Karthik',
#  'KC Cariappa',
#  'KC Sangakkara',
#  'KD Karthik',
#  'KH Pandya',
#  'KJ Abbott',
#  'KK Ahmed',
#  'KK Cooper',
#  'KK Nair',
#  'KL Nagarkoti',
#  'KL Rahul',
#  'KM Asif',
#  'KM Jadhav',
#  'KMA Paul',
#  'KMDN Kulasekara',
#  'KP Appanna',
#  'KP Pietersen',
#  'KS Williamson',
#  'KV Sharma',
#  'KW Richardson',
#  'Kamran Akmal',
#  'Kamran Khan',
#  'Karanveer Singh',
#  'Kartik Tyagi',
#  'Kuldeep Yadav',
#  'L Ablish',
#  'L Balaji',
#  'L Ngidi',
#  'L Ronchi',
#  'LA Carseldine',
#  'LA Pomersbach',
#  'LE Plunkett',
#  'LH Ferguson',
#  'LJ Wright',
#  'LMP Simmons',
#  'LPC Silva',
#  'LR Shukla',
#  'LRPL Taylor',
#  'LS Livingstone',
#  'M Ashwin',
#  'M Kaif',
#  'M Kartik',
#  'M Klinger',
#  'M Manhas',
#  'M Markande',
#  'M Morkel',
#  'M Muralitharan',
#  'M Ntini',
#  'M Prasidh Krishna',
#  'M Rawat',
#  'M Vijay',
#  'M Vohra',
#  'M de Lange',
#  'MA Agarwal',
#  'MA Khote',
#  'MA Starc',
#  'MA Wood',
#  'MB Parmar',
#  'MC Henriques',
#  'MC Juneja',
#  'MD Mishra',
#  'MDKJ Perera',
#  'MEK Hussey',
#  'MF Maharoof',
#  'MG Johnson',
#  'MG Neser',
#  'MJ Clarke',
#  'MJ Guptill',
#  'MJ Henry',
#  'MJ Lumb',
#  'MJ McClenaghan',
#  'MJ Santner',
#  'MK Lomror',
#  'MK Pandey',
#  'MK Tiwary',
#  'ML Hayden',
#  'MM Ali',
#  'MM Patel',
#  'MM Sharma',
#  'MN Samuels',
#  'MN van Wyk',
#  'MP Stoinis',
#  'MR Marsh',
#  'MS Bisla',
#  'MS Dhoni',
#  'MS Gony',
#  'MS Wade',
#  'MV Boucher',
#  'Mandeep Singh',
#  'Mashrafe Mortaza',
#  'Misbah-ul-Haq',
#  'Mohammad Ashraful',
#  'Mohammad Asif',
#  'Mohammad Hafeez',
#  'Mohammad Nabi',
#  'Mohammed Shami',
#  'Mohammed Siraj',
#  'Monu Kumar',
#  'Mujeeb Ur Rahman',
#  'Mustafizur Rahman',
#  'N Jagadeesan',
#  'N Pooran',
#  'N Rana',
#  'N Saini',
#  'NA Saini',
#  'NB Singh',
#  'ND Doshi',
#  'NJ Maddinson',
#  'NJ Rimmington',
#  'NL McCullum',
#  'NLTC Perera',
#  'NM Coulter-Nile',
#  'NS Naik',
#  'NV Ojha',
#  'Niraj Patel',
#  'O Thomas',
#  'OA Shah',
#  'P Amarnath',
#  'P Awana',
#  'P Chopra',
#  'P Dogra',
#  'P Dubey',
#  'P Kumar',
#  'P Negi',
#  'P Parameswaran',
#  'P Prasanth',
#  'P Ray Barman',
#  'P Sahu',
#  'P Simran Singh',
#  'P Suyal',
#  'PA Patel',
#  'PA Reddy',
#  'PC Valthaty',
#  'PD Collingwood',
#  'PJ Cummins',
#  'PJ Sangwan',
#  'PK Garg',
#  'PM Sarvesh Kumar',
#  'PP Chawla',
#  'PP Ojha',
#  'PP Shaw',
#  'PR Shah',
#  'PSP Handscomb',
#  'PV Tambe',
#  'Pankaj Singh',
#  'Parvez Rasool',
#  'Q de Kock',
#  'R Ashwin',
#  'R Bhatia',
#  'R Bishnoi',
#  'R Dhawan',
#  'R Dravid',
#  'R McLaren',
#  'R Ninan',
#  'R Parag',
#  'R Rampaul',
#  'R Sathish',
#  'R Sharma',
#  'R Shukla',
#  'R Tewatia',
#  'R Vinay Kumar',
#  'RA Jadeja',
#  'RA Shaikh',
#  'RA Tripathi',
#  'RD Chahar',
#  'RD Gaikwad',
#  'RE Levi',
#  'RE van der Merwe',
#  'RG More',
#  'RG Sharma',
#  'RJ Harris',
#  'RJ Peterson',
#  'RJ Quiney',
#  'RK Bhui',
#  'RK Singh',
#  'RN ten Doeschate',
#  'RP Singh',
#  'RR Bhatkal',
#  'RR Bose',
#  'RR Pant',
#  'RR Powar',
#  'RR Raje',
#  'RR Rossouw',
#  'RR Sarwan',
#  'RS Bopara',
#  'RS Gavaskar',
#  'RS Sodhi',
#  'RT Ponting',
#  'RV Gomez',
#  'RV Uthappa',
#  'RW Price',
#  'Rashid Khan',
#  'Rasikh Salam',
#  'Ravi Bishnoi',
#  'S Anirudha',
#  'S Aravind',
#  'S Badree',
#  'S Badrinath',
#  'S Chanderpaul',
#  'S Dhawan',
#  'S Dube',
#  'S Gopal',
#  'S Kaul',
#  'S Kaushik',
#  'S Ladda',
#  'S Lamichhane',
#  'S Midhun',
#  'S Nadeem',
#  'S Narwal',
#  'S Rana',
#  'S Randiv',
#  'S Sandeep Warrier',
#  'S Sohal',
#  'S Sreesanth',
#  'S Sriram',
#  'S Tyagi',
#  'S Vidyut',
#  'SA Abbott',
#  'SA Asnodkar',
#  'SA Yadav',
#  'SB Bangar',
#  'SB Jakati',
#  'SB Joshi',
#  'SB Styris',
#  'SB Wagh',
#  'SC Ganguly',
#  'SC Kuggeleijn',
#  'SD Chitnis',
#  'SD Lad',
#  'SE Bond',
#  'SE Marsh',
#  'SE Rutherford',
#  'SJ Srivastava',
#  'SK Raina',
#  'SK Trivedi',
#  'SK Warne',
#  'SL Malinga',
#  'SM Boland',
#  'SM Curran',
#  'SM Harwood',
#  'SM Katich',
#  'SM Pollock',
#  'SMSM Senanayake',
#  'SN Khan',
#  'SN Thakur',
#  'SO Hetmyer',
#  'SP Fleming',
#  'SP Goswami',
#  'SP Jackson',
#  'SP Narine',
#  'SPD Smith',
#  'SR Tendulkar',
#  'SR Watson',
#  'SS Agarwal',
#  'SS Cottrell',
#  'SS Iyer',
#  'SS Mundhe',
#  'SS Sarkar',
#  'SS Shaikh',
#  'SS Tiwary',
#  'ST Jayasuriya',
#  'STR Binny',
#  'SV Samson',
#  'SW Billings',
#  'SW Tait',
#  'Sachin Baby',
#  'Salman Butt',
#  'Sandeep Sharma',
#  'Shahbaz Ahmed',
#  'Shahid Afridi',
#  'Shakib Al Hasan',
#  'Shivam Mavi',
#  'Shivam Sharma',
#  'Shoaib Ahmed',
#  'Shoaib Akhtar',
#  'Shoaib Malik',
#  'Shubman Gill',
#  'Sohail Tanvir',
#  'Sunny Gupta',
#  'Sunny Singh',
#  'Swapnil Singh',
#  'T Banton',
#  'T Henderson',
#  'T Kohli',
#  'T Natarajan',
#  'T Shamsi',
#  'T Taibu',
#  'T Thushara',
#  'TA Boult',
#  'TD Paine',
#  'TG Southee',
#  'TK Curran',
#  'TL Suman',
#  'TM Dilshan',
#  'TM Head',
#  'TM Srivastava',
#  'TP Sudhindra',
#  'TR Birt',
#  'TS Mills',
#  'TU Deshpande',
#  'Tejas Baroka',
#  'U Kaul',
#  'UA Birla',
#  'UBT Chand',
#  'UT Khawaja',
#  'UT Yadav',
#  'Umar Gul',
#  'V Kohli',
#  'V Pratap Singh',
#  'V Sehwag',
#  'V Shankar',
#  'VH Zol',
#  'VR Aaron',
#  'VRV Singh',
#  'VS Malik',
#  'VS Yeligati',
#  'VVS Laxman',
#  'VY Mahesh',
#  'Vishnu Vinod',
#  'W Jaffer',
#  'WA Mota',
#  'WD Parnell',
#  'WP Saha',
#  'WPUJC Vaas',
#  'Washington Sundar',
#  'X Thalaivan Sargunam',
#  'Y Gnaneswara Rao',
#  'Y Nagar',
#  'Y Prithvi Raj',
#  'Y Venugopal Rao',
#  'YA Abdulla',
#  'YBK Jaiswal',
#  'YK Pathan',
#  'YS Chahal',
#  'YV Takawale',
#  'Yashpal Singh',
#  'Younis Khan',
#  'Yuvraj Singh',
#  'Z Khan'}

# %% [markdown]
# ### for each one of these unique players, we are trying to find a best match map from the players sheet and updating the player_display_name

# %%
for player_name in tqdm(unique_player_names):
    players_with_same_surname = players[players.player_name.str.contains(player_name.split(" ")[-1])]
    best_match_name = get_best_possible_name_match(player_name, players_with_same_surname)
    # if null string was returned, skip the player
    if best_match_name:
        update_player("player_display_name", player_name, "player_name", best_match_name)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 580/580 [00:37<00:00, 15.55it/s]

# %% [markdown]
# ### Beyond this if we find any inaccuracies in the mapping, lets just manually correct them

# %% [markdown]
# ## Venue table

# %%
unique_venues = set()
all_venues = []
for match in tqdm(matches):
    unique_venues.add(match['info']['venue'])
    all_venues.append(match['info']['venue'])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 816/816 [00:00<00:00, 274815.49it/s]

# %% [markdown]
# ### Trying to find if there are duplicate names for the same stadium

# %%
unique_venues_list = list(unique_venues)
similarity_scores = []
for i in range(len(unique_venues_list)-1):
    for j in range(i+1, len(unique_venues_list)):
        similarity_score = fuzz.WRatio(unique_venues_list[i], unique_venues_list[j])
        similarity_scores.append([i, j, similarity_score])

similarity_scores_sorted = sorted(similarity_scores, key=lambda x : x[2], reverse=True)
counter = 0
for pair in similarity_scores_sorted:
    print(f"{unique_venues_list[pair[0]]} - {unique_venues_list[pair[1]]} --> {pair[2]}")
    if counter > 20:
        break
print(Counter(all_venues))
# Out:
# M Chinnaswamy Stadium - M.Chinnaswamy Stadium --> 100
# Punjab Cricket Association Stadium, Mohali - Punjab Cricket Association IS Bindra Stadium, Mohali --> 95
# Saurashtra Cricket Association Stadium - Maharashtra Cricket Association Stadium --> 94
# Himachal Pradesh Cricket Association Stadium - Maharashtra Cricket Association Stadium --> 87
# M Chinnaswamy Stadium - Punjab Cricket Association Stadium, Mohali --> 86
# M Chinnaswamy Stadium - Saurashtra Cricket Association Stadium --> 86
# M Chinnaswamy Stadium - Vidarbha Cricket Association Stadium, Jamtha --> 86
# M Chinnaswamy Stadium - Shaheed Veer Narayan Singh International Stadium --> 86
# M Chinnaswamy Stadium - Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium --> 86
# M Chinnaswamy Stadium - Himachal Pradesh Cricket Association Stadium --> 86
# M Chinnaswamy Stadium - Nehru Stadium --> 86
# M Chinnaswamy Stadium - Rajiv Gandhi International Stadium, Uppal --> 86
# M Chinnaswamy Stadium - Dubai International Cricket Stadium --> 86
# M Chinnaswamy Stadium - JSCA International Stadium Complex --> 86
# M Chinnaswamy Stadium - Maharashtra Cricket Association Stadium --> 86
# M Chinnaswamy Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# Punjab Cricket Association Stadium, Mohali - Holkar Cricket Stadium --> 86
# Punjab Cricket Association Stadium, Mohali - Sharjah Cricket Stadium --> 86
# Punjab Cricket Association Stadium, Mohali - Nehru Stadium --> 86
# Punjab Cricket Association Stadium, Mohali - Sawai Mansingh Stadium --> 86
# Punjab Cricket Association Stadium, Mohali - Brabourne Stadium --> 86
# Punjab Cricket Association Stadium, Mohali - Sardar Patel Stadium, Motera --> 86
# Punjab Cricket Association Stadium, Mohali - Sheikh Zayed Stadium --> 86
# Punjab Cricket Association Stadium, Mohali - M.Chinnaswamy Stadium --> 86
# Punjab Cricket Association Stadium, Mohali - Subrata Roy Sahara Stadium --> 86
# Punjab Cricket Association Stadium, Mohali - Wankhede Stadium --> 86
# Punjab Cricket Association Stadium, Mohali - Barabati Stadium --> 86
# Punjab Cricket Association Stadium, Mohali - New Wanderers Stadium --> 86
# Saurashtra Cricket Association Stadium - Holkar Cricket Stadium --> 86
# Saurashtra Cricket Association Stadium - Sharjah Cricket Stadium --> 86
# Saurashtra Cricket Association Stadium - Nehru Stadium --> 86
# Saurashtra Cricket Association Stadium - Sawai Mansingh Stadium --> 86
# Saurashtra Cricket Association Stadium - Brabourne Stadium --> 86
# Saurashtra Cricket Association Stadium - Sheikh Zayed Stadium --> 86
# Saurashtra Cricket Association Stadium - M.Chinnaswamy Stadium --> 86
# Saurashtra Cricket Association Stadium - Wankhede Stadium --> 86
# Saurashtra Cricket Association Stadium - Barabati Stadium --> 86
# Saurashtra Cricket Association Stadium - New Wanderers Stadium --> 86
# Vidarbha Cricket Association Stadium, Jamtha - Holkar Cricket Stadium --> 86
# Vidarbha Cricket Association Stadium, Jamtha - Sharjah Cricket Stadium --> 86
# Vidarbha Cricket Association Stadium, Jamtha - Nehru Stadium --> 86
# Vidarbha Cricket Association Stadium, Jamtha - Sawai Mansingh Stadium --> 86
# Vidarbha Cricket Association Stadium, Jamtha - Brabourne Stadium --> 86
# Vidarbha Cricket Association Stadium, Jamtha - Sardar Patel Stadium, Motera --> 86
# Vidarbha Cricket Association Stadium, Jamtha - Sheikh Zayed Stadium --> 86
# Vidarbha Cricket Association Stadium, Jamtha - M.Chinnaswamy Stadium --> 86
# Vidarbha Cricket Association Stadium, Jamtha - Subrata Roy Sahara Stadium --> 86
# Vidarbha Cricket Association Stadium, Jamtha - Wankhede Stadium --> 86
# Vidarbha Cricket Association Stadium, Jamtha - Barabati Stadium --> 86
# Vidarbha Cricket Association Stadium, Jamtha - New Wanderers Stadium --> 86
# Holkar Cricket Stadium - Shaheed Veer Narayan Singh International Stadium --> 86
# Holkar Cricket Stadium - Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium --> 86
# Holkar Cricket Stadium - Himachal Pradesh Cricket Association Stadium --> 86
# Holkar Cricket Stadium - Nehru Stadium --> 86
# Holkar Cricket Stadium - Rajiv Gandhi International Stadium, Uppal --> 86
# Holkar Cricket Stadium - Dubai International Cricket Stadium --> 86
# Holkar Cricket Stadium - JSCA International Stadium Complex --> 86
# Holkar Cricket Stadium - Maharashtra Cricket Association Stadium --> 86
# Holkar Cricket Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# Shaheed Veer Narayan Singh International Stadium - Sharjah Cricket Stadium --> 86
# Shaheed Veer Narayan Singh International Stadium - Nehru Stadium --> 86
# Shaheed Veer Narayan Singh International Stadium - Sawai Mansingh Stadium --> 86
# Shaheed Veer Narayan Singh International Stadium - Brabourne Stadium --> 86
# Shaheed Veer Narayan Singh International Stadium - Sardar Patel Stadium, Motera --> 86
# Shaheed Veer Narayan Singh International Stadium - MA Chidambaram Stadium, Chepauk --> 86
# Shaheed Veer Narayan Singh International Stadium - Sheikh Zayed Stadium --> 86
# Shaheed Veer Narayan Singh International Stadium - M.Chinnaswamy Stadium --> 86
# Shaheed Veer Narayan Singh International Stadium - Subrata Roy Sahara Stadium --> 86
# Shaheed Veer Narayan Singh International Stadium - Wankhede Stadium --> 86
# Shaheed Veer Narayan Singh International Stadium - Barabati Stadium --> 86
# Shaheed Veer Narayan Singh International Stadium - New Wanderers Stadium --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Sharjah Cricket Stadium --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Dr DY Patil Sports Academy --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Nehru Stadium --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Sawai Mansingh Stadium --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Brabourne Stadium --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Sardar Patel Stadium, Motera --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - MA Chidambaram Stadium, Chepauk --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Sheikh Zayed Stadium --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - M.Chinnaswamy Stadium --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - JSCA International Stadium Complex --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Subrata Roy Sahara Stadium --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Wankhede Stadium --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - St George's Park --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Barabati Stadium --> 86
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - New Wanderers Stadium --> 86
# Himachal Pradesh Cricket Association Stadium - Sharjah Cricket Stadium --> 86
# Himachal Pradesh Cricket Association Stadium - Nehru Stadium --> 86
# Himachal Pradesh Cricket Association Stadium - Sawai Mansingh Stadium --> 86
# Himachal Pradesh Cricket Association Stadium - Brabourne Stadium --> 86
# Himachal Pradesh Cricket Association Stadium - Sardar Patel Stadium, Motera --> 86
# Himachal Pradesh Cricket Association Stadium - Sheikh Zayed Stadium --> 86
# Himachal Pradesh Cricket Association Stadium - M.Chinnaswamy Stadium --> 86
# Himachal Pradesh Cricket Association Stadium - Subrata Roy Sahara Stadium --> 86
# Himachal Pradesh Cricket Association Stadium - Wankhede Stadium --> 86
# Himachal Pradesh Cricket Association Stadium - Barabati Stadium --> 86
# Himachal Pradesh Cricket Association Stadium - New Wanderers Stadium --> 86
# Sharjah Cricket Stadium - Nehru Stadium --> 86
# Sharjah Cricket Stadium - Rajiv Gandhi International Stadium, Uppal --> 86
# Sharjah Cricket Stadium - Dubai International Cricket Stadium --> 86
# Sharjah Cricket Stadium - Maharashtra Cricket Association Stadium --> 86
# Sharjah Cricket Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# Nehru Stadium - Rajiv Gandhi International Stadium, Uppal --> 86
# Nehru Stadium - Sawai Mansingh Stadium --> 86
# Nehru Stadium - Sardar Patel Stadium, Motera --> 86
# Nehru Stadium - MA Chidambaram Stadium, Chepauk --> 86
# Nehru Stadium - Sheikh Zayed Stadium --> 86
# Nehru Stadium - M.Chinnaswamy Stadium --> 86
# Nehru Stadium - Dubai International Cricket Stadium --> 86
# Nehru Stadium - JSCA International Stadium Complex --> 86
# Nehru Stadium - Maharashtra Cricket Association Stadium --> 86
# Nehru Stadium - Subrata Roy Sahara Stadium --> 86
# Nehru Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# Nehru Stadium - New Wanderers Stadium --> 86
# Rajiv Gandhi International Stadium, Uppal - Sawai Mansingh Stadium --> 86
# Rajiv Gandhi International Stadium, Uppal - Brabourne Stadium --> 86
# Rajiv Gandhi International Stadium, Uppal - Sheikh Zayed Stadium --> 86
# Rajiv Gandhi International Stadium, Uppal - M.Chinnaswamy Stadium --> 86
# Rajiv Gandhi International Stadium, Uppal - Subrata Roy Sahara Stadium --> 86
# Rajiv Gandhi International Stadium, Uppal - Wankhede Stadium --> 86
# Rajiv Gandhi International Stadium, Uppal - Barabati Stadium --> 86
# Rajiv Gandhi International Stadium, Uppal - New Wanderers Stadium --> 86
# Sawai Mansingh Stadium - Dubai International Cricket Stadium --> 86
# Sawai Mansingh Stadium - JSCA International Stadium Complex --> 86
# Sawai Mansingh Stadium - Maharashtra Cricket Association Stadium --> 86
# Sawai Mansingh Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# Brabourne Stadium - Sardar Patel Stadium, Motera --> 86
# Brabourne Stadium - MA Chidambaram Stadium, Chepauk --> 86
# Brabourne Stadium - Dubai International Cricket Stadium --> 86
# Brabourne Stadium - JSCA International Stadium Complex --> 86
# Brabourne Stadium - Maharashtra Cricket Association Stadium --> 86
# Brabourne Stadium - Subrata Roy Sahara Stadium --> 86
# Brabourne Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# SuperSport Park - Green Park --> 86
# Sardar Patel Stadium, Motera - Wankhede Stadium --> 86
# Sardar Patel Stadium, Motera - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# Sardar Patel Stadium, Motera - Barabati Stadium --> 86
# MA Chidambaram Stadium, Chepauk - Sheikh Zayed Stadium --> 86
# MA Chidambaram Stadium, Chepauk - Wankhede Stadium --> 86
# MA Chidambaram Stadium, Chepauk - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# MA Chidambaram Stadium, Chepauk - Barabati Stadium --> 86
# Sheikh Zayed Stadium - Dubai International Cricket Stadium --> 86
# Sheikh Zayed Stadium - JSCA International Stadium Complex --> 86
# Sheikh Zayed Stadium - Maharashtra Cricket Association Stadium --> 86
# Sheikh Zayed Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# Green Park - St George's Park --> 86
# M.Chinnaswamy Stadium - Dubai International Cricket Stadium --> 86
# M.Chinnaswamy Stadium - JSCA International Stadium Complex --> 86
# M.Chinnaswamy Stadium - Maharashtra Cricket Association Stadium --> 86
# M.Chinnaswamy Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# Dubai International Cricket Stadium - Wankhede Stadium --> 86
# Dubai International Cricket Stadium - Barabati Stadium --> 86
# Dubai International Cricket Stadium - New Wanderers Stadium --> 86
# JSCA International Stadium Complex - Wankhede Stadium --> 86
# JSCA International Stadium Complex - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# JSCA International Stadium Complex - Barabati Stadium --> 86
# JSCA International Stadium Complex - New Wanderers Stadium --> 86
# Maharashtra Cricket Association Stadium - Subrata Roy Sahara Stadium --> 86
# Maharashtra Cricket Association Stadium - Wankhede Stadium --> 86
# Maharashtra Cricket Association Stadium - Barabati Stadium --> 86
# Maharashtra Cricket Association Stadium - New Wanderers Stadium --> 86
# Subrata Roy Sahara Stadium - Wankhede Stadium --> 86
# Subrata Roy Sahara Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# Subrata Roy Sahara Stadium - Barabati Stadium --> 86
# Wankhede Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 86
# Punjab Cricket Association IS Bindra Stadium, Mohali - Barabati Stadium --> 86
# Punjab Cricket Association IS Bindra Stadium, Mohali - New Wanderers Stadium --> 86
# Holkar Cricket Stadium - Sharjah Cricket Stadium --> 84
# Punjab Cricket Association Stadium, Mohali - Vidarbha Cricket Association Stadium, Jamtha --> 81
# Saurashtra Cricket Association Stadium - Himachal Pradesh Cricket Association Stadium --> 80
# Punjab Cricket Association Stadium, Mohali - Saurashtra Cricket Association Stadium --> 79
# Saurashtra Cricket Association Stadium - Vidarbha Cricket Association Stadium, Jamtha --> 79
# Saurashtra Cricket Association Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 79
# Vidarbha Cricket Association Stadium, Jamtha - Maharashtra Cricket Association Stadium --> 79
# Punjab Cricket Association Stadium, Mohali - Himachal Pradesh Cricket Association Stadium --> 78
# Punjab Cricket Association Stadium, Mohali - Maharashtra Cricket Association Stadium --> 78
# Maharashtra Cricket Association Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 78
# Vidarbha Cricket Association Stadium, Jamtha - Himachal Pradesh Cricket Association Stadium --> 74
# Vidarbha Cricket Association Stadium, Jamtha - Punjab Cricket Association IS Bindra Stadium, Mohali --> 73
# Brabourne Stadium - Barabati Stadium --> 73
# Shaheed Veer Narayan Singh International Stadium - JSCA International Stadium Complex --> 72
# Himachal Pradesh Cricket Association Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 72
# Rajiv Gandhi International Stadium, Uppal - JSCA International Stadium Complex --> 72
# Dubai International Cricket Stadium - JSCA International Stadium Complex --> 72
# Shaheed Veer Narayan Singh International Stadium - Dubai International Cricket Stadium --> 71
# Rajiv Gandhi International Stadium, Uppal - Dubai International Cricket Stadium --> 71
# Wankhede Stadium - New Wanderers Stadium --> 70
# Nehru Stadium - Wankhede Stadium --> 69
# Newlands - New Wanderers Stadium --> 68
# Nehru Stadium - Brabourne Stadium --> 67
# Brabourne Stadium - Wankhede Stadium --> 67
# Sheikh Zayed Stadium - Wankhede Stadium --> 67
# Shaheed Veer Narayan Singh International Stadium - Rajiv Gandhi International Stadium, Uppal --> 66
# Nehru Stadium - Barabati Stadium --> 66
# Punjab Cricket Association Stadium, Mohali - Dubai International Cricket Stadium --> 63
# Saurashtra Cricket Association Stadium - Dubai International Cricket Stadium --> 63
# Sawai Mansingh Stadium - Wankhede Stadium --> 63
# Sawai Mansingh Stadium - Barabati Stadium --> 63
# M Chinnaswamy Stadium - MA Chidambaram Stadium, Chepauk --> 62
# Sharjah Cricket Stadium - Barabati Stadium --> 62
# MA Chidambaram Stadium, Chepauk - M.Chinnaswamy Stadium --> 62
# Dubai International Cricket Stadium - Maharashtra Cricket Association Stadium --> 62
# Himachal Pradesh Cricket Association Stadium - Dubai International Cricket Stadium --> 60
# Sharjah Cricket Stadium - Brabourne Stadium --> 60
# Sharjah Cricket Stadium - Sheikh Zayed Stadium --> 60
# Kingsmead - Sawai Mansingh Stadium --> 60
# Sawai Mansingh Stadium - New Wanderers Stadium --> 60
# Dubai International Cricket Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 60
# M Chinnaswamy Stadium - Sheikh Zayed Stadium --> 59
# Saurashtra Cricket Association Stadium - Subrata Roy Sahara Stadium --> 59
# Vidarbha Cricket Association Stadium, Jamtha - Dubai International Cricket Stadium --> 59
# Sawai Mansingh Stadium - Sheikh Zayed Stadium --> 59
# Sheikh Zayed Stadium - M.Chinnaswamy Stadium --> 59
# Sheikh Zayed Stadium - New Wanderers Stadium --> 59
# M Chinnaswamy Stadium - Wankhede Stadium --> 58
# M Chinnaswamy Stadium - Barabati Stadium --> 58
# Vidarbha Cricket Association Stadium, Jamtha - Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium --> 58
# Holkar Cricket Stadium - Wankhede Stadium --> 58
# Holkar Cricket Stadium - Barabati Stadium --> 58
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Maharashtra Cricket Association Stadium --> 58
# Sharjah Cricket Stadium - Sawai Mansingh Stadium --> 58
# Sharjah Cricket Stadium - Subrata Roy Sahara Stadium --> 58
# Sharjah Cricket Stadium - Wankhede Stadium --> 58
# Sawai Mansingh Stadium - Subrata Roy Sahara Stadium --> 58
# Brabourne Stadium - New Wanderers Stadium --> 58
# SuperSport Park - St George's Park --> 58
# Sardar Patel Stadium, Motera - MA Chidambaram Stadium, Chepauk --> 58
# Sheikh Zayed Stadium - Barabati Stadium --> 58
# M.Chinnaswamy Stadium - Wankhede Stadium --> 58
# M.Chinnaswamy Stadium - Barabati Stadium --> 58
# Wankhede Stadium - Barabati Stadium --> 58
# Barabati Stadium - New Wanderers Stadium --> 58
# M Chinnaswamy Stadium - Sawai Mansingh Stadium --> 57
# Saurashtra Cricket Association Stadium - Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium --> 57
# Holkar Cricket Stadium - Sheikh Zayed Stadium --> 57
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Dubai International Cricket Stadium --> 57
# Sharjah Cricket Stadium - Sardar Patel Stadium, Motera --> 57
# Sawai Mansingh Stadium - M.Chinnaswamy Stadium --> 57
# Holkar Cricket Stadium - Brabourne Stadium --> 56
# Sardar Patel Stadium, Motera - JSCA International Stadium Complex --> 56
# M Chinnaswamy Stadium - Brabourne Stadium --> 55
# Punjab Cricket Association Stadium, Mohali - JSCA International Stadium Complex --> 55
# Eden Gardens - Green Park --> 55
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Himachal Pradesh Cricket Association Stadium --> 55
# Sawai Mansingh Stadium - Brabourne Stadium --> 55
# Brabourne Stadium - Sheikh Zayed Stadium --> 55
# Brabourne Stadium - M.Chinnaswamy Stadium --> 55
# Sardar Patel Stadium, Motera - New Wanderers Stadium --> 55
# Sharjah Cricket Stadium - MA Chidambaram Stadium, Chepauk --> 54
# Sawai Mansingh Stadium - Sardar Patel Stadium, Motera --> 54
# Sardar Patel Stadium, Motera - Subrata Roy Sahara Stadium --> 54
# Green Park - Buffalo Park --> 54
# Punjab Cricket Association Stadium, Mohali - Rajiv Gandhi International Stadium, Uppal --> 53
# Saurashtra Cricket Association Stadium - Shaheed Veer Narayan Singh International Stadium --> 53
# Holkar Cricket Stadium - New Wanderers Stadium --> 53
# Shaheed Veer Narayan Singh International Stadium - Maharashtra Cricket Association Stadium --> 53
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 53
# M Chinnaswamy Stadium - Sharjah Cricket Stadium --> 52
# M Chinnaswamy Stadium - New Wanderers Stadium --> 52
# Saurashtra Cricket Association Stadium - Sardar Patel Stadium, Motera --> 52
# Vidarbha Cricket Association Stadium, Jamtha - Rajiv Gandhi International Stadium, Uppal --> 52
# Shaheed Veer Narayan Singh International Stadium - Himachal Pradesh Cricket Association Stadium --> 52
# Sharjah Cricket Stadium - M.Chinnaswamy Stadium --> 52
# Sharjah Cricket Stadium - New Wanderers Stadium --> 52
# Rajiv Gandhi International Stadium, Uppal - Sardar Patel Stadium, Motera --> 52
# SuperSport Park - Buffalo Park --> 52
# Sardar Patel Stadium, Motera - Sheikh Zayed Stadium --> 52
# M.Chinnaswamy Stadium - New Wanderers Stadium --> 52
# Dubai International Cricket Stadium - Subrata Roy Sahara Stadium --> 52
# M Chinnaswamy Stadium - Holkar Cricket Stadium --> 51
# M Chinnaswamy Stadium - Subrata Roy Sahara Stadium --> 51
# Punjab Cricket Association Stadium, Mohali - Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium --> 51
# Saurashtra Cricket Association Stadium - Rajiv Gandhi International Stadium, Uppal --> 51
# Vidarbha Cricket Association Stadium, Jamtha - MA Chidambaram Stadium, Chepauk --> 51
# Holkar Cricket Stadium - MA Chidambaram Stadium, Chepauk --> 51
# Holkar Cricket Stadium - M.Chinnaswamy Stadium --> 51
# Holkar Cricket Stadium - Subrata Roy Sahara Stadium --> 51
# MA Chidambaram Stadium, Chepauk - Subrata Roy Sahara Stadium --> 51
# M.Chinnaswamy Stadium - Subrata Roy Sahara Stadium --> 51
# Punjab Cricket Association Stadium, Mohali - Kingsmead --> 50
# Saurashtra Cricket Association Stadium - Kingsmead --> 50
# Saurashtra Cricket Association Stadium - JSCA International Stadium Complex --> 50
# Vidarbha Cricket Association Stadium, Jamtha - Kingsmead --> 50
# Holkar Cricket Stadium - Sawai Mansingh Stadium --> 50
# Holkar Cricket Stadium - Sardar Patel Stadium, Motera --> 50
# Feroz Shah Kotla - Subrata Roy Sahara Stadium --> 50
# Himachal Pradesh Cricket Association Stadium - Kingsmead --> 50
# Sharjah Cricket Stadium - JSCA International Stadium Complex --> 50
# Kingsmead - Maharashtra Cricket Association Stadium --> 50
# Rajiv Gandhi International Stadium, Uppal - MA Chidambaram Stadium, Chepauk --> 50
# Rajiv Gandhi International Stadium, Uppal - Punjab Cricket Association IS Bindra Stadium, Mohali --> 50
# Punjab Cricket Association Stadium, Mohali - MA Chidambaram Stadium, Chepauk --> 49
# Vidarbha Cricket Association Stadium, Jamtha - JSCA International Stadium Complex --> 49
# Himachal Pradesh Cricket Association Stadium - Rajiv Gandhi International Stadium, Uppal --> 49
# Sardar Patel Stadium, Motera - Maharashtra Cricket Association Stadium --> 49
# MA Chidambaram Stadium, Chepauk - Dubai International Cricket Stadium --> 49
# MA Chidambaram Stadium, Chepauk - JSCA International Stadium Complex --> 49
# MA Chidambaram Stadium, Chepauk - Maharashtra Cricket Association Stadium --> 49
# Sheikh Zayed Stadium - Subrata Roy Sahara Stadium --> 49
# JSCA International Stadium Complex - Maharashtra Cricket Association Stadium --> 49
# M Chinnaswamy Stadium - Sardar Patel Stadium, Motera --> 48
# Saurashtra Cricket Association Stadium - MA Chidambaram Stadium, Chepauk --> 48
# Shaheed Veer Narayan Singh International Stadium - Kingsmead --> 48
# Himachal Pradesh Cricket Association Stadium - MA Chidambaram Stadium, Chepauk --> 48
# Dr DY Patil Sports Academy - Sardar Patel Stadium, Motera --> 48
# Dr DY Patil Sports Academy - Barabati Stadium --> 48
# Rajiv Gandhi International Stadium, Uppal - Maharashtra Cricket Association Stadium --> 48
# Sardar Patel Stadium, Motera - M.Chinnaswamy Stadium --> 48
# MA Chidambaram Stadium, Chepauk - New Wanderers Stadium --> 48
# De Beers Diamond Oval - New Wanderers Stadium --> 48
# JSCA International Stadium Complex - Subrata Roy Sahara Stadium --> 48
# Subrata Roy Sahara Stadium - New Wanderers Stadium --> 48
# Buffalo Park - St George's Park --> 48
# Shaheed Veer Narayan Singh International Stadium - Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium --> 47
# Himachal Pradesh Cricket Association Stadium - JSCA International Stadium Complex --> 47
# Kingsmead - Newlands --> 47
# Vidarbha Cricket Association Stadium, Jamtha - Shaheed Veer Narayan Singh International Stadium --> 46
# Shaheed Veer Narayan Singh International Stadium - Punjab Cricket Association IS Bindra Stadium, Mohali --> 46
# Sawai Mansingh Stadium - MA Chidambaram Stadium, Chepauk --> 46
# Sardar Patel Stadium, Motera - Dubai International Cricket Stadium --> 46
# Punjab Cricket Association Stadium, Mohali - Shaheed Veer Narayan Singh International Stadium --> 45
# Saurashtra Cricket Association Stadium - SuperSport Park --> 45
# Eden Gardens - Shaheed Veer Narayan Singh International Stadium --> 45
# Eden Gardens - New Wanderers Stadium --> 45
# Himachal Pradesh Cricket Association Stadium - Newlands --> 45
# Dr DY Patil Sports Academy - SuperSport Park --> 45
# Newlands - Brabourne Stadium --> 45
# Newlands - Sardar Patel Stadium, Motera --> 45
# Newlands - Wankhede Stadium --> 45
# Brabourne Stadium - OUTsurance Oval --> 44
# De Beers Diamond Oval - OUTsurance Oval --> 44
# Saurashtra Cricket Association Stadium - St George's Park --> 43
# Eden Gardens - Sardar Patel Stadium, Motera --> 43
# Eden Gardens - Wankhede Stadium --> 43
# Feroz Shah Kotla - Sardar Patel Stadium, Motera --> 43
# Dr DY Patil Sports Academy - Dubai International Cricket Stadium --> 43
# Sardar Patel Stadium, Motera - St George's Park --> 43
# De Beers Diamond Oval - Punjab Cricket Association IS Bindra Stadium, Mohali --> 43
# Saurashtra Cricket Association Stadium - OUTsurance Oval --> 42
# Dr DY Patil Sports Academy - Rajiv Gandhi International Stadium, Uppal --> 42
# Dr DY Patil Sports Academy - Subrata Roy Sahara Stadium --> 42
# Maharashtra Cricket Association Stadium - OUTsurance Oval --> 42
# Subrata Roy Sahara Stadium - OUTsurance Oval --> 42
# Eden Gardens - St George's Park --> 41
# Shaheed Veer Narayan Singh International Stadium - Dr DY Patil Sports Academy --> 41
# Feroz Shah Kotla - Sharjah Cricket Stadium --> 41
# Feroz Shah Kotla - Nehru Stadium --> 41
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Rajiv Gandhi International Stadium, Uppal --> 41
# Nehru Stadium - De Beers Diamond Oval --> 41
# Sardar Patel Stadium, Motera - De Beers Diamond Oval --> 41
# M Chinnaswamy Stadium - Kingsmead --> 40
# Punjab Cricket Association Stadium, Mohali - OUTsurance Oval --> 40
# Saurashtra Cricket Association Stadium - Feroz Shah Kotla --> 40
# Eden Gardens - Newlands --> 40
# Holkar Cricket Stadium - Feroz Shah Kotla --> 40
# Holkar Cricket Stadium - Kingsmead --> 40
# Holkar Cricket Stadium - St George's Park --> 40
# Shaheed Veer Narayan Singh International Stadium - Feroz Shah Kotla --> 40
# Shaheed Veer Narayan Singh International Stadium - St George's Park --> 40
# Feroz Shah Kotla - Himachal Pradesh Cricket Association Stadium --> 40
# Feroz Shah Kotla - Rajiv Gandhi International Stadium, Uppal --> 40
# Feroz Shah Kotla - JSCA International Stadium Complex --> 40
# Himachal Pradesh Cricket Association Stadium - St George's Park --> 40
# Sharjah Cricket Stadium - Kingsmead --> 40
# Dr DY Patil Sports Academy - St George's Park --> 40
# Kingsmead - Rajiv Gandhi International Stadium, Uppal --> 40
# Kingsmead - Brabourne Stadium --> 40
# Kingsmead - M.Chinnaswamy Stadium --> 40
# Kingsmead - Dubai International Cricket Stadium --> 40
# Kingsmead - JSCA International Stadium Complex --> 40
# Kingsmead - Barabati Stadium --> 40
# SuperSport Park - Sardar Patel Stadium, Motera --> 40
# Sardar Patel Stadium, Motera - OUTsurance Oval --> 40
# MA Chidambaram Stadium, Chepauk - St George's Park --> 40
# Maharashtra Cricket Association Stadium - St George's Park --> 40
# Subrata Roy Sahara Stadium - St George's Park --> 40
# Punjab Cricket Association IS Bindra Stadium, Mohali - OUTsurance Oval --> 40
# Punjab Cricket Association Stadium, Mohali - De Beers Diamond Oval --> 39
# Saurashtra Cricket Association Stadium - De Beers Diamond Oval --> 39
# Vidarbha Cricket Association Stadium, Jamtha - De Beers Diamond Oval --> 39
# Shaheed Veer Narayan Singh International Stadium - De Beers Diamond Oval --> 39
# Feroz Shah Kotla - SuperSport Park --> 39
# Feroz Shah Kotla - OUTsurance Oval --> 39
# Himachal Pradesh Cricket Association Stadium - De Beers Diamond Oval --> 39
# Sharjah Cricket Stadium - St George's Park --> 39
# Rajiv Gandhi International Stadium, Uppal - De Beers Diamond Oval --> 39
# De Beers Diamond Oval - Dubai International Cricket Stadium --> 39
# De Beers Diamond Oval - Maharashtra Cricket Association Stadium --> 39
# Punjab Cricket Association Stadium, Mohali - Dr DY Patil Sports Academy --> 38
# Punjab Cricket Association Stadium, Mohali - Buffalo Park --> 38
# Punjab Cricket Association Stadium, Mohali - St George's Park --> 38
# Saurashtra Cricket Association Stadium - Dr DY Patil Sports Academy --> 38
# Eden Gardens - Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium --> 38
# Eden Gardens - Himachal Pradesh Cricket Association Stadium --> 38
# Eden Gardens - Kingsmead --> 38
# Eden Gardens - Rajiv Gandhi International Stadium, Uppal --> 38
# Eden Gardens - Sheikh Zayed Stadium --> 38
# Eden Gardens - De Beers Diamond Oval --> 38
# Vidarbha Cricket Association Stadium, Jamtha - Feroz Shah Kotla --> 38
# Vidarbha Cricket Association Stadium, Jamtha - Buffalo Park --> 38
# Vidarbha Cricket Association Stadium, Jamtha - St George's Park --> 38
# Holkar Cricket Stadium - Dr DY Patil Sports Academy --> 38
# Feroz Shah Kotla - Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium --> 38
# Feroz Shah Kotla - De Beers Diamond Oval --> 38
# Feroz Shah Kotla - Dubai International Cricket Stadium --> 38
# Feroz Shah Kotla - St George's Park --> 38
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Buffalo Park --> 38
# Himachal Pradesh Cricket Association Stadium - Dr DY Patil Sports Academy --> 38
# Himachal Pradesh Cricket Association Stadium - Buffalo Park --> 38
# Dr DY Patil Sports Academy - Sawai Mansingh Stadium --> 38
# Dr DY Patil Sports Academy - Maharashtra Cricket Association Stadium --> 38
# Dr DY Patil Sports Academy - Buffalo Park --> 38
# Kingsmead - Sheikh Zayed Stadium --> 38
# Kingsmead - Punjab Cricket Association IS Bindra Stadium, Mohali --> 38
# Kingsmead - New Wanderers Stadium --> 38
# Newlands - Nehru Stadium --> 38
# MA Chidambaram Stadium, Chepauk - Buffalo Park --> 38
# De Beers Diamond Oval - Wankhede Stadium --> 38
# JSCA International Stadium Complex - St George's Park --> 38
# Subrata Roy Sahara Stadium - Buffalo Park --> 38
# Buffalo Park - Punjab Cricket Association IS Bindra Stadium, Mohali --> 38
# Punjab Cricket Association IS Bindra Stadium, Mohali - St George's Park --> 38
# St George's Park - New Wanderers Stadium --> 38
# Vidarbha Cricket Association Stadium, Jamtha - Dr DY Patil Sports Academy --> 37
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - De Beers Diamond Oval --> 37
# Sharjah Cricket Stadium - Dr DY Patil Sports Academy --> 37
# Sharjah Cricket Stadium - OUTsurance Oval --> 37
# Dr DY Patil Sports Academy - Brabourne Stadium --> 37
# Dr DY Patil Sports Academy - JSCA International Stadium Complex --> 37
# Brabourne Stadium - De Beers Diamond Oval --> 37
# Sheikh Zayed Stadium - De Beers Diamond Oval --> 37
# Punjab Cricket Association Stadium, Mohali - SuperSport Park --> 36
# Punjab Cricket Association Stadium, Mohali - Green Park --> 36
# Saurashtra Cricket Association Stadium - Eden Gardens --> 36
# Eden Gardens - Maharashtra Cricket Association Stadium --> 36
# Vidarbha Cricket Association Stadium, Jamtha - SuperSport Park --> 36
# Vidarbha Cricket Association Stadium, Jamtha - OUTsurance Oval --> 36
# Holkar Cricket Stadium - Green Park --> 36
# Shaheed Veer Narayan Singh International Stadium - Green Park --> 36
# Shaheed Veer Narayan Singh International Stadium - Buffalo Park --> 36
# Shaheed Veer Narayan Singh International Stadium - OUTsurance Oval --> 36
# Feroz Shah Kotla - Brabourne Stadium --> 36
# Feroz Shah Kotla - Green Park --> 36
# Feroz Shah Kotla - Buffalo Park --> 36
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Green Park --> 36
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - OUTsurance Oval --> 36
# Himachal Pradesh Cricket Association Stadium - SuperSport Park --> 36
# Himachal Pradesh Cricket Association Stadium - Green Park --> 36
# Himachal Pradesh Cricket Association Stadium - OUTsurance Oval --> 36
# Dr DY Patil Sports Academy - Nehru Stadium --> 36
# Dr DY Patil Sports Academy - Green Park --> 36
# Dr DY Patil Sports Academy - OUTsurance Oval --> 36
# Kingsmead - Nehru Stadium --> 36
# Nehru Stadium - SuperSport Park --> 36
# Rajiv Gandhi International Stadium, Uppal - OUTsurance Oval --> 36
# Brabourne Stadium - Green Park --> 36
# Brabourne Stadium - St George's Park --> 36
# SuperSport Park - Maharashtra Cricket Association Stadium --> 36
# SuperSport Park - Subrata Roy Sahara Stadium --> 36
# Sardar Patel Stadium, Motera - Green Park --> 36
# Sardar Patel Stadium, Motera - Buffalo Park --> 36
# MA Chidambaram Stadium, Chepauk - Green Park --> 36
# Green Park - De Beers Diamond Oval --> 36
# Green Park - Dubai International Cricket Stadium --> 36
# Green Park - Subrata Roy Sahara Stadium --> 36
# Green Park - Wankhede Stadium --> 36
# Green Park - Punjab Cricket Association IS Bindra Stadium, Mohali --> 36
# Green Park - OUTsurance Oval --> 36
# Green Park - New Wanderers Stadium --> 36
# De Beers Diamond Oval - JSCA International Stadium Complex --> 36
# Dubai International Cricket Stadium - OUTsurance Oval --> 36
# JSCA International Stadium Complex - OUTsurance Oval --> 36
# Dr DY Patil Sports Academy - Sheikh Zayed Stadium --> 35
# MA Chidambaram Stadium, Chepauk - De Beers Diamond Oval --> 35
# M Chinnaswamy Stadium - Dr DY Patil Sports Academy --> 34
# M Chinnaswamy Stadium - Newlands --> 34
# Punjab Cricket Association Stadium, Mohali - Feroz Shah Kotla --> 34
# Punjab Cricket Association Stadium, Mohali - Newlands --> 34
# Saurashtra Cricket Association Stadium - Newlands --> 34
# Saurashtra Cricket Association Stadium - Green Park --> 34
# Vidarbha Cricket Association Stadium, Jamtha - Newlands --> 34
# Vidarbha Cricket Association Stadium, Jamtha - Green Park --> 34
# Holkar Cricket Stadium - Newlands --> 34
# Shaheed Veer Narayan Singh International Stadium - Newlands --> 34
# Feroz Shah Kotla - Dr DY Patil Sports Academy --> 34
# Feroz Shah Kotla - Maharashtra Cricket Association Stadium --> 34
# Feroz Shah Kotla - Punjab Cricket Association IS Bindra Stadium, Mohali --> 34
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - SuperSport Park --> 34
# Sharjah Cricket Stadium - Newlands --> 34
# Sharjah Cricket Stadium - SuperSport Park --> 34
# Sharjah Cricket Stadium - Green Park --> 34
# Dr DY Patil Sports Academy - MA Chidambaram Stadium, Chepauk --> 34
# Dr DY Patil Sports Academy - De Beers Diamond Oval --> 34
# Dr DY Patil Sports Academy - M.Chinnaswamy Stadium --> 34
# Dr DY Patil Sports Academy - Wankhede Stadium --> 34
# Dr DY Patil Sports Academy - Punjab Cricket Association IS Bindra Stadium, Mohali --> 34
# Dr DY Patil Sports Academy - New Wanderers Stadium --> 34
# Newlands - Rajiv Gandhi International Stadium, Uppal --> 34
# Newlands - Sawai Mansingh Stadium --> 34
# Newlands - Sheikh Zayed Stadium --> 34
# Newlands - De Beers Diamond Oval --> 34
# Newlands - M.Chinnaswamy Stadium --> 34
# Newlands - Dubai International Cricket Stadium --> 34
# Newlands - JSCA International Stadium Complex --> 34
# Newlands - Maharashtra Cricket Association Stadium --> 34
# Newlands - Punjab Cricket Association IS Bindra Stadium, Mohali --> 34
# Newlands - OUTsurance Oval --> 34
# Nehru Stadium - St George's Park --> 34
# Rajiv Gandhi International Stadium, Uppal - St George's Park --> 34
# Brabourne Stadium - Buffalo Park --> 34
# Green Park - Maharashtra Cricket Association Stadium --> 34
# Dubai International Cricket Stadium - St George's Park --> 34
# Feroz Shah Kotla - Sheikh Zayed Stadium --> 33
# SuperSport Park - De Beers Diamond Oval --> 33
# SuperSport Park - OUTsurance Oval --> 33
# Sheikh Zayed Stadium - St George's Park --> 33
# M Chinnaswamy Stadium - Feroz Shah Kotla --> 32
# Eden Gardens - Dr DY Patil Sports Academy --> 32
# Eden Gardens - Nehru Stadium --> 32
# Holkar Cricket Stadium - OUTsurance Oval --> 32
# Feroz Shah Kotla - Newlands --> 32
# Feroz Shah Kotla - Sawai Mansingh Stadium --> 32
# Feroz Shah Kotla - MA Chidambaram Stadium, Chepauk --> 32
# Feroz Shah Kotla - M.Chinnaswamy Stadium --> 32
# Feroz Shah Kotla - New Wanderers Stadium --> 32
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Newlands --> 32
# Kingsmead - Green Park --> 32
# Kingsmead - Wankhede Stadium --> 32
# Newlands - Subrata Roy Sahara Stadium --> 32
# Newlands - St George's Park --> 32
# Sawai Mansingh Stadium - St George's Park --> 32
# SuperSport Park - Dubai International Cricket Stadium --> 32
# De Beers Diamond Oval - Subrata Roy Sahara Stadium --> 32
# De Beers Diamond Oval - St George's Park --> 32
# De Beers Diamond Oval - Barabati Stadium --> 32
# Wankhede Stadium - OUTsurance Oval --> 32
# St George's Park - OUTsurance Oval --> 32
# Feroz Shah Kotla - Wankhede Stadium --> 31
# Feroz Shah Kotla - Barabati Stadium --> 31
# Brabourne Stadium - SuperSport Park --> 31
# SuperSport Park - New Wanderers Stadium --> 31
# Wankhede Stadium - St George's Park --> 31
# Punjab Cricket Association Stadium, Mohali - Eden Gardens --> 30
# Saurashtra Cricket Association Stadium - Buffalo Park --> 30
# Eden Gardens - Vidarbha Cricket Association Stadium, Jamtha --> 30
# Eden Gardens - Holkar Cricket Stadium --> 30
# Eden Gardens - Sharjah Cricket Stadium --> 30
# Eden Gardens - Sawai Mansingh Stadium --> 30
# Eden Gardens - SuperSport Park --> 30
# Eden Gardens - MA Chidambaram Stadium, Chepauk --> 30
# Eden Gardens - Dubai International Cricket Stadium --> 30
# Eden Gardens - JSCA International Stadium Complex --> 30
# Eden Gardens - Subrata Roy Sahara Stadium --> 30
# Eden Gardens - Punjab Cricket Association IS Bindra Stadium, Mohali --> 30
# Holkar Cricket Stadium - SuperSport Park --> 30
# Holkar Cricket Stadium - Buffalo Park --> 30
# Shaheed Veer Narayan Singh International Stadium - SuperSport Park --> 30
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium - Kingsmead --> 30
# Sharjah Cricket Stadium - Buffalo Park --> 30
# Dr DY Patil Sports Academy - Kingsmead --> 30
# Kingsmead - Sardar Patel Stadium, Motera --> 30
# Kingsmead - MA Chidambaram Stadium, Chepauk --> 30
# Kingsmead - De Beers Diamond Oval --> 30
# Kingsmead - Subrata Roy Sahara Stadium --> 30
# Kingsmead - St George's Park --> 30
# Kingsmead - OUTsurance Oval --> 30
# Rajiv Gandhi International Stadium, Uppal - SuperSport Park --> 30
# Rajiv Gandhi International Stadium, Uppal - Buffalo Park --> 30
# SuperSport Park - MA Chidambaram Stadium, Chepauk --> 30
# SuperSport Park - JSCA International Stadium Complex --> 30
# SuperSport Park - Punjab Cricket Association IS Bindra Stadium, Mohali --> 30
# SuperSport Park - Barabati Stadium --> 30
# MA Chidambaram Stadium, Chepauk - OUTsurance Oval --> 30
# De Beers Diamond Oval - Buffalo Park --> 30
# Dubai International Cricket Stadium - Buffalo Park --> 30
# JSCA International Stadium Complex - Buffalo Park --> 30
# Maharashtra Cricket Association Stadium - Buffalo Park --> 30
# Buffalo Park - OUTsurance Oval --> 30
# M Chinnaswamy Stadium - De Beers Diamond Oval --> 29
# Nehru Stadium - OUTsurance Oval --> 29
# SuperSport Park - Sheikh Zayed Stadium --> 29
# Sheikh Zayed Stadium - OUTsurance Oval --> 29
# De Beers Diamond Oval - M.Chinnaswamy Stadium --> 29
# Buffalo Park - Barabati Stadium --> 29
# St George's Park - Barabati Stadium --> 29
# Eden Gardens - Feroz Shah Kotla --> 28
# Eden Gardens - Brabourne Stadium --> 28
# Holkar Cricket Stadium - De Beers Diamond Oval --> 28
# Feroz Shah Kotla - Kingsmead --> 28
# Kingsmead - SuperSport Park --> 28
# Sawai Mansingh Stadium - De Beers Diamond Oval --> 28
# Wankhede Stadium - Buffalo Park --> 28
# Buffalo Park - New Wanderers Stadium --> 28
# OUTsurance Oval - New Wanderers Stadium --> 28
# Sharjah Cricket Stadium - De Beers Diamond Oval --> 27
# Rajiv Gandhi International Stadium, Uppal - Green Park --> 27
# Sawai Mansingh Stadium - Green Park --> 27
# Sawai Mansingh Stadium - OUTsurance Oval --> 27
# Sheikh Zayed Stadium - Green Park --> 27
# Green Park - JSCA International Stadium Complex --> 27
# M Chinnaswamy Stadium - St George's Park --> 26
# Nehru Stadium - Green Park --> 26
# Sawai Mansingh Stadium - SuperSport Park --> 26
# SuperSport Park - Wankhede Stadium --> 26
# M.Chinnaswamy Stadium - St George's Park --> 26
# OUTsurance Oval - Barabati Stadium --> 26
# Eden Gardens - Buffalo Park --> 25
# M Chinnaswamy Stadium - Eden Gardens --> 24
# Eden Gardens - M.Chinnaswamy Stadium --> 24
# Nehru Stadium - Buffalo Park --> 24
# Green Park - Barabati Stadium --> 23
# M Chinnaswamy Stadium - SuperSport Park --> 22
# M Chinnaswamy Stadium - Buffalo Park --> 22
# M Chinnaswamy Stadium - OUTsurance Oval --> 22
# Eden Gardens - OUTsurance Oval --> 22
# Dr DY Patil Sports Academy - Newlands --> 22
# Newlands - SuperSport Park --> 22
# Newlands - MA Chidambaram Stadium, Chepauk --> 22
# Newlands - Green Park --> 22
# Newlands - Buffalo Park --> 22
# Newlands - Barabati Stadium --> 22
# Sawai Mansingh Stadium - Buffalo Park --> 22
# SuperSport Park - M.Chinnaswamy Stadium --> 22
# Sheikh Zayed Stadium - Buffalo Park --> 22
# M.Chinnaswamy Stadium - Buffalo Park --> 22
# M.Chinnaswamy Stadium - OUTsurance Oval --> 22
# Eden Gardens - Barabati Stadium --> 21
# M Chinnaswamy Stadium - Green Park --> 19
# Green Park - M.Chinnaswamy Stadium --> 19
# Kingsmead - Buffalo Park --> 10
# Counter({'Eden Gardens': 77, 'Feroz Shah Kotla': 74, 'Wankhede Stadium': 73, 'M Chinnaswamy Stadium': 65, 'Rajiv Gandhi International Stadium, Uppal': 64, 'MA Chidambaram Stadium, Chepauk': 57, 'Sawai Mansingh Stadium': 47, 'Punjab Cricket Association Stadium, Mohali': 35, 'Dubai International Cricket Stadium': 33, 'Sheikh Zayed Stadium': 29, 'Maharashtra Cricket Association Stadium': 21, 'Punjab Cricket Association IS Bindra Stadium, Mohali': 21, 'Sharjah Cricket Stadium': 18, 'Dr DY Patil Sports Academy': 17, 'Subrata Roy Sahara Stadium': 17, 'M.Chinnaswamy Stadium': 15, 'Kingsmead': 15, 'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium': 13, 'SuperSport Park': 12, 'Sardar Patel Stadium, Motera': 12, 'Brabourne Stadium': 11, 'Saurashtra Cricket Association Stadium': 10, 'Holkar Cricket Stadium': 9, 'Himachal Pradesh Cricket Association Stadium': 9, 'New Wanderers Stadium': 8, 'Newlands': 7, "St George's Park": 7, 'Barabati Stadium': 7, 'JSCA International Stadium Complex': 7, 'Shaheed Veer Narayan Singh International Stadium': 6, 'Nehru Stadium': 5, 'Green Park': 4, 'Buffalo Park': 3, 'De Beers Diamond Oval': 3, 'Vidarbha Cricket Association Stadium, Jamtha': 3, 'OUTsurance Oval': 2})

# %% [markdown]
# ### These stadiums have duplicates so removing them, but they need to be mapped to the same venue_id when iterating over the matches

# %%
if tournament_name == "IPL":
    unique_venues_list.remove("M.Chinnaswamy Stadium")
    unique_venues_list.remove("Punjab Cricket Association IS Bindra Stadium, Mohali")
if tournament_name == "BBL":
    unique_venues_list.remove("Brisbane Cricket Ground")

# %%
pad=0
# if venue.csv already exists, read it and append the new data into it. if it does not exist, create new file
if os.path.exists(os.path.join(clean_data_path, "venue.csv")):
    old_venue_csv = pd.read_csv(os.path.join(clean_data_path, "venue.csv"))
    pad = len(old_venue_csv)

venue_columns = ["venue_id", "venue_name"]
venue_csv = pd.DataFrame(columns = venue_columns)
    
for i in range(len(unique_venues_list)):
    venue_id = i+1+pad
    venue_name = unique_venues_list[i]
    venue_csv = venue_csv.append({"venue_id" : venue_id, 
                                  "venue_name" : venue_name}, ignore_index=True)
    
if os.path.exists(os.path.join(clean_data_path, "venue.csv")):
    old_venue_csv = pd.read_csv(os.path.join(clean_data_path, "venue.csv"))
    venue_csv = old_venue_csv.append(venue_csv)
    
venue_csv.to_csv(os.path.join(clean_data_path, "venue.csv"), index=False)

# %% [markdown]
# ### Utility maps for tournaments, venues, teams and players

# %%
df_tournament = pd.read_csv(os.path.join(clean_data_path, "tournament.csv"))
df_tournament = df_tournament.loc[:, ~df_tournament.columns.str.contains('^Unnamed')]
tournament_id_map = dict(zip(df_tournament.tournament_name, df_tournament.tournament_id))
tournament_fullname_id_map = dict(zip(df_tournament.tournament_full_name, df_tournament.tournament_id))

# %%
df_venue = pd.read_csv(os.path.join(clean_data_path, "venue.csv"))
df_venue = df_venue.loc[:, ~df_venue.columns.str.contains('^Unnamed')]
venue_id_map = dict(zip(df_venue.venue_name, df_venue.venue_id))

# Mapping the duplicates as well to its correct venue ids
# IPL maps
if tournament_name == "IPL":
    venue_id_map["Punjab Cricket Association IS Bindra Stadium, Mohali"] = venue_id_map["Punjab Cricket Association Stadium, Mohali"]
    venue_id_map["M.Chinnaswamy Stadium"] = venue_id_map["M Chinnaswamy Stadium"]
# BBL maps
if tournament_name == "BBL":
    venue_id_map["Brisbane Cricket Ground"] = venue_id_map["Brisbane Cricket Ground, Woolloongabba"]

# %%
df_team = pd.read_csv(os.path.join(clean_data_path, "team.csv"))
df_team = df_team.loc[:, ~df_team.columns.str.contains('^Unnamed')]
team_id_map = dict(zip(df_team.team_name, df_team.team_id))

# %% [markdown]
# ### Use this cell for all manual corrections to update/insert in players table

# %%
# updates

# IPL
update_player("player_display_name", "RG Sharma", "player_name", "Rohit Sharma")
update_player("player_display_name", "SA Yadav", "player_name", "Suryakumar Yadav")
update_player("player_display_name", "CRD Fernando", "player_name", "Dilhara Fernando")
update_player("player_display_name", "DPMD Jayawardene", "player_name", "Mahela Jayawardene")
update_player("player_display_name", "R Powell", "player_name", "Rovman Powell")
update_player("player_display_name", "RK Singh", "player_name", "Rinku Singh")
update_player("player_display_name", "JPR Scantlebury-Searles", "player_name", "Javon Searles")
update_player("player_display_name", "Milind Kumar", "player_name", "Milind Kumar")
update_player("player_display_name", "NB Singh", "player_name", "Nathu Singh")
update_player("player_display_name", "AS Yadav", "player_name", "Arjun Yadav")
update_player("player_display_name", "VRV Singh", "player_full_name", "Vikram Raj Vir Singh")
update_player("player_display_name", "R Bishnoi", "player_full_name", "Rajesh Bishnoi")
update_player("player_display_name", "KH Devdhar", "player_full_name", "Kedar Hemant Devdhar")
update_player("player_display_name", "Harmeet Singh (2)", "player_full_name", "Harmeet Singh")
update_player("player_display_name", "AV Wankhade", "player_full_name", "Apoorv Vijay Wankhade")
update_player("player_display_name", "B Aparajith", "player_full_name", "Baba Aparajith")
update_player("player_display_name", "Anmolpreet Singh", "player_full_name", "Anmolpreet Singh")
update_player("player_display_name", "A Mishra", "player_full_name", "Amit Mishra")
update_player("player_display_name", "", "player_full_name", "Aditya Mishra")
update_player("player_display_name", "B Kumar", "player_full_name", "Bhuvneshwar Kumar Singh")
update_player("player_display_name", "", "player_full_name", "Kumar Dinesh Boresa")



# BBL
update_player("player_display_name", "CJ Green", "player_full_name", "Christopher James Green")
update_player("player_display_name", "C Green", "player_full_name", "Cameron Green")
update_player("player_display_name", "DP Hughes", "player_full_name", "Daniel Peter Hughes")
update_player("player_display_name", "TH David", "player_full_name", "Timothy Hays David")



# inserts

# IPL
add_player("Ankit Soni", "Ankit Soni", "Ankit Soni", "Right-hand bat", "Legbreak googly", "02/08/1993", "2", str(team_id_map["Gujarat Lions"]))
add_player("J Suchith", "Jagadeesha Suchith", "Jagadeesha Suchith", "Left-hand bat", "Slow left-arm orthodox", "01/16/1994", "2", str(team_id_map["Kings XI Punjab"]))
add_player("SD Lad", "Siddhesh Lad", "Siddhesh Dinesh Lad", "Right-hand bat", "Right-arm offbreak", "23/05/92", "2", str(team_id_map["Mumbai Indians"]))
add_player("S Kaushik", "Shivil Kaushik", "Shivil Sharma Kaushik", "Left-hand bat", "Slow left-arm wrist-spin", "07/09/95", "2", str(team_id_map["Gujarat Lions"]))
add_player("KM Asif", "KM Asif", "KM Asif", "Right-hand bat", "Right-arm medium", "24/07/93", "2", str(team_id_map["Chennai Super Kings"]))
add_player("AS Roy", "Anukul Roy", "Anukul Sudhakar Roy", "Left-hand bat", "Slow left-arm orthodox", "30/11/98", "2", str(team_id_map["Mumbai Indians"]))
add_player("YBK Jaiswal", "Yashasvi Jaiswal", "Yashasvi Bhupendra Kumar Jaiswal", "Left-hand bat", "", "28/12/01", "2", str(team_id_map["Rajasthan Royals"]))
add_player("Abdul Samad", "Abdul Samad", "Abdul Samad", "Right-hand bat", "Right-arm legbreak", "10/28/01", "2", str(team_id_map["Sunrisers Hyderabad"]))
add_player("Kartik Tyagi", "Kartik Tyagi", "Kartik Tyagi", "Right-hand bat", "Right-arm fast", "11/08/00", "2", str(team_id_map["Rajasthan Royals"]))
add_player("Lalit Yadav", "Lalit Yadav", "Lalit Yadav", "Right-hand bat", "Right-arm offbreak", "03/01/97", "2", str(team_id_map["Delhi Daredevils"]))
add_player("Ravi Bishnoi", "Ravi Bishnoi", "Ravi Bishnoi", "Right-hand bat", "Legbreak googly", "05/09/00", "2", str(team_id_map["Kings XI Punjab"]))
add_player("RA Shaikh", "Rahil Shaikh", "Rahil Akhil Ahmed Shaikh", "Left-hand bat", "Left-arm medium", "12/06/85", "2", str(team_id_map["Mumbai Indians"]))
add_player("AN Ahmed", "AN Ahmed", "AN Ahmed", "Left-hand bat", "Left-arm medium", "12/06/85", "2", str(team_id_map["Mumbai Indians"]))
add_player("AA Kazi", "Abrar Kazi", "Abrar Anjum Kazi", "Left-hand bat", "Slow left-arm orthodox", "10/29/89", "2", str(team_id_map["Royal Challengers Bangalore"]))
add_player("T Mishra", "Tanmay Mishra", "Tanmay Mishra", "Right-hand bat", "Right-arm medium-fast", "12/22/86", "2", str(team_id_map["Deccan Chargers"]))

# BBL
add_player("AG Harriott", "Andrew Harriott", "Andrew Harriott", "Right-hand bat", "Right-arm medium-fast", "05/03/92", "4", str(team_id_map["Melbourne Renegades"]))
add_player("B Doggett", "Brendan Doggett", "Brendan Doggett", "Right-hand bat", "Right-arm fast-medium", "03/05/94", "4", str(team_id_map["Sydney Thunder"]) + "," + str(team_id_map["Brisbane Heat"]))
add_player("CP Simpson", "Chris Simpson", "Christopher Patrick Simpson", "Right-hand bat", "Right-arm offbreak", "09/01/82", "4", str(team_id_map["Sydney Thunder"]))
add_player("D Morton", "Daniel Morton", "Daniel Morton", "Right-hand bat", "Right-arm offbreak", "", "4", str(team_id_map["Perth Scorchers"]))
add_player("Dilbar Hussain", "Dilbar Hussain", "Dilbar Hussain", "Right-hand bat", "Right-arm fast-medium", "", "5", str(team_id_map["Melbourne Stars"]))
add_player("GA West", "GA West", "GA West", "", "", "", "", str(team_id_map["Adelaide Strikers"]))
add_player("H Kerr", "Hayden Kerr", "Hayden Kerr", "", "", "", "", str(team_id_map["Sydney Sixers"]))
add_player("Haris Rauf", "Haris Rauf", "Haris Rauf", "Right-hand bat", "Right-arm fast", "11/07/93", "5", str(team_id_map["Melbourne Stars"]))
add_player("J Fraser-McGurk", "Jake Fraser-McGurk", "Jake Fraser-McGurk", "Right-hand bat", "Legbreak googly", "11/04/02", "4", str(team_id_map["Melbourne Renegades"]))
add_player("CR Swan", "CR Swan", "CR Swan", "", "", "", "4", "72")
add_player("JA Prestwidge", "JA Prestwidge", "JA Prestwidge", "", "", "", "4", "199, 72")
add_player("JP Wood", "JP Wood", "JP Wood", "", "", "", "4", "72")
add_player("K White (sub)", "K White (sub)", "K White (sub)", "", "", "", "4", "512")
add_player("L Bowe", "L Bowe", "L Bowe", "", "", "", "4", "512, 568")
add_player("LR Morris", "LR Morris", "LR Morris", "", "", "", "4", "568")
add_player("M Perry", "M Perry", "M Perry", "", "", "", "4", "199")
add_player("MJ Owen", "MJ Owen", "MJ Owen", "", "", "", "4", "45")
add_player("NA McSweeney", "NA McSweeney", "NA McSweeney", "", "", "", "4", "199")
add_player("NT Ellis", "NT Ellis", "NT Ellis", "", "", "", "4", "45")
add_player("Noor Ahmad", "Noor Ahmad", "Noor Ahmad", "", "", "", "4", "199")
add_player("O Davies", "O Davies", "O Davies", "", "", "", "4", "512")
add_player("P Hatzoglou", "P Hatzoglou", "P Hatzoglou", "", "", "", "4", "199")
add_player("RJG Lockyear", "RJG Lockyear", "RJG Lockyear", "", "", "", "4", "45, 512")
add_player("RR Ayre (sub)", "RR Ayre (sub)", "RR Ayre (sub)", "", "", "", "4", "455")
add_player("SJ Coyte (2)", "SJ Coyte (2)", "SJ Coyte (2)", "", "", "", "4", "512")
add_player("T Sangha", "T Sangha", "T Sangha", "", "", "", "4", "512")
add_player("XC Bartlett", "XC Bartlett", "XC Bartlett", "", "", "", "4", "72")
add_player("K White", "K White", "K White", "", "", "", "4", "447")
add_player("RR Ayre", "RR Ayre", "RR Ayre", "", "", "", "4", "241")

# %%
df_player = pd.read_csv(os.path.join(clean_data_path, "player.csv"))
df_player = df_player.loc[:, ~df_player.columns.str.contains('^Unnamed')]
player_id_map = dict(zip(df_player.player_display_name, df_player.player_id))

# %%
player_id_map
# Out:
# {nan: 9445,
#  'Z Khan': 3,
#  'DNT Zoysa': 17,
#  'VH Zol': 53,
#  'EJG Morgan': 94,
#  'TS Mills': 128,
#  'MJ Lumb': 136,
#  'P Kumar': 186,
#  'A Zampa': 197,
#  'LS Livingstone': 216,
#  'E Lewis': 255,
#  'AD Mascarenhas': 292,
#  'GR Napier': 490,
#  'MM Ali': 553,
#  'SS Agarwal': 581,
#  'Mujeeb Ur Rahman': 604,
#  'Mohammad Nabi': 608,
#  'Rashid Khan': 3949,
#  'A Singh': 793,
#  'S Lamichhane': 807,
#  'Mustafizur Rahman': 876,
#  'Mohammad Ashraful': 900,
#  'Mashrafe Mortaza': 909,
#  'Shakib Al Hasan': 974,
#  'Abdur Razzak': 1211,
#  'RN ten Doeschate': 1275,
#  'RE van der Merwe': 1286,
#  'RW Price': 1506,
#  'T Taibu': 1546,
#  'S Sohal': 1603,
#  'R Sharma': 1627,
#  'Harmeet Singh': 1628,
#  'Gagandeep Singh': 2367,
#  'O Thomas': 1640,
#  'JE Taylor': 1644,
#  'CJ Anderson': 1674,
#  'DAJ Bracewell': 1697,
#  'TA Boult': 1698,
#  'SE Bond': 1699,
#  'C de Grandhomme': 1755,
#  'JEC Franklin': 1775,
#  'SP Fleming': 1782,
#  'LH Ferguson': 1788,
#  'MJ Guptill': 1792,
#  'MJ Henry': 1820,
#  'SC Kuggeleijn': 1845,
#  'C Munro': 1868,
#  'AF Milne': 1884,
#  'NL McCullum': 1915,
#  'BB McCullum': 1916,
#  'MJ McClenaghan': 1917,
#  'JDS Neesham': 1930,
#  'JDP Oram': 1935,
#  'JD Ryder': 1966,
#  'L Ronchi': 1972,
#  'SB Styris': 1990,
#  'TG Southee': 1997,
#  'IS Sodhi': 2001,
#  'MJ Santner': 2015,
#  'AJ Turner': 2018,
#  'LRPL Taylor': 2030,
#  'DL Vettori': 2037,
#  'KS Williamson': 2049,
#  'Avesh Khan': 2073,
#  'SA Asnodkar': 2076,
#  'R Ashwin': 2079,
#  'M Ashwin': 2080,
#  'A Ashish Reddy': 2085,
#  'J Arunkumar': 2089,
#  'KB Arun Karthik': 2090,
#  'Arshdeep Singh': 2091,
#  'S Aravind': 2097,
#  'KP Appanna': 2099,
#  'B Aparajith': 2100,
#  'Anureet Singh': 2101,
#  'Anmolpreet Singh': 2103,
#  'Ankit Sharma': 2105,
#  'Anirudh Singh': 2106,
#  'S Anirudha': 2107,
#  'Anand Rajan': 2110,
#  'A Mishra': 2545,
#  'JJ Bumrah': 2125,
#  'B Akhil': 2126,
#  'KK Ahmed': 2136,
#  'RR Bose': 2138,
#  'MA Agarwal': 2148,
#  'AB Agarkar': 2150,
#  'MS Bisla': 2154,
#  'R Bishnoi': 2156,
#  'UA Birla': 2158,
#  'Bipul Sharma': 2160,
#  'STR Binny': 2161,
#  'L Ablish': 2162,
#  'AA Bilakhia': 2165,
#  'Abhishek Sharma': 2167,
#  'RK Bhui': 2171,
#  'VR Aaron': 2177,
#  'P Amarnath': 2178,
#  'BA Bhatt': 2180,
#  'RR Bhatkal': 2181,
#  'R Bhatia': 2184,
#  'Basil Thampi': 2195,
#  'SB Bangar': 2198,
#  'L Balaji': 2206,
#  'S Badrinath': 2209,
#  'AR Bawne': 2212,
#  'ER Dwivedi': 2214,
#  'S Dube': 2218,
#  'P Dubey': 2219,
#  'R Dravid': 2221,
#  'AP Dole': 2222,
#  'P Dogra': 2224,
#  'AB Dinda': 2226,
#  'MS Dhoni': 2235,
#  'S Dhawan': 2237,
#  'R Dhawan': 2240,
#  'A Choudhary': 2242,
#  'P Chopra': 2244,
#  'A Chopra': 2248,
#  'SD Chitnis': 2249,
#  'B Chipli': 2251,
#  'KH Devdhar': 2257,
#  'PP Chawla': 2258,
#  'TU Deshpande': 2259,
#  'AA Chavan': 2260,
#  'A Chandila': 2279,
#  'UBT Chand': 2280,
#  'RD Chahar': 2286,
#  'DL Chahar': 2287,
#  'YS Chahal': 2288,
#  'KC Cariappa': 2292,
#  'H Das': 2295,
#  'DB Das': 2296,
#  'Gurkeerat Singh': 2305,
#  'Sunny Gupta': 2311,
#  'K Gowtham': 2316,
#  'SP Goswami': 2320,
#  'S Gopal': 2322,
#  'MS Gony': 2325,
#  'RV Gomez': 2326,
#  'K Goel': 2329,
#  'Y Gnaneswara Rao': 2331,
#  'FY Fazal': 2335,
#  'AN Ghosh': 2342,
#  'RS Gavaskar': 2348,
#  'CM Gautam': 2351,
#  'PK Garg': 2354,
#  'SC Ganguly': 2358,
#  'C Ganapathy': 2363,
#  'G Gambhir': 2364,
#  'RD Gaikwad': 2365,
#  'DJ Hooda': 2373,
#  'Harpreet Singh': 2388,
#  'Harpreet Brar': 2389,
#  'Harmeet Singh (2)': 2390,
#  'Harbhajan Singh': 2391,
#  'A Kumble': 2395,
#  'B Kumar': 2401,
#  'DS Kulkarni': 2404,
#  'Kuldeep Yadav': 2405,
#  'SS Iyer': 2413,
#  'MC Juneja': 2414,
#  'Ishan Kishan': 2419,
#  'SB Joshi': 2420,
#  'V Kohli': 2422,
#  'T Kohli': 2423,
#  'Iqbal Abdulla': 2425,
#  'Joginder Sharma': 2433,
#  'AA Jhunjhunwala': 2438,
#  'MA Khote': 2439,
#  'K Khejroliya': 2442,
#  'SN Khan': 2452,
#  'Jaskaran Singh': 2456,
#  'SB Jakati': 2459,
#  'IR Jaggi': 2468,
#  'N Jagadeesan': 2470,
#  'W Jaffer': 2471,
#  'KM Jadhav': 2475,
#  'U Kaul': 2479,
#  'S Kaul': 2480,
#  'RA Jadeja': 2481,
#  'SP Jackson': 2483,
#  'M Kartik': 2484,
#  'KD Karthik': 2485,
#  'Karanveer Singh': 2490,
#  'Kamran Khan': 3546,
#  'D Kalyankrishna': 2499,
#  'M Kaif': 2507,
#  'DJ Muthuswami': 2510,
#  'AG Murtaza': 2511,
#  'SS Mundhe': 2513,
#  'A Mukund': 2515,
#  'WA Mota': 2520,
#  'RG More': 2522,
#  'Monu Kumar': 2525,
#  'Mohammed Siraj': 2534,
#  'Mohammed Shami': 2535,
#  'A Mithun': 2540,
#  'MD Mishra': 2544,
#  'Milind Kumar': 2546,
#  'S Midhun': 2548,
#  'AL Menaria': 2552,
#  'M Markande': 2557,
#  'M Vijay': 2563,
#  'M Manhas': 2568,
#  'Mandeep Singh': 2571,
#  'VS Malik': 2575,
#  'I Malhotra': 2577,
#  'MK Lomror': 2578,
#  'AP Majumdar': 2584,
#  'VVS Laxman': 2587,
#  'VY Mahesh': 2589,
#  'C Madan': 2595,
#  'S Ladda': 2596,
#  'R Ninan': 2600,
#  'A Nehra': 2603,
#  'P Negi': 2604,
#  'AM Nayar': 2608,
#  'T Natarajan': 2613,
#  'S Narwal': 2614,
#  'C Nanda': 2615,
#  'J Syed Mohammad': 2619,
#  'KK Nair': 2620,
#  'NS Naik': 2624,
#  'Swapnil Singh': 2627,
#  'P Suyal': 2628,
#  'KL Nagarkoti': 2632,
#  'Y Nagar': 2635,
#  'S Nadeem': 2636,
#  'AD Nath': 2637,
#  'Sunny Singh': 2638,
#  'B Sumanth': 2641,
#  'TL Suman': 2642,
#  'TP Sudhindra': 2646,
#  'TM Srivastava': 2651,
#  'SJ Srivastava': 2652,
#  'S Sriram': 2653,
#  'S Sreesanth': 2658,
#  'BB Sran': 2659,
#  'RS Sodhi': 2663,
#  'VRV Singh': 2670,
#  'RP Singh': 2677,
#  'RK Singh': 2679,
#  'NB Singh': 2681,
#  'CA Pujara': 2684,
#  'Y Prithvi Raj': 2687,
#  'P Simran Singh': 2690,
#  'V Pratap Singh': 2695,
#  'M Prasidh Krishna': 2696,
#  'P Prasanth': 2698,
#  'R Shukla': 2700,
#  'LR Shukla': 2701,
#  'Shubman Gill': 2702,
#  'DR Shorey': 2710,
#  'Shoaib Ahmed': 3814,
#  'Shivam Sharma': 2715,
#  'Shivam Mavi': 2716,
#  'RR Powar': 2722,
#  'PP Shaw': 2728,
#  'AG Paunikar': 2744,
#  'RG Sharma': 2818,
#  'MM Sharma': 2747,
#  'KV Sharma': 2749,
#  'I Sharma': 2753,
#  'DT Patil': 2756,
#  'YK Pathan': 2759,
#  'IK Pathan': 2760,
#  'AUK Pathan': 2761,
#  'V Shankar': 2781,
#  'PA Patel': 2783,
#  'Niraj Patel': 2784,
#  'SS Shaikh': 2788,
#  'HV Patel': 2790,
#  'PP Ojha': 2796,
#  'NV Ojha': 2797,
#  'AR Patel': 2801,
#  'PR Shah': 2803,
#  'Parvez Rasool': 2814,
#  'MB Parmar': 2821,
#  'V Sehwag': 2829,
#  'P Parameswaran': 2834,
#  'R Parag': 2838,
#  'PA Reddy': 2850,
#  'RR Pant': 2852,
#  'Pankaj Singh': 2853,
#  'KH Pandya': 2854,
#  'HH Pandya': 2855,
#  'R Sathish': 2860,
#  'P Ray Barman': 2863,
#  'AT Rayudu': 2864,
#  'M Rawat': 2868,
#  'MK Pandey': 2870,
#  'IC Pandey': 2871,
#  'PM Sarvesh Kumar': 2875,
#  'DB Ravi Teja': 2880,
#  'SS Sarkar': 2884,
#  'AS Raut': 2896,
#  'D Padikkal': 2905,
#  'P Awana': 2907,
#  'Rasikh Salam': 2913,
#  'PJ Sangwan': 2914,
#  'S Sandeep Warrier': 2917,
#  'Sandeep Sharma': 2920,
#  'SV Samson': 2926,
#  'BB Samantray': 2929,
#  'AM Salvi': 2933,
#  'S Rana': 2936,
#  'N Rana': 2938,
#  'D Salunkhe': 2941,
#  'NA Saini': 2944,
#  'N Saini': 2945,
#  'P Sahu': 2951,
#  'WP Saha': 2954,
#  'Sachin Baby': 2956,
#  'AS Rajpoot': 2962,
#  'RR Raje': 2965,
#  'SK Raina': 2969,
#  'KL Rahul': 2974,
#  'AM Rahane': 2975,
#  'S Tyagi': 2981,
#  'SK Trivedi': 2982,
#  'RA Tripathi': 2983,
#  'SS Tiwary': 2985,
#  'MK Tiwary': 2986,
#  'X Thalaivan Sargunam': 2991,
#  'SN Thakur': 2993,
#  'R Tewatia': 2997,
#  'SR Tendulkar': 2998,
#  'Tejas Baroka': 3000,
#  'AP Tare': 3002,
#  'PV Tambe': 3006,
#  'YV Takawale': 3007,
#  'RV Uthappa': 3009,
#  'K Upadhyay': 3011,
#  'A Uniyal': 3012,
#  'JD Unadkat': 3013,
#  'M Vohra': 3016,
#  'Vishnu Vinod': 3018,
#  'R Vinay Kumar': 3019,
#  'DP Vijaykumar': 3024,
#  'GH Vihari': 3028,
#  'S Vidyut': 3030,
#  'Y Venugopal Rao': 3032,
#  'CV Varun': 3039,
#  'PC Valthaty': 3041,
#  'Azhar Mahmood': 3049,
#  'Shahbaz Ahmed': 3184,
#  'Washington Sundar': 3239,
#  'AV Wankhade': 3241,
#  'SB Wagh': 3248,
#  'Yuvraj Singh': 3273,
#  'VS Yeligati': 3277,
#  'Yashpal Singh': 3279,
#  'DH Yagnik': 3281,
#  'UT Yadav': 3286,
#  'SA Yadav': 3291,
#  'J Yadav': 3295,
#  'AS Yadav': 3297,
#  'Kamran Akmal': 3553,
#  'Mohammad Hafeez': 3652,
#  'Mohammad Asif': 3668,
#  'Misbah-ul-Haq': 3689,
#  'Sohail Tanvir': 3792,
#  'Shoaib Malik': 3808,
#  'Shoaib Akhtar': 3813,
#  'Shahid Afridi': 3868,
#  'Salman Butt': 3905,
#  'Umar Gul': 4036,
#  'Younis Khan': 4098,
#  'TM Dilshan': 4153,
#  'A Dananjaya': 4273,
#  'CRD Fernando': 4354,
#  'DPMD Jayawardene': 4463,
#  'ST Jayasuriya': 4468,
#  'KMDN Kulasekara': 4513,
#  'CK Kapugedera': 4551,
#  'S Randiv': 4559,
#  'M Muralitharan': 4596,
#  'BMAJ Mendis': 4617,
#  'BAW Mendis': 4621,
#  'AD Mathews': 4624,
#  'SL Malinga': 4634,
#  'MF Maharoof': 4640,
#  'NLTC Perera': 4732,
#  'MDKJ Perera': 4741,
#  'LPC Silva': 4896,
#  'SMSM Senanayake': 4936,
#  'KC Sangakkara': 4946,
#  'T Thushara': 4976,
#  'I Udana': 4994,
#  'WPUJC Vaas': 5055,
#  'DJG Sammy': 5189,
#  'JC Buttler': 5203,
#  'RS Bopara': 5311,
#  'SW Billings': 5344,
#  'TK Curran': 5419,
#  'SM Curran': 5420,
#  'T Banton': 5445,
#  'JM Bairstow': 5482,
#  'PD Collingwood': 5546,
#  'ND Doshi': 5675,
#  'JL Denly': 5714,
#  'HF Gurney': 5898,
#  'A Flintoff': 6095,
#  'AD Hales': 6187,
#  'CJ Jordan': 6252,
#  'LE Plunkett': 6295,
#  'KP Pietersen': 6324,
#  'MM Patel': 6406,
#  'BA Stokes': 6482,
#  'JJ Roy': 6562,
#  'OA Shah': 6684,
#  'LJ Wright': 6935,
#  'MA Wood': 6959,
#  'CR Woakes': 6970,
#  'DJ Willey': 6999,
#  'SM Boland': 7220,
#  'DE Bollinger': 7221,
#  'AC Blizzard': 7222,
#  'SA Abbott': 7230,
#  'TR Birt': 7232,
#  'JP Behrendorff': 7244,
#  'BCJ Cutting': 7256,
#  'PJ Cummins': 7261,
#  'GJ Bailey': 7271,
#  'NM Coulter-Nile': 7283,
#  'MJ Clarke': 7305,
#  'DT Christian': 7309,
#  'LA Carseldine': 7319,
#  'AT Carey': 7321,
#  'BR Dunk': 7335,
#  'TH David': 7380,
#  'MEK Hussey': 7421,
#  'AJ Finch': 7422,
#  'CJ Ferguson': 7426,
#  'DJ Hussey': 7427,
#  'JP Faulkner': 7439,
#  'DP Hughes': 7442,
#  'JR Hopes': 7462,
#  'CJ Green': 7467,
#  'C Green': 7468,
#  'GB Hogg': 7479,
#  'BJ Hodge': 7484,
#  'BW Hilfenhaus': 7498,
#  'AC Gilchrist': 7504,
#  'MC Henriques': 7511,
#  'B Geeves': 7512,
#  'TM Head': 7518,
#  'JR Hazlewood': 7525,
#  'ML Hayden': 7529,
#  'JW Hastings': 7535,
#  'SM Harwood': 7537,
#  'RJ Harris': 7544,
#  'DJ Harris': 7547,
#  'PSP Handscomb': 7555,
#  'BJ Haddin': 7561,
#  'MG Johnson': 7608,
#  'GJ Maxwell': 7624,
#  'DR Martyn': 7642,
#  'SE Marsh': 7653,
#  'MR Marsh': 7654,
#  'M Klinger': 7666,
#  'CA Lynn': 7672,
#  'UT Khawaja': 7684,
#  'NJ Maddinson': 7689,
#  'SM Katich': 7713,
#  'DS Lehmann': 7723,
#  'CJ McKay': 7725,
#  'B Lee': 7727,
#  'GD McGrath': 7731,
#  'B Laughlin': 7738,
#  'AB McDonald': 7753,
#  'AA Noffke': 7763,
#  'MG Neser': 7773,
#  'DP Nannes': 7776,
#  'RT Ponting': 7792,
#  'LA Pomersbach': 7796,
#  'JR Philippe': 7814,
#  'JL Pattinson': 7823,
#  'TD Paine': 7839,
#  'A Symonds': 7844,
#  'BJ Rohrer': 7854,
#  'MP Stoinis': 7861,
#  'MA Starc': 7878,
#  'B Stanlake': 7880,
#  'NJ Rimmington': 7883,
#  'KW Richardson': 7889,
#  'RJ Quiney': 7894,
#  'SPD Smith': 7901,
#  'GC Smith': 8896,
#  'DR Smith': 7917,
#  'DJM Short': 7936,
#  'GS Sandhu': 7951,
#  'DR Sams': 7952,
#  'AJ Tye': 7959,
#  'DJ Thornely': 7980,
#  'SW Tait': 7989,
#  'AC Voges': 8012,
#  'CL White': 8022,
#  'SR Watson': 8034,
#  'DA Warner': 8038,
#  'SK Warne': 8039,
#  'MS Wade': 8049,
#  'MV Boucher': 8084,
#  'J Botha': 8091,
#  'HM Amla': 8127,
#  'F Behardien': 8149,
#  'YA Abdulla': 8174,
#  'KJ Abbott': 8175,
#  'D du Preez': 8255,
#  'F du Plessis': 8260,
#  'JP Duminy': 8272,
#  'AB de Villiers': 8304,
#  'M de Lange': 8307,
#  'Q de Kock': 8310,
#  'CJ Dala': 8327,
#  'HH Gibbs': 8404,
#  'BE Hendricks': 8441,
#  'T Henderson': 8442,
#  'CA Ingram': 8472,
#  'Imran Tahir': 8473,
#  'CH Morris': 8501,
#  'M Morkel': 8503,
#  'JA Morkel': 8504,
#  'DJ Jacobs': 8543,
#  'DA Miller': 8553,
#  'H Klaasen': 8595,
#  'JM Kemp': 8623,
#  'JH Kallis': 8637,
#  'R McLaren': 8683,
#  'RE Levi': 8695,
#  'CK Langeveldt': 8707,
#  'M Ntini': 8719,
#  'A Nortje': 8723,
#  'L Ngidi': 8738,
#  'A Nel': 8745,
#  'SM Pollock': 8782,
#  'RJ Peterson': 8806,
#  'WD Parnell': 8815,
#  'DW Steyn': 8845,
#  'RR Rossouw': 8852,
#  'K Rabada': 8933,
#  'T Shamsi': 8939,
#  'AC Thomas': 8991,
#  'J Theron': 8992,
#  'GC Viljoen': 9016,
#  'MN van Wyk': 9038,
#  'JJ van der Wath': 9056,
#  'D Wiese': 9085,
#  'JC Archer': 9111,
#  'DM Bravo': 9128,
#  'DJ Bravo': 9129,
#  'CR Brathwaite': 9132,
#  'AB Barath': 9156,
#  'S Badree': 9159,
#  'SS Cottrell': 9168,
#  'KK Cooper': 9173,
#  'S Chanderpaul': 9193,
#  'FH Edwards': 9219,
#  'CH Gayle': 9246,
#  'JO Holder': 9260,
#  'SO Hetmyer': 9269,
#  'AS Joseph': 9283,
#  'SP Narine': 9356,
#  'R Powell': 9363,
#  'N Pooran': 9369,
#  'KA Pollard': 9370,
#  'KMA Paul': 9383,
#  'SE Rutherford': 9393,
#  'AD Russell': 9394,
#  'KAJ Roach': 9398,
#  'R Rampaul': 9409,
#  'LMP Simmons': 9435,
#  'JPR Scantlebury-Searles': 9441,
#  'RR Sarwan': 9443,
#  'K Santokie': 9444,
#  'MN Samuels': 9446,
#  'Ankit Soni': 9447,
#  'J Suchith': 9448,
#  'SD Lad': 9449,
#  'S Kaushik': 9450,
#  'KM Asif': 9451,
#  'AS Roy': 9452,
#  'YBK Jaiswal': 9453,
#  'Abdul Samad': 9454,
#  'Kartik Tyagi': 9455,
#  'Lalit Yadav': 9456,
#  'Ravi Bishnoi': 9457,
#  'RA Shaikh': 9458,
#  'AN Ahmed': 9459,
#  'AA Kazi': 9460,
#  'T Mishra': 9461,
#  'AG Harriott': 9462,
#  'B Doggett': 9463,
#  'CP Simpson': 9464,
#  'D Morton': 9465,
#  'Dilbar Hussain': 9466,
#  'GA West': 9467,
#  'H Kerr': 9468,
#  'Haris Rauf': 9469,
#  'J Fraser-McGurk': 9470,
#  'CR Swan': 9471,
#  'JA Prestwidge': 9472,
#  'JP Wood': 9473,
#  'K White (sub)': 9474,
#  'L Bowe': 9475,
#  'LR Morris': 9476,
#  'M Perry': 9477,
#  'MJ Owen': 9478,
#  'NA McSweeney': 9479,
#  'NT Ellis': 9480,
#  'Noor Ahmad': 9481,
#  'O Davies': 9482,
#  'P Hatzoglou': 9483,
#  'RJG Lockyear': 9484,
#  'RR Ayre (sub)': 9485,
#  'SJ Coyte (2)': 9486,
#  'T Sangha': 9487,
#  'XC Bartlett': 9488,
#  'K White': 9489,
#  'RR Ayre': 9490}

# %% [markdown]
# ## Utility code to catch exceptions and add those entries to the player database.
# ### 1) Run this cell
# ### 2) copy all the print statements and add it to the updates cell and run it.
# ### 3) Finally run the above cell to update player maps.
# ### This is to be done so that ingestion of matches and balls takes place smoothly without any exceptions

# %%
print_statements = set()
country_id = 4 # set this to the host nation for maximum correct values

for match in matches:
        
    if match["info"]["toss"]["decision"] == "field":
        team_name_batting_second = match["info"]["toss"]["winner"]
        if team_name_batting_second == match["info"]["teams"][0]:
            team_name_batting_first = match["info"]["teams"][1]
        elif team_name_batting_second == match["info"]["teams"][1]:
            team_name_batting_first = match["info"]["teams"][0]
    elif match["info"]["toss"]["decision"] == "bat":
        team_name_batting_first = match["info"]["toss"]["winner"]
        if team_name_batting_first == match["info"]["teams"][0]:
            team_name_batting_second = match["info"]["teams"][1]
        elif team_name_batting_first == match["info"]["teams"][1]:
            team_name_batting_second = match["info"]["teams"][0]
    
    for inning in match['innings']:
        for inning_number in inning:
            for ball in inning[inning_number]['deliveries']:
                for ball_number in ball:
                    
                    try:
                        batsman = player_id_map[ball[ball_number]['batsman']]
                    except Exception as e:
                        if int(inning_number[0]) % 2 == 1:
                            player_nf = ball[ball_number]['batsman']
                            print_statement = f'add_player("{player_nf}", "{player_nf}", "{player_nf}", "", "", "", "{country_id}", "{str(team_id_map[team_name_batting_first])}")'
                            print_statements.add(print_statement)
                        else:
                            player_nf = ball[ball_number]['batsman']
                            print_statement = f'add_player("{player_nf}", "{player_nf}", "{player_nf}", "", "", "", "{country_id}", "{str(team_id_map[team_name_batting_second])}")'
                            print_statements.add(print_statement)
                    
                    try:
                        bowler = player_id_map[ball[ball_number]['bowler']]
                    except Exception as e:
                        if int(inning_number[0]) % 2 == 1:
                            player_nf = ball[ball_number]['bowler']
                            print_statement = f'add_player("{player_nf}", "{player_nf}", "{player_nf}", "", "", "", "{country_id}", "{str(team_id_map[team_name_batting_second])}")'
                            print_statements.add(print_statement)
                        else:
                            player_nf = ball[ball_number]['bowler']
                            print_statement = f'add_player("{player_nf}", "{player_nf}", "{player_nf}", "", "", "", "{country_id}", "{str(team_id_map[team_name_batting_first])}")'
                            print_statements.add(print_statement)
                            
                    try:
                        non_striker = player_id_map[ball[ball_number]['non_striker']]
                    except Exception as e:
                        if int(inning_number[0]) % 2 == 1:
                            player_nf = ball[ball_number]['non_striker']
                            print_statement = f'add_player("{player_nf}", "{player_nf}", "{player_nf}", "", "", "", "{country_id}", "{str(team_id_map[team_name_batting_first])}")'
                            print_statements.add(print_statement)
                        else:
                            player_nf = ball[ball_number]['non_striker']
                            print_statement = f'add_player("{player_nf}", "{player_nf}", "{player_nf}", "", "", "", "{country_id}", "{str(team_id_map[team_name_batting_second])}")'
                            print_statements.add(print_statement)
                    

                    if "wicket" in ball[ball_number]:
                        try:
                            player_dismissed = player_id_map[ball[ball_number]["wicket"]["player_out"]]
                            dismissal_type = ball[ball_number]["wicket"]["kind"]
                        except Exception as e:
                            pass

                        if "fielders" in ball[ball_number]["wicket"]:
                            
                            try:
                                # There is "(sub)" when a substitute fielder is involved in a wicket
                                fielders = ",".join([str(player_id_map[fielder.replace(" (sub)", "")]) for fielder in ball[ball_number]["wicket"]["fielders"]])
                            except Exception as e:
                                if int(inning_number[0]) % 2 == 1:
                                    player_nf = ball[ball_number]['wicket']['fielders'][0].replace(" (sub)", "")
                                    print_statement = f'add_player("{player_nf}", "{player_nf}", "{player_nf}", "", "", "", "{country_id}", "{str(team_id_map[team_name_batting_second])}")'
                                    print_statements.add(print_statement)
                                else:
                                    player_nf = ball[ball_number]['wicket']['fielders'][0].replace(" (sub)", "")
                                    print_statement = f'add_player("{player_nf}", "{player_nf}", "{player_nf}", "", "", "", "{country_id}", "{str(team_id_map[team_name_batting_first])}")'
                                    print_statements.add(print_statement)
for stmt in sorted(list(print_statements)):
    print(stmt)

# %% [markdown]
# ## Match and Ball table

# %%
match_columns = ["match_id", "tournament_id", "venue_id", "match_date", "team_1", "team_2", "toss_winner", "toss_decision", "player_of_match", 
                 "match_winner", "match_win_by_runs", "match_win_by_wickets", "highlights_url", "match_url", "match_description"]
#match_csv = pd.DataFrame(columns = match_columns)

ball_columns = ["ball_id", "match_id", "ball_number", "innings_number", "batsman", "bowler", "non_striker", "batsman_runs", "wide_runs", "noball_runs",
                "bye_runs", "legbye_runs", "extras_runs", "total_runs", "player_dismissed", "dismissal_type", "fielders", "ball_description", "ball_url"]
#ball_csv = pd.DataFrame(columns = ball_columns)

if os.path.exists("./clean_data/match.csv"):
    old_match_csv = pd.read_csv("./clean_data/match.csv")
    i = len(old_match_csv)
else:
    i=0
    
if os.path.exists("./clean_data/ball.csv"):
    old_ball_csv = pd.read_csv("./clean_data/ball.csv")
    j = len(old_ball_csv)
else:
    j=0
    
match_csv = {}
ball_csv = {}

for match in tqdm((matches), position=0, leave=True):
    
    # First adding entries to the match table
    try:
        
        match_id = i
        if match['info']['competition'] in tournament_id_map:
            tournament_id = tournament_id_map[match['info']['competition']] # For ODI and TEST "competition" to be changed to "match_Type"
        elif match['info']['competition'] in tournament_fullname_id_map:
            tournament_id = tournament_fullname_id_map[match['info']['competition']]
            
        venue_id = venue_id_map[match['info']['venue']]
        
        # if date is a date instance, parse and read. if not directly read
        match_date = [",".join([str(date.strftime('%Y-%m-%d')) if isinstance(date, datetime.date) else str(date) for date in match['info']['dates']])]

        team_1_best_fuzzy_match = process.extractOne(match['info']['teams'][0], team_id_map.keys())[0]
        team_2_best_fuzzy_match = process.extractOne(match['info']['teams'][1], team_id_map.keys())[0]
        team_1 = team_id_map[team_1_best_fuzzy_match]
        team_2 = team_id_map[team_2_best_fuzzy_match]

        toss_winner_best_fuzzy_match = process.extractOne(match['info']['toss']['winner'], team_id_map.keys())[0]
        toss_winner = team_id_map[toss_winner_best_fuzzy_match]
        toss_decision = match['info']['toss']['decision']
        
        # Match was canceled/washed out
        if "result" in match['info']['outcome'] and match['info']['outcome']['result'] == "no result":
            match_winner = "NA"
            match_win_by_wickets = "NA"
            match_win_by_runs = "NA"
            player_of_match = "NA"
            
        # Match was tied
        elif "result" in match['info']['outcome'] and match['info']['outcome']['result'] == "tie":
            match_winner = "TIE"
            match_win_by_wickets = "NA"
            match_win_by_runs = "NA"
            player_of_match = ",".join([str(player_id_map[player]) for player in match['info']['player_of_match']])

        elif "runs" in match['info']['outcome']['by']:
            match_win_by_runs = match['info']['outcome']['by']['runs']
            match_win_by_wickets = 'NA'
            match_winner_best_fuzzy_match = process.extractOne(match['info']['outcome']['winner'], team_id_map.keys())[0]
            match_winner = team_id_map[match_winner_best_fuzzy_match]
            player_of_match = ",".join([str(player_id_map[player]) for player in match['info']['player_of_match']])

        elif "wickets" in match['info']['outcome']['by']:
            match_win_by_wickets = match['info']['outcome']['by']['wickets']
            match_win_by_runs = 'NA'
            match_winner_best_fuzzy_match = process.extractOne(match['info']['outcome']['winner'], team_id_map.keys())[0]
            match_winner = team_id_map[match_winner_best_fuzzy_match]
            player_of_match = ",".join([str(player_id_map[player]) for player in match['info']['player_of_match']])
        
        # For ambitious future deep learning projects
        highlights_url = 'NA'
        match_url = 'NA'
        match_description = 'NA'
        
        match_csv[i] = {
                        "match_id" : match_id, 
                        "tournament_id" : tournament_id,
                        "venue_id" : venue_id,
                        "match_date" : match_date, 
                        "team_1" : team_1,
                        "team_2" : team_2,
                        "toss_winner" : toss_winner,
                        "toss_decision" : toss_decision,
                        "player_of_match" : player_of_match,
                        "match_winner" : match_winner,
                        "match_win_by_runs" : match_win_by_runs,
                        "match_win_by_wickets" : match_win_by_wickets,
                        "highlights_url" : highlights_url,
                        "match_url" : match_url,
                        "match_description" : match_description
        }
    
    except Exception as e:
        
        print("Exception happened in match: ", e)
        print(match['info'])
        
        break
    
    
    # Then adding entries to the ball table
    
    try:
        for inning in match['innings']:
            for inning_number in inning:
                for ball in inning[inning_number]['deliveries']:
                    for ball_number in ball:
                        ball_id = j
                        innings_number = inning_number[0]
                        batsman = player_id_map[ball[ball_number]['batsman']]
                        bowler = player_id_map[ball[ball_number]['bowler']]
                        non_striker = player_id_map[ball[ball_number]['non_striker']]
                        
                        wide_runs = 0
                        bye_runs = 0
                        noball_runs = 0
                        legbye_runs = 0
                        batsman_runs = 0
                        extras_runs = 0
                        total_runs = 0
                        
                        player_dismissed = "NA"
                        dismissal_type = "NA"
                        fielders = "NA"
                        
                        if "extras" in ball[ball_number]:
                            if "wides" in ball[ball_number]["extras"]:
                                wide_runs = ball[ball_number]["extras"]["wides"]
                            if "legbyes" in ball[ball_number]["extras"]:
                                legbye_runs = ball[ball_number]["extras"]["legbyes"]
                            if "noballs" in ball[ball_number]["extras"]:
                                noball_runs = ball[ball_number]["extras"]["noballs"]
                            if "byes" in ball[ball_number]["extras"]:
                                bye_runs = ball[ball_number]["extras"]["byes"]
                        
                        if "runs" in ball[ball_number]:
                            batsman_runs = ball[ball_number]["runs"]["batsman"]
                            extras_runs = ball[ball_number]["runs"]["extras"]
                            total_runs = ball[ball_number]["runs"]["total"]
                            
                        if "wicket" in ball[ball_number]:
                            player_dismissed = player_id_map[ball[ball_number]["wicket"]["player_out"]]
                            dismissal_type = ball[ball_number]["wicket"]["kind"]
                            
                            if "fielders" in ball[ball_number]["wicket"]:
                                # There is "(sub)" when a substitute fielder is involved in a wicket
                                fielders = ",".join([str(player_id_map[fielder.replace(" (sub)", "")]) for fielder in ball[ball_number]["wicket"]["fielders"]])
                        
                        # For ambitious future deep learning projects
                        ball_description = "NA"
                        ball_url = "NA"
                        
                        ball_csv[j] = {
                                        "ball_id" : j, 
                                        "match_id" : match_id,
                                        "ball_number" : ball_number,
                                        "innings_number" : innings_number, 
                                        "batsman" : batsman,
                                        "bowler" : bowler,
                                        "non_striker" : non_striker,
                                        "batsman_runs" : batsman_runs,
                                        "wide_runs" : wide_runs,
                                        "bye_runs" : bye_runs,
                                        "noball_runs" : noball_runs,
                                        "legbye_runs" : legbye_runs,
                                        "extras_runs" : extras_runs,
                                        "total_runs" : total_runs,
                                        "player_dismissed" : player_dismissed,
                                        "dismissal_type" : dismissal_type,
                                        "fielders" : fielders,
                                        "ball_description" : ball_description,
                                        "ball_url" : ball_url,
                        }
                        
                        j += 1
    
    except Exception as e:
        print(f"Exception {e} happened in ball number {ball_number} ")
        print(f"ball {ball[ball_number]}")
        print(f"match info: {match['info']}")
        break
        
    i += 1
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 816/816 [01:39<00:00,  8.18it/s]

# %%
df_match_csv = pd.DataFrame.from_dict(match_csv, "index")
df_ball_csv = pd.DataFrame.from_dict(ball_csv, "index")

if os.path.exists(os.path.join(clean_data_path, "match.csv")):
    old_match_csv = pd.read_csv(os.path.join(clean_data_path, "match.csv"))
    df_match_csv = old_match_csv.append(df_match_csv)
    
if os.path.exists(os.path.join(clean_data_path, "ball.csv")):
    old_ball_csv = pd.read_csv(os.path.join(clean_data_path, "ball.csv"))
    df_ball_csv = old_ball_csv.append(df_ball_csv)


df_match_csv.to_csv(os.path.join(clean_data_path, "match.csv"), index=False)
df_ball_csv.to_csv(os.path.join(clean_data_path, "ball.csv"), index=False)
