# %%
import numpy as np
import os
import pandas as pd
from tqdm import tqdm
import copy
import pickle

# %%
# Config variables
clean_data_path = os.path.join("..", "clean_data")

# %%
df_player = pd.read_csv(os.path.join(clean_data_path, "player.csv"))
df_player = df_player.loc[:, ~df_player.columns.str.contains('^Unnamed')]

# %%
df_team = pd.read_csv(os.path.join(clean_data_path, "team.csv"))
df_team = df_team.loc[:, ~df_team.columns.str.contains('^Unnamed')]
team_id_map = dict(zip(df_team.team_name, df_team.team_id))

team_id_map["Delhi Capitals"] = team_id_map["Delhi Daredevils"]
team_id_map["Punjab Kings"] = team_id_map["Kings XI Punjab"]

# %%
df_match = pd.read_csv(os.path.join(clean_data_path, "match.csv"))
df_match = df_match.loc[:, ~df_match.columns.str.contains('^Unnamed')]
teams_id=set(df_match["team_1"])
teams_names=df_team.loc[df_team.team_id.isin(teams_id)]

# %%
years=['2010']
required_matches = df_match[df_match['match_date'].str.contains('|'.join(years))]
len(required_matches)
# Out:
# 60

# %%
df_ball = pd.read_csv(os.path.join(clean_data_path, "ball.csv"))
df_ball = df_ball.loc[:, ~df_ball.columns.str.contains('^Unnamed')]

# %%
empty_match_object={
    "batting_insights":{"runs_scored" : {"Powerplay" : 0, "Middle_overs" : 0, "Death" : 0, "Total" : 0},
    "wickets" : {"Powerplay" : 0, "Middle_overs" : 0, "Death" : 0, "Total" : 0},
    "num_4s" : {"Powerplay" : 0, "Middle_overs" : 0, "Death" : 0, "Total" : 0},
    "num_6s" : {"Powerplay" : 0, "Middle_overs" : 0, "Death" : 0, "Total" : 0},
    "dot_balls" : {"Powerplay" : 0, "Middle_overs" : 0, "Death" : 0, "Total" : 0}},
    "bowling_insights":{"runs_conceded" : {"Powerplay" : 0, "Middle_overs" : 0, "Death" : 0, "Total" : 0},
    "wickets_taken" : {"Powerplay" : 0, "Middle_overs" : 0, "Death" : 0, "Total" : 0},
    "num_4s_conceded" : {"Powerplay" : 0, "Middle_overs" : 0, "Death" : 0, "Total" : 0},
    "num_6s_conceded" : {"Powerplay" : 0, "Middle_overs" : 0, "Death" : 0, "Total" : 0},
    "dot_balls_bowled" : {"Powerplay" : 0, "Middle_overs" : 0, "Death" : 0, "Total" : 0}},
    "innings":1,
    "match_winner":0,
    "venue":0,
    "opposition": 0,
    "match_date":''
    }

# %%
match_insight_obj={}

# %%
ball_temp=df_ball

for i,row in tqdm(ball_temp.iterrows()):
    match_id = int(row["match_id"])
    innings_number = int(row["innings_number"])
    required_match=df_match.loc[df_match["match_id"] == match_id]
    if innings_number==1:
        batting_team=required_match["batting_team"].iloc[0]
        bowling_team=required_match["chasing_team"].iloc[0]
    else:
        batting_team=required_match["chasing_team"].iloc[0]
        bowling_team=required_match["batting_team"].iloc[0]
    
    try:
        match_insight_obj[batting_team]
    except Exception as e:
        match_insight_obj[batting_team] = {}
    
    try:
        match_insight_obj[bowling_team]
    except Exception as e:
        match_insight_obj[bowling_team] = {}
        
    try: 
        match_insight_obj[batting_team][match_id]
    except Exception as e:
        match_insight_obj[batting_team][match_id] = copy.deepcopy(empty_match_object)    
    
    try: 
        match_insight_obj[bowling_team][match_id]
    except Exception as e:
        match_insight_obj[bowling_team][match_id] = copy.deepcopy(empty_match_object)   
    
    
    #runs scored
    total_runs=row["total_runs"]
    if row["ball_number"]<6.0:
        match_insight_obj[batting_team][match_id]["batting_insights"]["runs_scored"]["Powerplay"]+=total_runs
        match_insight_obj[bowling_team][match_id]["bowling_insights"]["runs_conceded"]["Powerplay"]+=total_runs
    elif (row["ball_number"]>6.0) and (row["ball_number"]<15.0):
        match_insight_obj[batting_team][match_id]["batting_insights"]["runs_scored"]["Middle_overs"]+=total_runs
        match_insight_obj[bowling_team][match_id]["bowling_insights"]["runs_conceded"]["Middle_overs"]+=total_runs
    else:
        match_insight_obj[batting_team][match_id]["batting_insights"]["runs_scored"]["Death"]+=total_runs
        match_insight_obj[bowling_team][match_id]["bowling_insights"]["runs_conceded"]["Death"]+=total_runs
    match_insight_obj[batting_team][match_id]["batting_insights"]["runs_scored"]["Total"] = match_insight_obj[batting_team][match_id]["batting_insights"]["runs_scored"]["Death"] + match_insight_obj[batting_team][match_id]["batting_insights"]["runs_scored"]["Middle_overs"] + match_insight_obj[batting_team][match_id]["batting_insights"]["runs_scored"]["Powerplay"]    
    match_insight_obj[bowling_team][match_id]["bowling_insights"]["runs_conceded"]["Total"] = match_insight_obj[bowling_team][match_id]["bowling_insights"]["runs_conceded"]["Death"] + match_insight_obj[bowling_team][match_id]["bowling_insights"]["runs_conceded"]["Middle_overs"] + match_insight_obj[bowling_team][match_id]["bowling_insights"]["runs_conceded"]["Powerplay"]
    
    #wickets    
    if not np.isnan(row["player_dismissed"]):
        if row["ball_number"]<6.0:
            match_insight_obj[batting_team][match_id]["batting_insights"]["wickets"]["Powerplay"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["wickets_taken"]["Powerplay"]+=1
        elif (row["ball_number"]>6.0) and (row["ball_number"]<15.0):
            match_insight_obj[batting_team][match_id]["batting_insights"]["wickets"]["Middle_overs"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["wickets_taken"]["Middle_overs"]+=1
        else:
            match_insight_obj[batting_team][match_id]["batting_insights"]["wickets"]["Death"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["wickets_taken"]["Death"]+=1
    match_insight_obj[batting_team][match_id]["batting_insights"]["wickets"]["Total"] = match_insight_obj[batting_team][match_id]["batting_insights"]["wickets"]["Death"] + match_insight_obj[batting_team][match_id]["batting_insights"]["wickets"]["Middle_overs"] + match_insight_obj[batting_team][match_id]["batting_insights"]["wickets"]["Powerplay"]    
    match_insight_obj[bowling_team][match_id]["bowling_insights"]["wickets_taken"]["Total"] = match_insight_obj[bowling_team][match_id]["bowling_insights"]["wickets_taken"]["Death"] + match_insight_obj[bowling_team][match_id]["bowling_insights"]["wickets_taken"]["Middle_overs"] + match_insight_obj[bowling_team][match_id]["bowling_insights"]["wickets_taken"]["Powerplay"]
    
    #number of 4's for team (i.e including 4legbyes)
    if row["total_runs"]==4:
        if row["ball_number"]<6.0:
            match_insight_obj[batting_team][match_id]["batting_insights"]["num_4s"]["Powerplay"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_4s_conceded"]["Powerplay"]+=1
        elif (row["ball_number"]>6.0) and (row["ball_number"]<15.0):
            match_insight_obj[batting_team][match_id]["batting_insights"]["num_4s"]["Middle_overs"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_4s_conceded"]["Middle_overs"]+=1
        else:
            match_insight_obj[batting_team][match_id]["batting_insights"]["num_4s"]["Death"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_4s_conceded"]["Death"]+=1
    match_insight_obj[batting_team][match_id]["batting_insights"]["num_4s"]["Total"] = match_insight_obj[batting_team][match_id]["batting_insights"]["num_4s"]["Death"] + match_insight_obj[batting_team][match_id]["batting_insights"]["num_4s"]["Middle_overs"] + match_insight_obj[batting_team][match_id]["batting_insights"]["num_4s"]["Powerplay"]    
    match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_4s_conceded"]["Total"] = match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_4s_conceded"]["Powerplay"] + match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_4s_conceded"]["Middle_overs"] + match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_4s_conceded"]["Death"]
    
    #number of 6s   
    if row["total_runs"]==6:
        if row["ball_number"]<6.0:
            match_insight_obj[batting_team][match_id]["batting_insights"]["num_6s"]["Powerplay"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_6s_conceded"]["Powerplay"]+=1
        elif (row["ball_number"]>6.0) and (row["ball_number"]<15.0):
            match_insight_obj[batting_team][match_id]["batting_insights"]["num_6s"]["Middle_overs"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_6s_conceded"]["Middle_overs"]+=1
        else:
            match_insight_obj[batting_team][match_id]["batting_insights"]["num_6s"]["Death"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_6s_conceded"]["Death"]+=1
    match_insight_obj[batting_team][match_id]["batting_insights"]["num_6s"]["Total"] = match_insight_obj[batting_team][match_id]["batting_insights"]["num_6s"]["Death"] + match_insight_obj[batting_team][match_id]["batting_insights"]["num_6s"]["Middle_overs"] + match_insight_obj[batting_team][match_id]["batting_insights"]["num_6s"]["Powerplay"]    
    match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_6s_conceded"]["Total"] = match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_6s_conceded"]["Powerplay"] + match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_6s_conceded"]["Middle_overs"] + match_insight_obj[bowling_team][match_id]["bowling_insights"]["num_6s_conceded"]["Death"]    
    
    #number of dot balls of legal deliveries
    if row["total_runs"]==0:
        if row["ball_number"]<6.0:
            match_insight_obj[batting_team][match_id]["batting_insights"]["dot_balls"]["Powerplay"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["dot_balls_bowled"]["Powerplay"]+=1
        elif (row["ball_number"]>6.0) and (row["ball_number"]<15.0):
            match_insight_obj[batting_team][match_id]["batting_insights"]["dot_balls"]["Middle_overs"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["dot_balls_bowled"]["Middle_overs"]+=1
        else:
            match_insight_obj[batting_team][match_id]["batting_insights"]["dot_balls"]["Death"]+=1
            match_insight_obj[bowling_team][match_id]["bowling_insights"]["dot_balls_bowled"]["Death"]+=1
    match_insight_obj[batting_team][match_id]["batting_insights"]["dot_balls"]["Total"] = match_insight_obj[batting_team][match_id]["batting_insights"]["dot_balls"]["Death"] + match_insight_obj[batting_team][match_id]["batting_insights"]["dot_balls"]["Middle_overs"] + match_insight_obj[batting_team][match_id]["batting_insights"]["dot_balls"]["Powerplay"]
    match_insight_obj[bowling_team][match_id]["bowling_insights"]["dot_balls_bowled"]["Total"] = match_insight_obj[bowling_team][match_id]["bowling_insights"]["dot_balls_bowled"]["Death"] + match_insight_obj[bowling_team][match_id]["bowling_insights"]["dot_balls_bowled"]["Middle_overs"] + match_insight_obj[bowling_team][match_id]["bowling_insights"]["dot_balls_bowled"]["Powerplay"]
    
    match_insight_obj[batting_team][match_id]["innings"]=innings_number
    try:
        match_insight_obj[batting_team][match_id]["match_winner"]=int(required_match["match_winner"].iloc[0])
    except Exception as e:
        match_insight_obj[batting_team][match_id]["match_winner"]=-1   
    match_insight_obj[batting_team][match_id]["venue"]=required_match["venue_id"].iloc[0]
    match_insight_obj[batting_team][match_id]["match_date"]=required_match["match_date"].iloc[0]
    match_insight_obj[batting_team][match_id]["opposition"]=bowling_team
# Out:
# 193468it [02:08, 1511.47it/s]

# %%
match_insight_obj
# Out:
# {72: {0: {'batting_insights': {'runs_scored': {'Powerplay': 59,
#      'Middle_overs': 92,
#      'Death': 56,
#      'Total': 207},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 1, 'Death': 2, 'Total': 4},
#     'num_4s': {'Powerplay': 8, 'Middle_overs': 6, 'Death': 3, 'Total': 17},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 4, 'Death': 4, 'Total': 9},
#     'dot_balls': {'Powerplay': 12,
#      'Middle_overs': 7,
#      'Death': 7,
#      'Total': 26}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 54,
#      'Middle_overs': 85,
#      'Death': 33,
#      'Total': 172},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 4,
#      'Death': 5,
#      'Total': 10},
#     'num_4s_conceded': {'Powerplay': 7,
#      'Middle_overs': 7,
#      'Death': 1,
#      'Total': 15},
#     'num_6s_conceded': {'Powerplay': 2,
#      'Middle_overs': 3,
#      'Death': 3,
#      'Total': 8},
#     'dot_balls_bowled': {'Powerplay': 18,
#      'Middle_overs': 12,
#      'Death': 14,
#      'Total': 44}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 182,
#    'match_date': "['2017-04-05']"},
#   5: {'batting_insights': {'runs_scored': {'Powerplay': 59,
#      'Middle_overs': 72,
#      'Death': 9,
#      'Total': 140},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 0, 'Death': 0, 'Total': 1},
#     'num_4s': {'Powerplay': 6, 'Middle_overs': 6, 'Death': 0, 'Total': 12},
#     'num_6s': {'Powerplay': 3, 'Middle_overs': 1, 'Death': 1, 'Total': 5},
#     'dot_balls': {'Powerplay': 14,
#      'Middle_overs': 13,
#      'Death': 0,
#      'Total': 27}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 40,
#      'Middle_overs': 62,
#      'Death': 33,
#      'Total': 135},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 2,
#      'Death': 3,
#      'Total': 7},
#     'num_4s_conceded': {'Powerplay': 5,
#      'Middle_overs': 5,
#      'Death': 1,
#      'Total': 11},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 1,
#      'Death': 1,
#      'Total': 2},
#     'dot_balls_bowled': {'Powerplay': 14,
#      'Middle_overs': 15,
#      'Death': 7,
#      'Total': 36}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 526,
#    'match_date': "['2017-04-09']"},
#   9: {'batting_insights': {'runs_scored': {'Powerplay': 34,
#      'Middle_overs': 84,
#      'Death': 40,
#      'Total': 158},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 3, 'Death': 5, 'Total': 8},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 9, 'Death': 4, 'Total': 18},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 3, 'Death': 0, 'Total': 3},
#     'dot_balls': {'Powerplay': 19,
#      'Middle_overs': 18,
#      'Death': 8,
#      'Total': 45}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 61,
#      'Middle_overs': 60,
#      'Death': 38,
#      'Total': 159},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 2,
#      'Death': 2,
#      'Total': 6},
#     'num_4s_conceded': {'Powerplay': 10,
#      'Middle_overs': 2,
#      'Death': 4,
#      'Total': 16},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 3,
#      'Death': 2,
#      'Total': 6},
#     'dot_balls_bowled': {'Powerplay': 14,
#      'Middle_overs': 18,
#      'Death': 7,
#      'Total': 39}},
#    'innings': 1,
#    'match_winner': 90,
#    'venue': 11,
#    'opposition': 90,
#    'match_date': "['2017-04-12']"},
#   13: {'batting_insights': {'runs_scored': {'Powerplay': 45,
#      'Middle_overs': 68,
#      'Death': 42,
#      'Total': 155},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 5, 'Death': 1, 'Total': 6},
#     'num_4s': {'Powerplay': 8, 'Middle_overs': 6, 'Death': 2, 'Total': 16},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 3, 'Death': 2, 'Total': 5},
#     'dot_balls': {'Powerplay': 17,
#      'Middle_overs': 22,
#      'Death': 9,
#      'Total': 48}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 40,
#      'Middle_overs': 84,
#      'Death': 48,
#      'Total': 172},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 1,
#      'Death': 3,
#      'Total': 6},
#     'num_4s_conceded': {'Powerplay': 4,
#      'Middle_overs': 6,
#      'Death': 3,
#      'Total': 13},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 3,
#      'Death': 3,
#      'Total': 7},
#     'dot_balls_bowled': {'Powerplay': 17,
#      'Middle_overs': 11,
#      'Death': 12,
#      'Total': 40}},
#    'innings': 2,
#    'match_winner': 150,
#    'venue': 5,
#    'opposition': 150,
#    'match_date': "['2017-04-15']"},
#   18: {'batting_insights': {'runs_scored': {'Powerplay': 29,
#      'Middle_overs': 79,
#      'Death': 51,
#      'Total': 159},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 3, 'Total': 6},
#     'num_4s': {'Powerplay': 1, 'Middle_overs': 6, 'Death': 4, 'Total': 11},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 2, 'Total': 4},
#     'dot_balls': {'Powerplay': 16,
#      'Middle_overs': 15,
#      'Death': 7,
#      'Total': 38}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 51,
#      'Middle_overs': 53,
#      'Death': 50,
#      'Total': 154},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 4,
#      'Death': 4,
#      'Total': 10},
#     'num_4s_conceded': {'Powerplay': 5,
#      'Middle_overs': 3,
#      'Death': 3,
#      'Total': 11},
#     'num_6s_conceded': {'Powerplay': 2,
#      'Middle_overs': 2,
#      'Death': 3,
#      'Total': 7},
#     'dot_balls_bowled': {'Powerplay': 16,
#      'Middle_overs': 26,
#      'Death': 10,
#      'Total': 52}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 164,
#    'match_date': "['2017-04-17']"},
#   20: {'batting_insights': {'runs_scored': {'Powerplay': 39,
#      'Middle_overs': 96,
#      'Death': 56,
#      'Total': 191},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 0, 'Death': 3, 'Total': 4},
#     'num_4s': {'Powerplay': 4, 'Middle_overs': 5, 'Death': 6, 'Total': 15},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 5, 'Death': 2, 'Total': 7},
#     'dot_balls': {'Powerplay': 13,
#      'Middle_overs': 7,
#      'Death': 4,
#      'Total': 24}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 56,
#      'Middle_overs': 71,
#      'Death': 49,
#      'Total': 176},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 3,
#      'Death': 1,
#      'Total': 5},
#     'num_4s_conceded': {'Powerplay': 9,
#      'Middle_overs': 4,
#      'Death': 5,
#      'Total': 18},
#     'num_6s_conceded': {'Powerplay': 2,
#      'Middle_overs': 3,
#      'Death': 1,
#      'Total': 6},
#     'dot_balls_bowled': {'Powerplay': 17,
#      'Middle_overs': 13,
#      'Death': 5,
#      'Total': 35}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 330,
#    'match_date': "['2017-04-19']"},
#   24: {'batting_insights': {'runs_scored': {'Powerplay': 45,
#      'Middle_overs': 68,
#      'Death': 63,
#      'Total': 176},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 1, 'Total': 3},
#     'num_4s': {'Powerplay': 6, 'Middle_overs': 4, 'Death': 7, 'Total': 17},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 1, 'Death': 3, 'Total': 4},
#     'dot_balls': {'Powerplay': 12,
#      'Middle_overs': 18,
#      'Death': 4,
#      'Total': 34}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 55,
#      'Middle_overs': 60,
#      'Death': 64,
#      'Total': 179},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 4},
#     'num_4s_conceded': {'Powerplay': 6,
#      'Middle_overs': 3,
#      'Death': 7,
#      'Total': 16},
#     'num_6s_conceded': {'Powerplay': 3,
#      'Middle_overs': 3,
#      'Death': 2,
#      'Total': 8},
#     'dot_balls_bowled': {'Powerplay': 16,
#      'Middle_overs': 18,
#      'Death': 2,
#      'Total': 36}},
#    'innings': 1,
#    'match_winner': 550,
#    'venue': 24,
#    'opposition': 550,
#    'match_date': "['2017-04-22']"},
#   31: {'batting_insights': {'runs_scored': {'Powerplay': 60,
#      'Middle_overs': 95,
#      'Death': 52,
#      'Total': 207},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 1, 'Total': 3},
#     'num_4s': {'Powerplay': 6, 'Middle_overs': 8, 'Death': 5, 'Total': 19},
#     'num_6s': {'Powerplay': 3, 'Middle_overs': 3, 'Death': 1, 'Total': 7},
#     'dot_balls': {'Powerplay': 12,
#      'Middle_overs': 6,
#      'Death': 5,
#      'Total': 23}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 59,
#      'Middle_overs': 79,
#      'Death': 43,
#      'Total': 181},
#     'wickets_taken': {'Powerplay': 3,
#      'Middle_overs': 2,
#      'Death': 4,
#      'Total': 9},
#     'num_4s_conceded': {'Powerplay': 9,
#      'Middle_overs': 10,
#      'Death': 6,
#      'Total': 25},
#     'num_6s_conceded': {'Powerplay': 2,
#      'Middle_overs': 2,
#      'Death': 0,
#      'Total': 4},
#     'dot_balls_bowled': {'Powerplay': 15,
#      'Middle_overs': 16,
#      'Death': 7,
#      'Total': 38}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 17,
#    'opposition': 164,
#    'match_date': "['2017-04-28']"},
#   35: {'batting_insights': {'runs_scored': {'Powerplay': 79,
#      'Middle_overs': 75,
#      'Death': 55,
#      'Total': 209},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 1, 'Death': 2, 'Total': 3},
#     'num_4s': {'Powerplay': 7, 'Middle_overs': 3, 'Death': 7, 'Total': 17},
#     'num_6s': {'Powerplay': 5, 'Middle_overs': 4, 'Death': 0, 'Total': 9},
#     'dot_balls': {'Powerplay': 13,
#      'Middle_overs': 15,
#      'Death': 4,
#      'Total': 32}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 44,
#      'Middle_overs': 78,
#      'Death': 39,
#      'Total': 161},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 2,
#      'Death': 3,
#      'Total': 7},
#     'num_4s_conceded': {'Powerplay': 8,
#      'Middle_overs': 2,
#      'Death': 2,
#      'Total': 12},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 4,
#      'Death': 1,
#      'Total': 5},
#     'dot_balls_bowled': {'Powerplay': 17,
#      'Middle_overs': 12,
#      'Death': 8,
#      'Total': 37}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 150,
#    'match_date': "['2017-04-30']"},
#   38: {'batting_insights': {'runs_scored': {'Powerplay': 66,
#      'Middle_overs': 48,
#      'Death': 71,
#      'Total': 185},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 0, 'Total': 3},
#     'num_4s': {'Powerplay': 9, 'Middle_overs': 3, 'Death': 10, 'Total': 22},
#     'num_6s': {'Powerplay': 2, 'Middle_overs': 1, 'Death': 1, 'Total': 4},
#     'dot_balls': {'Powerplay': 14,
#      'Middle_overs': 22,
#      'Death': 2,
#      'Total': 38}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 62,
#      'Middle_overs': 80,
#      'Death': 47,
#      'Total': 189},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 4},
#     'num_4s_conceded': {'Powerplay': 7,
#      'Middle_overs': 5,
#      'Death': 3,
#      'Total': 15},
#     'num_6s_conceded': {'Powerplay': 3,
#      'Middle_overs': 4,
#      'Death': 3,
#      'Total': 10},
#     'dot_balls_bowled': {'Powerplay': 13,
#      'Middle_overs': 15,
#      'Death': 3,
#      'Total': 31}},
#    'innings': 1,
#    'match_winner': 330,
#    'venue': 22,
#    'opposition': 330,
#    'match_date': "['2017-05-02']"},
#   42: {'batting_insights': {'runs_scored': {'Powerplay': 47,
#      'Middle_overs': 54,
#      'Death': 35,
#      'Total': 136},
#     'wickets': {'Powerplay': 2, 'Middle_overs': 2, 'Death': 5, 'Total': 9},
#     'num_4s': {'Powerplay': 7, 'Middle_overs': 3, 'Death': 1, 'Total': 11},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 2, 'Total': 5},
#     'dot_balls': {'Powerplay': 17,
#      'Middle_overs': 24,
#      'Death': 14,
#      'Total': 55}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 35,
#      'Middle_overs': 65,
#      'Death': 48,
#      'Total': 148},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 2,
#      'Death': 5,
#      'Total': 8},
#     'num_4s_conceded': {'Powerplay': 0,
#      'Middle_overs': 1,
#      'Death': 4,
#      'Total': 5},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 3,
#      'Death': 2,
#      'Total': 6},
#     'dot_balls_bowled': {'Powerplay': 10,
#      'Middle_overs': 16,
#      'Death': 10,
#      'Total': 36}},
#    'innings': 2,
#    'match_winner': 550,
#    'venue': 10,
#    'opposition': 550,
#    'match_date': "['2017-05-06']"},
#   46: {'batting_insights': {'runs_scored': {'Powerplay': 43,
#      'Middle_overs': 70,
#      'Death': 27,
#      'Total': 140},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 0, 'Total': 3},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 7, 'Death': 1, 'Total': 13},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 0, 'Total': 2},
#     'dot_balls': {'Powerplay': 12,
#      'Middle_overs': 21,
#      'Death': 2,
#      'Total': 35}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 36,
#      'Middle_overs': 63,
#      'Death': 39,
#      'Total': 138},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 2,
#      'Death': 3,
#      'Total': 7},
#     'num_4s_conceded': {'Powerplay': 3,
#      'Middle_overs': 5,
#      'Death': 2,
#      'Total': 10},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 1,
#      'Total': 3},
#     'dot_balls_bowled': {'Powerplay': 19,
#      'Middle_overs': 18,
#      'Death': 10,
#      'Total': 47}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 90,
#    'match_date': "['2017-05-08']"},
#   51: {'batting_insights': {'runs_scored': {'Powerplay': 47,
#      'Middle_overs': 80,
#      'Death': 31,
#      'Total': 158},
#     'wickets': {'Powerplay': 2, 'Middle_overs': 0, 'Death': 0, 'Total': 2},
#     'num_4s': {'Powerplay': 8, 'Middle_overs': 10, 'Death': 5, 'Total': 23},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 0, 'Death': 0, 'Total': 0},
#     'dot_balls': {'Powerplay': 16,
#      'Middle_overs': 10,
#      'Death': 5,
#      'Total': 31}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 61,
#      'Middle_overs': 65,
#      'Death': 28,
#      'Total': 154},
#     'wickets_taken': {'Powerplay': 0,
#      'Middle_overs': 5,
#      'Death': 5,
#      'Total': 10},
#     'num_4s_conceded': {'Powerplay': 7,
#      'Middle_overs': 5,
#      'Death': 3,
#      'Total': 15},
#     'num_6s_conceded': {'Powerplay': 3,
#      'Middle_overs': 3,
#      'Death': 0,
#      'Total': 6},
#     'dot_balls_bowled': {'Powerplay': 12,
#      'Middle_overs': 23,
#      'Death': 9,
#      'Total': 44}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 18,
#    'opposition': 526,
#    'match_date': "['2017-05-13']"},
#   56: {'batting_insights': {'runs_scored': {'Powerplay': 30,
#      'Middle_overs': 68,
#      'Death': 30,
#      'Total': 128},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 4, 'Total': 7},
#     'num_4s': {'Powerplay': 3, 'Middle_overs': 5, 'Death': 1, 'Total': 9},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 4, 'Death': 1, 'Total': 5},
#     'dot_balls': {'Powerplay': 15,
#      'Middle_overs': 22,
#      'Death': 14,
#      'Total': 51}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 48,
#      'Middle_overs': 0,
#      'Death': 0,
#      'Total': 48},
#     'wickets_taken': {'Powerplay': 3,
#      'Middle_overs': 0,
#      'Death': 0,
#      'Total': 3},
#     'num_4s_conceded': {'Powerplay': 2,
#      'Middle_overs': 0,
#      'Death': 0,
#      'Total': 2},
#     'num_6s_conceded': {'Powerplay': 3,
#      'Middle_overs': 0,
#      'Death': 0,
#      'Total': 3},
#     'dot_balls_bowled': {'Powerplay': 10,
#      'Middle_overs': 0,
#      'Death': 0,
#      'Total': 10}},
#    'innings': 1,
#    'match_winner': 150,
#    'venue': 23,
#    'opposition': 150,
#    'match_date': "['2017-05-17,2017-05-18']"},
#   62: {'batting_insights': {'runs_scored': {'Powerplay': 57,
#      'Middle_overs': 66,
#      'Death': 4,
#      'Total': 127},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 0, 'Death': 0, 'Total': 1},
#     'num_4s': {'Powerplay': 8, 'Middle_overs': 9, 'Death': 1, 'Total': 18},
#     'num_6s': {'Powerplay': 2, 'Middle_overs': 0, 'Death': 0, 'Total': 2},
#     'dot_balls': {'Powerplay': 19,
#      'Middle_overs': 20,
#      'Death': 4,
#      'Total': 43}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 48,
#      'Middle_overs': 49,
#      'Death': 28,
#      'Total': 125},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 5,
#      'Death': 3,
#      'Total': 9},
#     'num_4s_conceded': {'Powerplay': 7,
#      'Middle_overs': 3,
#      'Death': 2,
#      'Total': 12},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 0,
#      'Death': 0,
#      'Total': 0},
#     'dot_balls_bowled': {'Powerplay': 15,
#      'Middle_overs': 18,
#      'Death': 12,
#      'Total': 45}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 169,
#    'match_date': "['2018-04-09']"},
#   65: {'batting_insights': {'runs_scored': {'Powerplay': 56,
#      'Middle_overs': 65,
#      'Death': 30,
#      'Total': 151},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 5, 'Death': 4, 'Total': 9},
#     'num_4s': {'Powerplay': 9, 'Middle_overs': 7, 'Death': 2, 'Total': 18},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 0, 'Death': 1, 'Total': 1},
#     'dot_balls': {'Powerplay': 8,
#      'Middle_overs': 16,
#      'Death': 13,
#      'Total': 37}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 54,
#      'Middle_overs': 57,
#      'Death': 36,
#      'Total': 147},
#     'wickets_taken': {'Powerplay': 3,
#      'Middle_overs': 2,
#      'Death': 3,
#      'Total': 8},
#     'num_4s_conceded': {'Powerplay': 7,
#      'Middle_overs': 6,
#      'Death': 3,
#      'Total': 16},
#     'num_6s_conceded': {'Powerplay': 3,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 6},
#     'dot_balls_bowled': {'Powerplay': 21,
#      'Middle_overs': 29,
#      'Death': 11,
#      'Total': 61}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 90,
#    'match_date': "['2018-04-12']"},
#   68: {'batting_insights': {'runs_scored': {'Powerplay': 46,
#      'Middle_overs': 66,
#      'Death': 27,
#      'Total': 139},
#     'wickets': {'Powerplay': 2, 'Middle_overs': 1, 'Death': 2, 'Total': 5},
#     'num_4s': {'Powerplay': 8, 'Middle_overs': 4, 'Death': 2, 'Total': 14},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 1, 'Total': 3},
#     'dot_balls': {'Powerplay': 19,
#      'Middle_overs': 14,
#      'Death': 10,
#      'Total': 43}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 49,
#      'Middle_overs': 57,
#      'Death': 32,
#      'Total': 138},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 4,
#      'Death': 3,
#      'Total': 8},
#     'num_4s_conceded': {'Powerplay': 8,
#      'Middle_overs': 3,
#      'Death': 1,
#      'Total': 12},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 4},
#     'dot_balls_bowled': {'Powerplay': 17,
#      'Middle_overs': 23,
#      'Death': 12,
#      'Total': 52}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 5,
#    'opposition': 150,
#    'match_date': "['2018-04-14']"},
#   74: {'batting_insights': {'runs_scored': {'Powerplay': 40,
#      'Middle_overs': 78,
#      'Death': 60,
#      'Total': 178},
#     'wickets': {'Powerplay': 3, 'Middle_overs': 1, 'Death': 1, 'Total': 5},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 4, 'Death': 1, 'Total': 10},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 3, 'Total': 5},
#     'dot_balls': {'Powerplay': 15,
#      'Middle_overs': 10,
#      'Death': 4,
#      'Total': 29}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 49,
#      'Middle_overs': 94,
#      'Death': 50,
#      'Total': 193},
#     'wickets_taken': {'Powerplay': 0,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 3},
#     'num_4s_conceded': {'Powerplay': 5,
#      'Middle_overs': 4,
#      'Death': 2,
#      'Total': 11},
#     'num_6s_conceded': {'Powerplay': 3,
#      'Middle_overs': 8,
#      'Death': 3,
#      'Total': 14},
#     'dot_balls_bowled': {'Powerplay': 18,
#      'Middle_overs': 15,
#      'Death': 5,
#      'Total': 38}},
#    'innings': 2,
#    'match_winner': 164,
#    'venue': 17,
#    'opposition': 164,
#    'match_date': "['2018-04-19']"},
#   78: {'batting_insights': {'runs_scored': {'Powerplay': 40,
#      'Middle_overs': 77,
#      'Death': 61,
#      'Total': 178},
#     'wickets': {'Powerplay': 3, 'Middle_overs': 1, 'Death': 2, 'Total': 6},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 3, 'Death': 2, 'Total': 10},
#     'num_6s': {'Powerplay': 2, 'Middle_overs': 4, 'Death': 6, 'Total': 12},
#     'dot_balls': {'Powerplay': 23,
#      'Middle_overs': 12,
#      'Death': 9,
#      'Total': 44}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 27,
#      'Middle_overs': 93,
#      'Death': 62,
#      'Total': 182},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 1,
#      'Total': 3},
#     'num_4s_conceded': {'Powerplay': 2,
#      'Middle_overs': 8,
#      'Death': 8,
#      'Total': 18},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 5,
#      'Death': 2,
#      'Total': 8},
#     'dot_balls_bowled': {'Powerplay': 22,
#      'Middle_overs': 14,
#      'Death': 3,
#      'Total': 39}},
#    'innings': 2,
#    'match_winner': 599,
#    'venue': 10,
#    'opposition': 599,
#    'match_date': "['2018-04-22']"},
#   81: {'batting_insights': {'runs_scored': {'Powerplay': 51,
#      'Middle_overs': 55,
#      'Death': 12,
#      'Total': 118},
#     'wickets': {'Powerplay': 4, 'Middle_overs': 3, 'Death': 3, 'Total': 10},
#     'num_4s': {'Powerplay': 8, 'Middle_overs': 6, 'Death': 0, 'Total': 14},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 0, 'Death': 1, 'Total': 1},
#     'dot_balls': {'Powerplay': 16,
#      'Middle_overs': 20,
#      'Death': 17,
#      'Total': 53}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 22,
#      'Middle_overs': 55,
#      'Death': 10,
#      'Total': 87},
#     'wickets_taken': {'Powerplay': 3,
#      'Middle_overs': 3,
#      'Death': 4,
#      'Total': 10},
#     'num_4s_conceded': {'Powerplay': 3,
#      'Middle_overs': 6,
#      'Death': 1,
#      'Total': 10},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 1,
#      'Death': 0,
#      'Total': 1},
#     'dot_balls_bowled': {'Powerplay': 25,
#      'Middle_overs': 24,
#      'Death': 16,
#      'Total': 65}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 11,
#    'opposition': 90,
#    'match_date': "['2018-04-24']"},
#   83: {'batting_insights': {'runs_scored': {'Powerplay': 37,
#      'Middle_overs': 60,
#      'Death': 35,
#      'Total': 132},
#     'wickets': {'Powerplay': 3, 'Middle_overs': 1, 'Death': 2, 'Total': 6},
#     'num_4s': {'Powerplay': 6, 'Middle_overs': 2, 'Death': 3, 'Total': 11},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 1, 'Death': 1, 'Total': 2},
#     'dot_balls': {'Powerplay': 21,
#      'Middle_overs': 16,
#      'Death': 14,
#      'Total': 51}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 44,
#      'Middle_overs': 47,
#      'Death': 28,
#      'Total': 119},
#     'wickets_taken': {'Powerplay': 0,
#      'Middle_overs': 5,
#      'Death': 5,
#      'Total': 10},
#     'num_4s_conceded': {'Powerplay': 5,
#      'Middle_overs': 0,
#      'Death': 4,
#      'Total': 9},
#     'num_6s_conceded': {'Powerplay': 2,
#      'Middle_overs': 2,
#      'Death': 0,
#      'Total': 4},
#     'dot_balls_bowled': {'Powerplay': 17,
#      'Middle_overs': 21,
#      'Death': 10,
#      'Total': 48}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 164,
#    'match_date': "['2018-04-26']"},
#   86: {'batting_insights': {'runs_scored': {'Powerplay': 39,
#      'Middle_overs': 81,
#      'Death': 31,
#      'Total': 151},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 4, 'Total': 7},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 8, 'Death': 2, 'Total': 15},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 0, 'Total': 2},
#     'dot_balls': {'Powerplay': 14,
#      'Middle_overs': 13,
#      'Death': 10,
#      'Total': 37}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 43,
#      'Middle_overs': 59,
#      'Death': 38,
#      'Total': 140},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 3,
#      'Death': 2,
#      'Total': 6},
#     'num_4s_conceded': {'Powerplay': 5,
#      'Middle_overs': 3,
#      'Death': 1,
#      'Total': 9},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 0,
#      'Death': 1,
#      'Total': 2},
#     'dot_balls_bowled': {'Powerplay': 16,
#      'Middle_overs': 11,
#      'Death': 6,
#      'Total': 33}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 34,
#    'opposition': 169,
#    'match_date': "['2018-04-29']"},
#   94: {'batting_insights': {'runs_scored': {'Powerplay': 61,
#      'Middle_overs': 54,
#      'Death': 49,
#      'Total': 164},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 1, 'Total': 3},
#     'num_4s': {'Powerplay': 4, 'Middle_overs': 3, 'Death': 2, 'Total': 9},
#     'num_6s': {'Powerplay': 4, 'Middle_overs': 0, 'Death': 3, 'Total': 7},
#     'dot_balls': {'Powerplay': 12,
#      'Middle_overs': 15,
#      'Death': 6,
#      'Total': 33}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 60,
#      'Middle_overs': 65,
#      'Death': 38,
#      'Total': 163},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 3,
#      'Total': 5},
#     'num_4s_conceded': {'Powerplay': 6,
#      'Middle_overs': 3,
#      'Death': 2,
#      'Total': 11},
#     'num_6s_conceded': {'Powerplay': 3,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 6},
#     'dot_balls_bowled': {'Powerplay': 12,
#      'Middle_overs': 12,
#      'Death': 9,
#      'Total': 33}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 330,
#    'match_date': "['2018-05-05']"},
#   97: {'batting_insights': {'runs_scored': {'Powerplay': 38,
#      'Middle_overs': 67,
#      'Death': 41,
#      'Total': 146},
#     'wickets': {'Powerplay': 2, 'Middle_overs': 1, 'Death': 7, 'Total': 10},
#     'num_4s': {'Powerplay': 4, 'Middle_overs': 5, 'Death': 5, 'Total': 14},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 1, 'Total': 3},
#     'dot_balls': {'Powerplay': 13,
#      'Middle_overs': 19,
#      'Death': 10,
#      'Total': 42}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 55,
#      'Middle_overs': 47,
#      'Death': 39,
#      'Total': 141},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 4,
#      'Death': 1,
#      'Total': 6},
#     'num_4s_conceded': {'Powerplay': 8,
#      'Middle_overs': 4,
#      'Death': 1,
#      'Total': 13},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 0,
#      'Death': 2,
#      'Total': 3},
#     'dot_balls_bowled': {'Powerplay': 13,
#      'Middle_overs': 23,
#      'Death': 7,
#      'Total': 43}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 182,
#    'match_date': "['2018-05-07']"},
#   100: {'batting_insights': {'runs_scored': {'Powerplay': 51,
#      'Middle_overs': 101,
#      'Death': 39,
#      'Total': 191},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 0, 'Death': 0, 'Total': 1},
#     'num_4s': {'Powerplay': 6, 'Middle_overs': 10, 'Death': 4, 'Total': 20},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 4, 'Death': 1, 'Total': 6},
#     'dot_balls': {'Powerplay': 11,
#      'Middle_overs': 9,
#      'Death': 3,
#      'Total': 23}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 38,
#      'Middle_overs': 73,
#      'Death': 76,
#      'Total': 187},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 5},
#     'num_4s_conceded': {'Powerplay': 6,
#      'Middle_overs': 6,
#      'Death': 7,
#      'Total': 19},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 3,
#      'Death': 6,
#      'Total': 9},
#     'dot_balls_bowled': {'Powerplay': 18,
#      'Middle_overs': 14,
#      'Death': 8,
#      'Total': 40}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 22,
#    'opposition': 330,
#    'match_date': "['2018-05-10']"},
#   104: {'batting_insights': {'runs_scored': {'Powerplay': 29,
#      'Middle_overs': 101,
#      'Death': 49,
#      'Total': 179},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 0, 'Death': 3, 'Total': 4},
#     'num_4s': {'Powerplay': 4, 'Middle_overs': 9, 'Death': 4, 'Total': 17},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 5, 'Death': 1, 'Total': 6},
#     'dot_balls': {'Powerplay': 20,
#      'Middle_overs': 11,
#      'Death': 7,
#      'Total': 38}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 53,
#      'Middle_overs': 90,
#      'Death': 37,
#      'Total': 180},
#     'wickets_taken': {'Powerplay': 0,
#      'Middle_overs': 2,
#      'Death': 0,
#      'Total': 2},
#     'num_4s_conceded': {'Powerplay': 4,
#      'Middle_overs': 7,
#      'Death': 2,
#      'Total': 13},
#     'num_6s_conceded': {'Powerplay': 4,
#      'Middle_overs': 5,
#      'Death': 2,
#      'Total': 11},
#     'dot_balls_bowled': {'Powerplay': 16,
#      'Middle_overs': 15,
#      'Death': 3,
#      'Total': 34}},
#    'innings': 1,
#    'match_winner': 599,
#    'venue': 24,
#    'opposition': 599,
#    'match_date': "['2018-05-13']"},
#   109: {'batting_insights': {'runs_scored': {'Powerplay': 56,
#      'Middle_overs': 96,
#      'Death': 52,
#      'Total': 204},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 1, 'Death': 1, 'Total': 3},
#     'num_4s': {'Powerplay': 3, 'Middle_overs': 8, 'Death': 5, 'Total': 16},
#     'num_6s': {'Powerplay': 5, 'Middle_overs': 6, 'Death': 1, 'Total': 12},
#     'dot_balls': {'Powerplay': 15,
#      'Middle_overs': 14,
#      'Death': 5,
#      'Total': 34}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 44,
#      'Middle_overs': 105,
#      'Death': 69,
#      'Total': 218},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 2,
#      'Death': 2,
#      'Total': 6},
#     'num_4s_conceded': {'Powerplay': 8,
#      'Middle_overs': 8,
#      'Death': 4,
#      'Total': 20},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 7,
#      'Death': 5,
#      'Total': 12},
#     'dot_balls_bowled': {'Powerplay': 16,
#      'Middle_overs': 13,
#      'Death': 4,
#      'Total': 33}},
#    'innings': 2,
#    'match_winner': 182,
#    'venue': 23,
#    'opposition': 182,
#    'match_date': "['2018-05-17']"},
#   112: {'batting_insights': {'runs_scored': {'Powerplay': 60,
#      'Middle_overs': 81,
#      'Death': 31,
#      'Total': 172},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 7, 'Total': 9},
#     'num_4s': {'Powerplay': 8, 'Middle_overs': 5, 'Death': 2, 'Total': 15},
#     'num_6s': {'Powerplay': 2, 'Middle_overs': 3, 'Death': 1, 'Total': 6},
#     'dot_balls': {'Powerplay': 15,
#      'Middle_overs': 12,
#      'Death': 13,
#      'Total': 40}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 66,
#      'Middle_overs': 66,
#      'Death': 41,
#      'Total': 173},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 3,
#      'Total': 5},
#     'num_4s_conceded': {'Powerplay': 9,
#      'Middle_overs': 1,
#      'Death': 4,
#      'Total': 14},
#     'num_6s_conceded': {'Powerplay': 3,
#      'Middle_overs': 4,
#      'Death': 1,
#      'Total': 8},
#     'dot_balls_bowled': {'Powerplay': 15,
#      'Middle_overs': 16,
#      'Death': 8,
#      'Total': 39}},
#    'innings': 1,
#    'match_winner': 150,
#    'venue': 10,
#    'opposition': 150,
#    'match_date': "['2018-05-19']"},
#   115: {'batting_insights': {'runs_scored': {'Powerplay': 47,
#      'Middle_overs': 41,
#      'Death': 51,
#      'Total': 139},
#     'wickets': {'Powerplay': 3, 'Middle_overs': 3, 'Death': 1, 'Total': 7},
#     'num_4s': {'Powerplay': 8, 'Middle_overs': 3, 'Death': 1, 'Total': 12},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 0, 'Death': 4, 'Total': 4},
#     'dot_balls': {'Powerplay': 16,
#      'Middle_overs': 29,
#      'Death': 9,
#      'Total': 54}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 33,
#      'Middle_overs': 59,
#      'Death': 48,
#      'Total': 140},
#     'wickets_taken': {'Powerplay': 3,
#      'Middle_overs': 4,
#      'Death': 1,
#      'Total': 8},
#     'num_4s_conceded': {'Powerplay': 5,
#      'Middle_overs': 2,
#      'Death': 6,
#      'Total': 13},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 3,
#      'Death': 2,
#      'Total': 5},
#     'dot_balls_bowled': {'Powerplay': 21,
#      'Middle_overs': 20,
#      'Death': 7,
#      'Total': 48}},
#    'innings': 1,
#    'match_winner': 599,
#    'venue': 11,
#    'opposition': 599,
#    'match_date': "['2018-05-22']"},
#   117: {'batting_insights': {'runs_scored': {'Powerplay': 45,
#      'Middle_overs': 68,
#      'Death': 61,
#      'Total': 174},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 3, 'Death': 4, 'Total': 7},
#     'num_4s': {'Powerplay': 4, 'Middle_overs': 9, 'Death': 3, 'Total': 16},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 0, 'Death': 6, 'Total': 7},
#     'dot_balls': {'Powerplay': 11,
#      'Middle_overs': 16,
#      'Death': 11,
#      'Total': 38}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 67,
#      'Middle_overs': 51,
#      'Death': 42,
#      'Total': 160},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 5,
#      'Death': 3,
#      'Total': 9},
#     'num_4s_conceded': {'Powerplay': 6,
#      'Middle_overs': 6,
#      'Death': 3,
#      'Total': 15},
#     'num_6s_conceded': {'Powerplay': 5,
#      'Middle_overs': 0,
#      'Death': 2,
#      'Total': 7},
#     'dot_balls_bowled': {'Powerplay': 13,
#      'Middle_overs': 23,
#      'Death': 9,
#      'Total': 45}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 5,
#    'opposition': 150,
#    'match_date': "['2018-05-25']"},
#   118: {'batting_insights': {'runs_scored': {'Powerplay': 42,
#      'Middle_overs': 84,
#      'Death': 52,
#      'Total': 178},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 3, 'Total': 6},
#     'num_4s': {'Powerplay': 2, 'Middle_overs': 9, 'Death': 2, 'Total': 13},
#     'num_6s': {'Powerplay': 2, 'Middle_overs': 3, 'Death': 4, 'Total': 9},
#     'dot_balls': {'Powerplay': 15,
#      'Middle_overs': 15,
#      'Death': 8,
#      'Total': 38}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 35,
#      'Middle_overs': 111,
#      'Death': 35,
#      'Total': 181},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 0,
#      'Total': 2},
#     'num_4s_conceded': {'Powerplay': 3,
#      'Middle_overs': 8,
#      'Death': 5,
#      'Total': 16},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 8,
#      'Death': 1,
#      'Total': 10},
#     'dot_balls_bowled': {'Powerplay': 20,
#      'Middle_overs': 11,
#      'Death': 6,
#      'Total': 37}},
#    'innings': 1,
#    'match_winner': 599,
#    'venue': 11,
#    'opposition': 599,
#    'match_date': "['2018-05-27']"},
#   120: {'batting_insights': {'runs_scored': {'Powerplay': 54,
#      'Middle_overs': 80,
#      'Death': 47,
#      'Total': 181},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 1, 'Death': 2, 'Total': 3},
#     'num_4s': {'Powerplay': 6, 'Middle_overs': 6, 'Death': 3, 'Total': 15},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 3, 'Death': 2, 'Total': 6},
#     'dot_balls': {'Powerplay': 14,
#      'Middle_overs': 11,
#      'Death': 5,
#      'Total': 30}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 47,
#      'Middle_overs': 67,
#      'Death': 69,
#      'Total': 183},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 4},
#     'num_4s_conceded': {'Powerplay': 6,
#      'Middle_overs': 4,
#      'Death': 5,
#      'Total': 15},
#     'num_6s_conceded': {'Powerplay': 2,
#      'Middle_overs': 3,
#      'Death': 6,
#      'Total': 11},
#     'dot_balls_bowled': {'Powerplay': 18,
#      'Middle_overs': 18,
#      'Death': 6,
#      'Total': 42}},
#    'innings': 1,
#    'match_winner': 150,
#    'venue': 5,
#    'opposition': 150,
#    'match_date': "['2019-03-24']"},
#   126: {'batting_insights': {'runs_scored': {'Powerplay': 69,
#      'Middle_overs': 96,
#      'Death': 36,
#      'Total': 201},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 3, 'Death': 2, 'Total': 5},
#     'num_4s': {'Powerplay': 11, 'Middle_overs': 7, 'Death': 1, 'Total': 19},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 5, 'Death': 2, 'Total': 8},
#     'dot_balls': {'Powerplay': 10,
#      'Middle_overs': 11,
#      'Death': 7,
#      'Total': 28}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 35,
#      'Middle_overs': 87,
#      'Death': 76,
#      'Total': 198},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 0,
#      'Death': 1,
#      'Total': 2},
#     'num_4s_conceded': {'Powerplay': 3,
#      'Middle_overs': 6,
#      'Death': 9,
#      'Total': 18},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 4,
#      'Death': 3,
#      'Total': 7},
#     'dot_balls_bowled': {'Powerplay': 16,
#      'Middle_overs': 12,
#      'Death': 3,
#      'Total': 31}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 169,
#    'match_date': "['2019-03-29']"},
#   129: {'batting_insights': {'runs_scored': {'Powerplay': 59,
#      'Middle_overs': 105,
#      'Death': 67,
#      'Total': 231},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 0, 'Death': 2, 'Total': 2},
#     'num_4s': {'Powerplay': 9, 'Middle_overs': 5, 'Death': 3, 'Total': 17},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 7, 'Death': 5, 'Total': 13},
#     'dot_balls': {'Powerplay': 12,
#      'Middle_overs': 9,
#      'Death': 3,
#      'Total': 24}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 30,
#      'Middle_overs': 56,
#      'Death': 27,
#      'Total': 113},
#     'wickets_taken': {'Powerplay': 3,
#      'Middle_overs': 3,
#      'Death': 4,
#      'Total': 10},
#     'num_4s_conceded': {'Powerplay': 3,
#      'Middle_overs': 6,
#      'Death': 1,
#      'Total': 10},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 4},
#     'dot_balls_bowled': {'Powerplay': 20,
#      'Middle_overs': 27,
#      'Death': 15,
#      'Total': 62}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 182,
#    'match_date': "['2019-03-31']"},
#   134: {'batting_insights': {'runs_scored': {'Powerplay': 62,
#      'Middle_overs': 41,
#      'Death': 28,
#      'Total': 131},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 4, 'Death': 1, 'Total': 5},
#     'num_4s': {'Powerplay': 11, 'Middle_overs': 2, 'Death': 3, 'Total': 16},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 0, 'Death': 1, 'Total': 2},
#     'dot_balls': {'Powerplay': 14,
#      'Middle_overs': 24,
#      'Death': 8,
#      'Total': 46}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 36,
#      'Middle_overs': 49,
#      'Death': 44,
#      'Total': 129},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 3,
#      'Death': 3,
#      'Total': 8},
#     'num_4s_conceded': {'Powerplay': 3,
#      'Middle_overs': 5,
#      'Death': 1,
#      'Total': 9},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 0,
#      'Death': 3,
#      'Total': 4},
#     'dot_balls_bowled': {'Powerplay': 15,
#      'Middle_overs': 22,
#      'Death': 10,
#      'Total': 47}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 22,
#    'opposition': 330,
#    'match_date': "['2019-04-04']"},
#   137: {'batting_insights': {'runs_scored': {'Powerplay': 39,
#      'Middle_overs': 45,
#      'Death': 12,
#      'Total': 96},
#     'wickets': {'Powerplay': 2, 'Middle_overs': 3, 'Death': 5, 'Total': 10},
#     'num_4s': {'Powerplay': 6, 'Middle_overs': 1, 'Death': 1, 'Total': 8},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 1, 'Death': 0, 'Total': 1},
#     'dot_balls': {'Powerplay': 19,
#      'Middle_overs': 22,
#      'Death': 9,
#      'Total': 50}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 30,
#      'Middle_overs': 45,
#      'Death': 61,
#      'Total': 136},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 3,
#      'Death': 2,
#      'Total': 7},
#     'num_4s_conceded': {'Powerplay': 1,
#      'Middle_overs': 3,
#      'Death': 4,
#      'Total': 8},
#     'num_6s_conceded': {'Powerplay': 2,
#      'Middle_overs': 0,
#      'Death': 5,
#      'Total': 7},
#     'dot_balls_bowled': {'Powerplay': 21,
#      'Middle_overs': 24,
#      'Death': 12,
#      'Total': 57}},
#    'innings': 2,
#    'match_winner': 90,
#    'venue': 10,
#    'opposition': 90,
#    'match_date': "['2019-04-06']"},
#   140: {'batting_insights': {'runs_scored': {'Powerplay': 27,
#      'Middle_overs': 65,
#      'Death': 58,
#      'Total': 150},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 1, 'Total': 4},
#     'num_4s': {'Powerplay': 2, 'Middle_overs': 4, 'Death': 6, 'Total': 12},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 0, 'Death': 2, 'Total': 2},
#     'dot_balls': {'Powerplay': 22,
#      'Middle_overs': 15,
#      'Death': 4,
#      'Total': 41}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 38,
#      'Middle_overs': 73,
#      'Death': 40,
#      'Total': 151},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 0,
#      'Death': 3,
#      'Total': 4},
#     'num_4s_conceded': {'Powerplay': 3,
#      'Middle_overs': 6,
#      'Death': 2,
#      'Total': 11},
#     'num_6s_conceded': {'Powerplay': 2,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 5},
#     'dot_balls_bowled': {'Powerplay': 18,
#      'Middle_overs': 15,
#      'Death': 6,
#      'Total': 39}},
#    'innings': 1,
#    'match_winner': 164,
#    'venue': 17,
#    'opposition': 164,
#    'match_date': "['2019-04-08']"},
#   148: {'batting_insights': {'runs_scored': {'Powerplay': 40,
#      'Middle_overs': 60,
#      'Death': 16,
#      'Total': 116},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 8, 'Total': 10},
#     'num_4s': {'Powerplay': 4, 'Middle_overs': 4, 'Death': 0, 'Total': 8},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 1, 'Death': 0, 'Total': 2},
#     'dot_balls': {'Powerplay': 17,
#      'Middle_overs': 19,
#      'Death': 11,
#      'Total': 47}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 51,
#      'Middle_overs': 70,
#      'Death': 34,
#      'Total': 155},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 1,
#      'Death': 4,
#      'Total': 7},
#     'num_4s_conceded': {'Powerplay': 6,
#      'Middle_overs': 7,
#      'Death': 1,
#      'Total': 14},
#     'num_6s_conceded': {'Powerplay': 2,
#      'Middle_overs': 1,
#      'Death': 1,
#      'Total': 4},
#     'dot_balls_bowled': {'Powerplay': 19,
#      'Middle_overs': 13,
#      'Death': 9,
#      'Total': 41}},
#    'innings': 2,
#    'match_winner': 330,
#    'venue': 10,
#    'opposition': 330,
#    'match_date': "['2019-04-14']"},
#   151: {'batting_insights': {'runs_scored': {'Powerplay': 68,
#      'Middle_overs': 48,
#      'Death': 21,
#      'Total': 137},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 1, 'Total': 4},
#     'num_4s': {'Powerplay': 12, 'Middle_overs': 1, 'Death': 1, 'Total': 14},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 1, 'Total': 3},
#     'dot_balls': {'Powerplay': 10,
#      'Middle_overs': 23,
#      'Death': 1,
#      'Total': 34}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 41,
#      'Middle_overs': 61,
#      'Death': 30,
#      'Total': 132},
#     'wickets_taken': {'Powerplay': 0,
#      'Middle_overs': 5,
#      'Death': 0,
#      'Total': 5},
#     'num_4s_conceded': {'Powerplay': 5,
#      'Middle_overs': 4,
#      'Death': 2,
#      'Total': 11},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 2,
#      'Death': 0,
#      'Total': 3},
#     'dot_balls_bowled': {'Powerplay': 18,
#      'Middle_overs': 18,
#      'Death': 12,
#      'Total': 48}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 599,
#    'match_date': "['2019-04-17']"},
#   156: {'batting_insights': {'runs_scored': {'Powerplay': 72,
#      'Middle_overs': 89,
#      'Death': 0,
#      'Total': 161},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 1, 'Death': 0, 'Total': 1},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 5, 'Death': 0, 'Total': 10},
#     'num_6s': {'Powerplay': 5, 'Middle_overs': 4, 'Death': 0, 'Total': 9},
#     'dot_balls': {'Powerplay': 10,
#      'Middle_overs': 9,
#      'Death': 0,
#      'Total': 19}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 61,
#      'Middle_overs': 55,
#      'Death': 43,
#      'Total': 159},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 2,
#      'Death': 4,
#      'Total': 8},
#     'num_4s_conceded': {'Powerplay': 6,
#      'Middle_overs': 3,
#      'Death': 2,
#      'Total': 11},
#     'num_6s_conceded': {'Powerplay': 3,
#      'Middle_overs': 1,
#      'Death': 4,
#      'Total': 8},
#     'dot_balls_bowled': {'Powerplay': 10,
#      'Middle_overs': 18,
#      'Death': 16,
#      'Total': 44}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 150,
#    'match_date': "['2019-04-21']"},
#   159: {'batting_insights': {'runs_scored': {'Powerplay': 54,
#      'Middle_overs': 80,
#      'Death': 41,
#      'Total': 175},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 1, 'Death': 1, 'Total': 3},
#     'num_4s': {'Powerplay': 6, 'Middle_overs': 4, 'Death': 2, 'Total': 12},
#     'num_6s': {'Powerplay': 2, 'Middle_overs': 3, 'Death': 1, 'Total': 6},
#     'dot_balls': {'Powerplay': 17,
#      'Middle_overs': 10,
#      'Death': 6,
#      'Total': 33}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 49,
#      'Middle_overs': 86,
#      'Death': 41,
#      'Total': 176},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 2,
#      'Total': 4},
#     'num_4s_conceded': {'Powerplay': 7,
#      'Middle_overs': 9,
#      'Death': 1,
#      'Total': 17},
#     'num_6s_conceded': {'Powerplay': 2,
#      'Middle_overs': 3,
#      'Death': 3,
#      'Total': 8},
#     'dot_balls_bowled': {'Powerplay': 19,
#      'Middle_overs': 14,
#      'Death': 8,
#      'Total': 41}},
#    'innings': 1,
#    'match_winner': 599,
#    'venue': 33,
#    'opposition': 599,
#    'match_date': "['2019-04-23']"},
#   163: {'batting_insights': {'runs_scored': {'Powerplay': 51,
#      'Middle_overs': 70,
#      'Death': 39,
#      'Total': 160},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 5, 'Total': 8},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 6, 'Death': 2, 'Total': 13},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 0, 'Death': 1, 'Total': 1},
#     'dot_balls': {'Powerplay': 12,
#      'Middle_overs': 9,
#      'Death': 8,
#      'Total': 29}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 60,
#      'Middle_overs': 72,
#      'Death': 29,
#      'Total': 161},
#     'wickets_taken': {'Powerplay': 0,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 3},
#     'num_4s_conceded': {'Powerplay': 6,
#      'Middle_overs': 6,
#      'Death': 3,
#      'Total': 15},
#     'num_6s_conceded': {'Powerplay': 4,
#      'Middle_overs': 1,
#      'Death': 0,
#      'Total': 5},
#     'dot_balls_bowled': {'Powerplay': 16,
#      'Middle_overs': 18,
#      'Death': 8,
#      'Total': 42}},
#    'innings': 1,
#    'match_winner': 169,
#    'venue': 34,
#    'opposition': 169,
#    'match_date': "['2019-04-27']"},
#   166: {'batting_insights': {'runs_scored': {'Powerplay': 77,
#      'Middle_overs': 82,
#      'Death': 53,
#      'Total': 212},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 1, 'Death': 5, 'Total': 6},
#     'num_4s': {'Powerplay': 8, 'Middle_overs': 6, 'Death': 2, 'Total': 16},
#     'num_6s': {'Powerplay': 3, 'Middle_overs': 1, 'Death': 3, 'Total': 7},
#     'dot_balls': {'Powerplay': 8, 'Middle_overs': 8, 'Death': 6, 'Total': 22}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 44,
#      'Middle_overs': 79,
#      'Death': 44,
#      'Total': 167},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 4,
#      'Death': 3,
#      'Total': 8},
#     'num_4s_conceded': {'Powerplay': 4,
#      'Middle_overs': 5,
#      'Death': 2,
#      'Total': 11},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 5,
#      'Death': 3,
#      'Total': 9},
#     'dot_balls_bowled': {'Powerplay': 14,
#      'Middle_overs': 21,
#      'Death': 13,
#      'Total': 48}},
#    'innings': 1,
#    'match_winner': 72,
#    'venue': 10,
#    'opposition': 164,
#    'match_date': "['2019-04-29']"},
#   169: {'batting_insights': {'runs_scored': {'Powerplay': 59,
#      'Middle_overs': 47,
#      'Death': 56,
#      'Total': 162},
#     'wickets': {'Powerplay': 2, 'Middle_overs': 3, 'Death': 1, 'Total': 6},
#     'num_4s': {'Powerplay': 8, 'Middle_overs': 3, 'Death': 5, 'Total': 16},
#     'num_6s': {'Powerplay': 2, 'Middle_overs': 0, 'Death': 3, 'Total': 5},
#     'dot_balls': {'Powerplay': 14,
#      'Middle_overs': 19,
#      'Death': 6,
#      'Total': 39}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 44,
#      'Middle_overs': 69,
#      'Death': 49,
#      'Total': 162},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 2,
#      'Death': 2,
#      'Total': 5},
#     'num_4s_conceded': {'Powerplay': 9,
#      'Middle_overs': 4,
#      'Death': 2,
#      'Total': 15},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 3,
#      'Death': 3,
#      'Total': 6},
#     'dot_balls_bowled': {'Powerplay': 20,
#      'Middle_overs': 17,
#      'Death': 6,
#      'Total': 43}},
#    'innings': 2,
#    'match_winner': -1,
#    'venue': 11,
#    'opposition': 90,
#    'match_date': "['2019-05-02']"},
#   172: {'batting_insights': {'runs_scored': {'Powerplay': 52,
#      'Middle_overs': 70,
#      'Death': 53,
#      'Total': 175},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 3, 'Death': 3, 'Total': 7},
# ...
#     'dot_balls': {'Powerplay': 21,
#      'Middle_overs': 27,
#      'Death': 13,
#      'Total': 61}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 56,
#      'Middle_overs': 44,
#      'Death': 0,
#      'Total': 100},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 0,
#      'Total': 2},
#     'num_4s_conceded': {'Powerplay': 9,
#      'Middle_overs': 5,
#      'Death': 0,
#      'Total': 14},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 0,
#      'Death': 0,
#      'Total': 1},
#     'dot_balls_bowled': {'Powerplay': 14,
#      'Middle_overs': 15,
#      'Death': 0,
#      'Total': 29}},
#    'innings': 1,
#    'match_winner': 164,
#    'venue': 20,
#    'opposition': 164,
#    'match_date': "['2013-04-07']"},
#   572: {'batting_insights': {'runs_scored': {'Powerplay': 64,
#      'Middle_overs': 53,
#      'Death': 31,
#      'Total': 148},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 1, 'Death': 1, 'Total': 3},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 3, 'Death': 2, 'Total': 10},
#     'num_6s': {'Powerplay': 4, 'Middle_overs': 2, 'Death': 2, 'Total': 8},
#     'dot_balls': {'Powerplay': 14,
#      'Middle_overs': 25,
#      'Death': 8,
#      'Total': 47}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 44,
#      'Middle_overs': 58,
#      'Death': 43,
#      'Total': 145},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 3,
#      'Death': 1,
#      'Total': 5},
#     'num_4s_conceded': {'Powerplay': 7,
#      'Middle_overs': 6,
#      'Death': 4,
#      'Total': 17},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 0,
#      'Death': 1,
#      'Total': 1},
#     'dot_balls_bowled': {'Powerplay': 16,
#      'Middle_overs': 17,
#      'Death': 8,
#      'Total': 41}},
#    'innings': 2,
#    'match_winner': 471,
#    'venue': 20,
#    'opposition': 169,
#    'match_date': "['2013-04-11']"},
#   574: {'batting_insights': {'runs_scored': {'Powerplay': 40,
#      'Middle_overs': 78,
#      'Death': 24,
#      'Total': 142},
#     'wickets': {'Powerplay': 4, 'Middle_overs': 2, 'Death': 2, 'Total': 8},
#     'num_4s': {'Powerplay': 7, 'Middle_overs': 2, 'Death': 2, 'Total': 11},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 5, 'Death': 0, 'Total': 5},
#     'dot_balls': {'Powerplay': 20,
#      'Middle_overs': 15,
#      'Death': 14,
#      'Total': 49}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 48,
#      'Middle_overs': 67,
#      'Death': 68,
#      'Total': 183},
#     'wickets_taken': {'Powerplay': 0,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 3},
#     'num_4s_conceded': {'Powerplay': 8,
#      'Middle_overs': 6,
#      'Death': 3,
#      'Total': 17},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 5,
#      'Total': 7},
#     'dot_balls_bowled': {'Powerplay': 19,
#      'Middle_overs': 15,
#      'Death': 7,
#      'Total': 41}},
#    'innings': 2,
#    'match_winner': 90,
#    'venue': 11,
#    'opposition': 90,
#    'match_date': "['2013-04-13']"},
#   578: {'batting_insights': {'runs_scored': {'Powerplay': 48,
#      'Middle_overs': 58,
#      'Death': 53,
#      'Total': 159},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 3, 'Total': 5},
#     'num_4s': {'Powerplay': 9, 'Middle_overs': 3, 'Death': 4, 'Total': 16},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 3, 'Total': 5},
#     'dot_balls': {'Powerplay': 16,
#      'Middle_overs': 16,
#      'Death': 9,
#      'Total': 41}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 38,
#      'Middle_overs': 61,
#      'Death': 36,
#      'Total': 135},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 3,
#      'Death': 3,
#      'Total': 8},
#     'num_4s_conceded': {'Powerplay': 4,
#      'Middle_overs': 4,
#      'Death': 2,
#      'Total': 10},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 1,
#      'Total': 3},
#     'dot_balls_bowled': {'Powerplay': 17,
#      'Middle_overs': 17,
#      'Death': 10,
#      'Total': 44}},
#    'innings': 1,
#    'match_winner': 471,
#    'venue': 33,
#    'opposition': 599,
#    'match_date': "['2013-04-15']"},
#   581: {'batting_insights': {'runs_scored': {'Powerplay': 41,
#      'Middle_overs': 46,
#      'Death': 21,
#      'Total': 108},
#     'wickets': {'Powerplay': 2, 'Middle_overs': 2, 'Death': 6, 'Total': 10},
#     'num_4s': {'Powerplay': 7, 'Middle_overs': 2, 'Death': 2, 'Total': 11},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 0, 'Death': 1, 'Total': 1},
#     'dot_balls': {'Powerplay': 20,
#      'Middle_overs': 20,
#      'Death': 14,
#      'Total': 54}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 25,
#      'Middle_overs': 50,
#      'Death': 44,
#      'Total': 119},
#     'wickets_taken': {'Powerplay': 4,
#      'Middle_overs': 3,
#      'Death': 1,
#      'Total': 8},
#     'num_4s_conceded': {'Powerplay': 3,
#      'Middle_overs': 3,
#      'Death': 3,
#      'Total': 9},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 1,
#      'Death': 1,
#      'Total': 2},
#     'dot_balls_bowled': {'Powerplay': 24,
#      'Middle_overs': 22,
#      'Death': 4,
#      'Total': 50}},
#    'innings': 2,
#    'match_winner': 72,
#    'venue': 20,
#    'opposition': 72,
#    'match_date': "['2013-04-17']"},
#   588: {'batting_insights': {'runs_scored': {'Powerplay': 48,
#      'Middle_overs': 76,
#      'Death': 61,
#      'Total': 185},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 1, 'Death': 3, 'Total': 4},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 9, 'Death': 6, 'Total': 20},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 3, 'Total': 6},
#     'dot_balls': {'Powerplay': 16,
#      'Middle_overs': 18,
#      'Death': 7,
#      'Total': 41}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 55,
#      'Middle_overs': 74,
#      'Death': 57,
#      'Total': 186},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 1,
#      'Death': 0,
#      'Total': 3},
#     'num_4s_conceded': {'Powerplay': 8,
#      'Middle_overs': 5,
#      'Death': 3,
#      'Total': 16},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 2,
#      'Death': 3,
#      'Total': 5},
#     'dot_balls_bowled': {'Powerplay': 13,
#      'Middle_overs': 13,
#      'Death': 2,
#      'Total': 28}},
#    'innings': 1,
#    'match_winner': 164,
#    'venue': 17,
#    'opposition': 164,
#    'match_date': "['2013-04-21']"},
#   590: {'batting_insights': {'runs_scored': {'Powerplay': 43,
#      'Middle_overs': 68,
#      'Death': 22,
#      'Total': 133},
#     'wickets': {'Powerplay': 4, 'Middle_overs': 1, 'Death': 4, 'Total': 9},
#     'num_4s': {'Powerplay': 6, 'Middle_overs': 6, 'Death': 3, 'Total': 15},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 2, 'Death': 0, 'Total': 3},
#     'dot_balls': {'Powerplay': 19,
#      'Middle_overs': 18,
#      'Death': 18,
#      'Total': 55}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 62,
#      'Middle_overs': 134,
#      'Death': 67,
#      'Total': 263},
#     'wickets_taken': {'Powerplay': 0,
#      'Middle_overs': 1,
#      'Death': 4,
#      'Total': 5},
#     'num_4s_conceded': {'Powerplay': 7,
#      'Middle_overs': 8,
#      'Death': 5,
#      'Total': 20},
#     'num_6s_conceded': {'Powerplay': 4,
#      'Middle_overs': 12,
#      'Death': 5,
#      'Total': 21},
#     'dot_balls_bowled': {'Powerplay': 22,
#      'Middle_overs': 9,
#      'Death': 6,
#      'Total': 37}},
#    'innings': 2,
#    'match_winner': 182,
#    'venue': 23,
#    'opposition': 182,
#    'match_date': "['2013-04-23']"},
#   598: {'batting_insights': {'runs_scored': {'Powerplay': 43,
#      'Middle_overs': 67,
#      'Death': 39,
#      'Total': 149},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 2, 'Total': 4},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 9, 'Death': 4, 'Total': 18},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 0, 'Death': 1, 'Total': 1},
#     'dot_balls': {'Powerplay': 16,
#      'Middle_overs': 21,
#      'Death': 11,
#      'Total': 48}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 37,
#      'Middle_overs': 64,
#      'Death': 63,
#      'Total': 164},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 3,
#      'Death': 1,
#      'Total': 5},
#     'num_4s_conceded': {'Powerplay': 4,
#      'Middle_overs': 4,
#      'Death': 4,
#      'Total': 12},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 2,
#      'Death': 5,
#      'Total': 8},
#     'dot_balls_bowled': {'Powerplay': 24,
#      'Middle_overs': 19,
#      'Death': 8,
#      'Total': 51}},
#    'innings': 2,
#    'match_winner': 330,
#    'venue': 29,
#    'opposition': 330,
#    'match_date': "['2013-04-28']"},
#   601: {'batting_insights': {'runs_scored': {'Powerplay': 46,
#      'Middle_overs': 47,
#      'Death': 34,
#      'Total': 127},
#     'wickets': {'Powerplay': 4, 'Middle_overs': 3, 'Death': 2, 'Total': 9},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 3, 'Death': 1, 'Total': 9},
#     'num_6s': {'Powerplay': 2, 'Middle_overs': 1, 'Death': 1, 'Total': 4},
#     'dot_balls': {'Powerplay': 19,
#      'Middle_overs': 26,
#      'Death': 10,
#      'Total': 55}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 29,
#      'Middle_overs': 73,
#      'Death': 62,
#      'Total': 164},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 0,
#      'Death': 1,
#      'Total': 3},
#     'num_4s_conceded': {'Powerplay': 3,
#      'Middle_overs': 4,
#      'Death': 6,
#      'Total': 13},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 3,
#      'Total': 5},
#     'dot_balls_bowled': {'Powerplay': 21,
#      'Middle_overs': 8,
#      'Death': 4,
#      'Total': 33}},
#    'innings': 2,
#    'match_winner': 599,
#    'venue': 20,
#    'opposition': 599,
#    'match_date': "['2013-04-30']"},
#   605: {'batting_insights': {'runs_scored': {'Powerplay': 39,
#      'Middle_overs': 83,
#      'Death': 48,
#      'Total': 170},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 3, 'Death': 5, 'Total': 9},
#     'num_4s': {'Powerplay': 3, 'Middle_overs': 4, 'Death': 2, 'Total': 9},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 6, 'Death': 4, 'Total': 11},
#     'dot_balls': {'Powerplay': 13,
#      'Middle_overs': 20,
#      'Death': 10,
#      'Total': 43}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 30,
#      'Middle_overs': 89,
#      'Death': 68,
#      'Total': 187},
#     'wickets_taken': {'Powerplay': 0,
#      'Middle_overs': 2,
#      'Death': 1,
#      'Total': 3},
#     'num_4s_conceded': {'Powerplay': 3,
#      'Middle_overs': 5,
#      'Death': 9,
#      'Total': 17},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 3,
#      'Death': 3,
#      'Total': 6},
#     'dot_balls_bowled': {'Powerplay': 18,
#      'Middle_overs': 11,
#      'Death': 7,
#      'Total': 36}},
#    'innings': 2,
#    'match_winner': 182,
#    'venue': 20,
#    'opposition': 182,
#    'match_date': "['2013-05-02']"},
#   610: {'batting_insights': {'runs_scored': {'Powerplay': 61,
#      'Middle_overs': 64,
#      'Death': 53,
#      'Total': 178},
#     'wickets': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 2, 'Total': 4},
#     'num_4s': {'Powerplay': 10, 'Middle_overs': 6, 'Death': 4, 'Total': 20},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 3, 'Total': 5},
#     'dot_balls': {'Powerplay': 13,
#      'Middle_overs': 28,
#      'Death': 9,
#      'Total': 50}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 53,
#      'Middle_overs': 75,
#      'Death': 54,
#      'Total': 182},
#     'wickets_taken': {'Powerplay': 0,
#      'Middle_overs': 2,
#      'Death': 3,
#      'Total': 5},
#     'num_4s_conceded': {'Powerplay': 9,
#      'Middle_overs': 6,
#      'Death': 5,
#      'Total': 20},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 2,
#      'Death': 2,
#      'Total': 5},
#     'dot_balls_bowled': {'Powerplay': 17,
#      'Middle_overs': 13,
#      'Death': 6,
#      'Total': 36}},
#    'innings': 1,
#    'match_winner': 169,
#    'venue': 34,
#    'opposition': 169,
#    'match_date': "['2013-05-05']"},
#   616: {'batting_insights': {'runs_scored': {'Powerplay': 34,
#      'Middle_overs': 46,
#      'Death': 26,
#      'Total': 106},
#     'wickets': {'Powerplay': 2, 'Middle_overs': 3, 'Death': 5, 'Total': 10},
#     'num_4s': {'Powerplay': 4, 'Middle_overs': 0, 'Death': 0, 'Total': 4},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 2, 'Death': 2, 'Total': 4},
#     'dot_balls': {'Powerplay': 18,
#      'Middle_overs': 21,
#      'Death': 11,
#      'Total': 50}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 50,
#      'Middle_overs': 46,
#      'Death': 56,
#      'Total': 152},
#     'wickets_taken': {'Powerplay': 1,
#      'Middle_overs': 3,
#      'Death': 2,
#      'Total': 6},
#     'num_4s_conceded': {'Powerplay': 8,
#      'Middle_overs': 2,
#      'Death': 6,
#      'Total': 16},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 0,
#      'Death': 2,
#      'Total': 2},
#     'dot_balls_bowled': {'Powerplay': 14,
#      'Middle_overs': 23,
#      'Death': 6,
#      'Total': 43}},
#    'innings': 2,
#    'match_winner': 150,
#    'venue': 20,
#    'opposition': 150,
#    'match_date': "['2013-05-09']"},
#   618: {'batting_insights': {'runs_scored': {'Powerplay': 36,
#      'Middle_overs': 52,
#      'Death': 24,
#      'Total': 112},
#     'wickets': {'Powerplay': 2, 'Middle_overs': 3, 'Death': 3, 'Total': 8},
#     'num_4s': {'Powerplay': 5, 'Middle_overs': 0, 'Death': 0, 'Total': 5},
#     'num_6s': {'Powerplay': 0, 'Middle_overs': 3, 'Death': 0, 'Total': 3},
#     'dot_balls': {'Powerplay': 19,
#      'Middle_overs': 20,
#      'Death': 9,
#      'Total': 48}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 37,
#      'Middle_overs': 46,
#      'Death': 33,
#      'Total': 116},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 1,
#      'Death': 2,
#      'Total': 5},
#     'num_4s_conceded': {'Powerplay': 4,
#      'Middle_overs': 2,
#      'Death': 5,
#      'Total': 11},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 1,
#      'Total': 3},
#     'dot_balls_bowled': {'Powerplay': 21,
#      'Middle_overs': 21,
#      'Death': 10,
#      'Total': 52}},
#    'innings': 1,
#    'match_winner': 90,
#    'venue': 20,
#    'opposition': 90,
#    'match_date': "['2013-05-11']"},
#   624: {'batting_insights': {'runs_scored': {'Powerplay': 42,
#      'Middle_overs': 70,
#      'Death': 58,
#      'Total': 170},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 1, 'Death': 2, 'Total': 4},
#     'num_4s': {'Powerplay': 3, 'Middle_overs': 3, 'Death': 5, 'Total': 11},
#     'num_6s': {'Powerplay': 2, 'Middle_overs': 4, 'Death': 3, 'Total': 9},
#     'dot_balls': {'Powerplay': 16,
#      'Middle_overs': 18,
#      'Death': 6,
#      'Total': 40}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 33,
#      'Middle_overs': 89,
#      'Death': 41,
#      'Total': 163},
#     'wickets_taken': {'Powerplay': 3,
#      'Middle_overs': 0,
#      'Death': 4,
#      'Total': 7},
#     'num_4s_conceded': {'Powerplay': 1,
#      'Middle_overs': 9,
#      'Death': 5,
#      'Total': 15},
#     'num_6s_conceded': {'Powerplay': 0,
#      'Middle_overs': 3,
#      'Death': 1,
#      'Total': 4},
#     'dot_balls_bowled': {'Powerplay': 21,
#      'Middle_overs': 10,
#      'Death': 12,
#      'Total': 43}},
#    'innings': 1,
#    'match_winner': 471,
#    'venue': 9,
#    'opposition': 150,
#    'match_date': "['2013-05-15']"},
#   630: {'batting_insights': {'runs_scored': {'Powerplay': 40,
#      'Middle_overs': 67,
#      'Death': 65,
#      'Total': 172},
#     'wickets': {'Powerplay': 1, 'Middle_overs': 3, 'Death': 1, 'Total': 5},
#     'num_4s': {'Powerplay': 4, 'Middle_overs': 3, 'Death': 6, 'Total': 13},
#     'num_6s': {'Powerplay': 1, 'Middle_overs': 4, 'Death': 3, 'Total': 8},
#     'dot_balls': {'Powerplay': 17,
#      'Middle_overs': 21,
#      'Death': 3,
#      'Total': 41}},
#    'bowling_insights': {'runs_conceded': {'Powerplay': 47,
#      'Middle_overs': 57,
#      'Death': 30,
#      'Total': 134},
#     'wickets_taken': {'Powerplay': 2,
#      'Middle_overs': 3,
#      'Death': 4,
#      'Total': 9},
#     'num_4s_conceded': {'Powerplay': 6,
#      'Middle_overs': 4,
#      'Death': 3,
#      'Total': 13},
#     'num_6s_conceded': {'Powerplay': 1,
#      'Middle_overs': 1,
#      'Death': 0,
#      'Total': 2},
#     'dot_balls_bowled': {'Powerplay': 20,
#      'Middle_overs': 20,
#      'Death': 12,
#      'Total': 52}},
#    'innings': 1,
#    'match_winner': 471,
#    'venue': 20,
#    'opposition': 330,
#    'match_date': "['2013-05-19']"}}}

# %%
with open(os.path.join(clean_data_path, 'pre_compute_match.pkl'), 'wb') as file:
    pickle.dump(match_insight_obj, file, pickle.HIGHEST_PROTOCOL)
