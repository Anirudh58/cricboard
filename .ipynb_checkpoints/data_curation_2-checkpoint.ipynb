# %%
# Basic
from collections import Counter
import math
import numpy as np
import os
import pprint

# yaml specific
import yaml

# Data handling
from fuzzywuzzy import fuzz, process
import pandas as pd
from tqdm import tqdm

# %%
# Config variables
raw_data_path = "raw_data"
clean_data_path = "clean_data"
tournament_name = "IPL"

# %%
def parse_yaml(path):
    """
    Parses a given yaml file and returns the object
    Args:
        path - path of the yaml file to be parsed
    """
    with open(path, 'r') as stream:
        try:
            data = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            print(exc)
    return data

# %%
def get_all_matches_raw_data(tournament_name):
    tournament_path = os.path.join(raw_data_path, tournament_name)
    match_files = os.listdir(tournament_path)
    matches = []
    print(f"Parsing {len(match_files)} matches for {tournament_name}")
    for match_file in tqdm(match_files):
        match_path = os.path.join(tournament_path, match_file)
        match = parse_yaml(match_path)
        matches.append(match)
    return matches

# %%
def get_best_possible_name_match(query_name, players_with_same_surname):
    #players_with_same_surname = players[players.player_name.str.contains(query_name.split(" ")[-1])]
    
    # collecting all capital letters in the name to be stored as initials
    initials = [c for c in query_name if c.isupper()]
    
    # creating a hash map between the player_name and player_full_name for easy access
    name_full_name_map = {}
    for index, row in players_with_same_surname.iterrows():
        name_full_name_map[row["player_name"]] = row["player_full_name"]
    
    # List of all choices for the fuzzy algorithm to run on. 
    choices_name = np.array(players_with_same_surname.player_name)
    potential_matches = process.extract(query_name, choices_name, limit=50)
    top_score = potential_matches[0][1]
    best_match = ""
    for potential_match in potential_matches:

        score = potential_match[1]
        match_name = potential_match[0]
    
        # if you get a perfect score, that should definitely be the correct match
        if score == 100:
            best_match = match_name
            break
        
        # if you dont get a perfect score, check if all the initials are present in the players full name, that should be the best match
        if all([initial in name_full_name_map[match_name] for initial in initials]):
            best_match = match_name
            break
        
        # if either of methods fail, return the best match the fuzzy scoring algo returned
        if score > top_score:
            top_score = score
            best_match = match_name

    return best_match

# %%
def update_players(update_column, update_value, check_column, check_value):
    players = pd.read_csv(os.path.join(clean_data_path, "player.csv"))
    players = players.loc[:, ~players.columns.str.contains('^Unnamed')]
    players.loc[players[check_column] == check_value, update_column] = update_value
    #players[update_column] = np.where(players[check_column] == check_value, update_value)
    players.to_csv(os.path.join(clean_data_path, "player.csv"), index=False)

# %% [markdown]
# # This notebook will be used to curate 2 tables.
# ## 1) Match 2) Ball

# %% [markdown]
# ## Match table

# %%
matches = get_all_matches_raw_data(tournament_name)
# Out:
#   0%|                                                                                          | 0/817 [00:00<?, ?it/s]
# Parsing 817 matches for IPL
# 100%|████████████████████████████████████████████████████████████████████████████████| 817/817 [03:52<00:00,  3.51it/s]

# %% [markdown]
# #### We need to first match all player names found in this dataset to the player_ids we have. Our player table contains full names (eg: David Warner) while this dataset has only the short names typically used in score cards (eg. DA Warner). So lets use fuzzy matching to map these

# %%
players = pd.read_csv(os.path.join(clean_data_path, "player.csv"))

# %%
# Out:
# array(['Rupert Kitzinger', 'Zulqarnain Haider', 'Daniel Zvidzai', ...,
#        'Audley Sanson', 'Robert Samuels', 'Marlon Samuels'], dtype=object)

# %%
a = [True, True, False]
all(a)
# Out:
# False

# %%
unique_player_names = set()
for match in matches:
    for inning in match['innings']:
        for inning_number in inning:
            for ball in inning[inning_number]['deliveries']:
                print(ball)
                for ball_number in ball:
                    unique_player_names.add(ball[ball_number]['batsman'])
                    unique_player_names.add(ball[ball_number]['bowler'])
                    unique_player_names.add(ball[ball_number]['non_striker'])
    break
# Out:
# {0.1: {'batsman': 'DA Warner', 'bowler': 'TS Mills', 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {0.2: {'batsman': 'DA Warner', 'bowler': 'TS Mills', 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {0.3: {'batsman': 'DA Warner', 'bowler': 'TS Mills', 'non_striker': 'S Dhawan', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {0.4: {'batsman': 'DA Warner', 'bowler': 'TS Mills', 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {0.5: {'batsman': 'DA Warner', 'bowler': 'TS Mills', 'extras': {'wides': 2}, 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 2, 'total': 2}}}
# {0.6: {'batsman': 'S Dhawan', 'bowler': 'TS Mills', 'non_striker': 'DA Warner', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {0.7: {'batsman': 'S Dhawan', 'bowler': 'TS Mills', 'extras': {'legbyes': 1}, 'non_striker': 'DA Warner', 'runs': {'batsman': 0, 'extras': 1, 'total': 1}}}
# {1.1: {'batsman': 'S Dhawan', 'bowler': 'A Choudhary', 'non_striker': 'DA Warner', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {1.2: {'batsman': 'DA Warner', 'bowler': 'A Choudhary', 'non_striker': 'S Dhawan', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {1.3: {'batsman': 'DA Warner', 'bowler': 'A Choudhary', 'extras': {'noballs': 1}, 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 1, 'total': 1}}}
# {1.4: {'batsman': 'DA Warner', 'bowler': 'A Choudhary', 'non_striker': 'S Dhawan', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {1.5: {'batsman': 'DA Warner', 'bowler': 'A Choudhary', 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'fielders': ['Mandeep Singh'], 'kind': 'caught', 'player_out': 'DA Warner'}}}
# {1.6: {'batsman': 'MC Henriques', 'bowler': 'A Choudhary', 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {1.7: {'batsman': 'MC Henriques', 'bowler': 'A Choudhary', 'non_striker': 'S Dhawan', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {2.1: {'batsman': 'S Dhawan', 'bowler': 'TS Mills', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {2.2: {'batsman': 'MC Henriques', 'bowler': 'TS Mills', 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {2.3: {'batsman': 'MC Henriques', 'bowler': 'TS Mills', 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {2.4: {'batsman': 'MC Henriques', 'bowler': 'TS Mills', 'non_striker': 'S Dhawan', 'runs': {'batsman': 3, 'extras': 0, 'total': 3}}}
# {2.5: {'batsman': 'S Dhawan', 'bowler': 'TS Mills', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {2.6: {'batsman': 'MC Henriques', 'bowler': 'TS Mills', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {3.1: {'batsman': 'MC Henriques', 'bowler': 'YS Chahal', 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {3.2: {'batsman': 'MC Henriques', 'bowler': 'YS Chahal', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {3.3: {'batsman': 'S Dhawan', 'bowler': 'YS Chahal', 'non_striker': 'MC Henriques', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {3.4: {'batsman': 'S Dhawan', 'bowler': 'YS Chahal', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {3.5: {'batsman': 'MC Henriques', 'bowler': 'YS Chahal', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {3.6: {'batsman': 'S Dhawan', 'bowler': 'YS Chahal', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {4.1: {'batsman': 'S Dhawan', 'bowler': 'S Aravind', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {4.2: {'batsman': 'MC Henriques', 'bowler': 'S Aravind', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {4.3: {'batsman': 'S Dhawan', 'bowler': 'S Aravind', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {4.4: {'batsman': 'MC Henriques', 'bowler': 'S Aravind', 'non_striker': 'S Dhawan', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {4.5: {'batsman': 'MC Henriques', 'bowler': 'S Aravind', 'non_striker': 'S Dhawan', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {4.6: {'batsman': 'MC Henriques', 'bowler': 'S Aravind', 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {5.1: {'batsman': 'S Dhawan', 'bowler': 'SR Watson', 'non_striker': 'MC Henriques', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {5.2: {'batsman': 'S Dhawan', 'bowler': 'SR Watson', 'non_striker': 'MC Henriques', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {5.3: {'batsman': 'S Dhawan', 'bowler': 'SR Watson', 'non_striker': 'MC Henriques', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {5.4: {'batsman': 'S Dhawan', 'bowler': 'SR Watson', 'non_striker': 'MC Henriques', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {5.5: {'batsman': 'S Dhawan', 'bowler': 'SR Watson', 'non_striker': 'MC Henriques', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {5.6: {'batsman': 'S Dhawan', 'bowler': 'SR Watson', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {6.1: {'batsman': 'S Dhawan', 'bowler': 'YS Chahal', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {6.2: {'batsman': 'MC Henriques', 'bowler': 'YS Chahal', 'non_striker': 'S Dhawan', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {6.3: {'batsman': 'MC Henriques', 'bowler': 'YS Chahal', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {6.4: {'batsman': 'S Dhawan', 'bowler': 'YS Chahal', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {6.5: {'batsman': 'MC Henriques', 'bowler': 'YS Chahal', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {6.6: {'batsman': 'S Dhawan', 'bowler': 'YS Chahal', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {7.1: {'batsman': 'S Dhawan', 'bowler': 'TM Head', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {7.2: {'batsman': 'MC Henriques', 'bowler': 'TM Head', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {7.3: {'batsman': 'S Dhawan', 'bowler': 'TM Head', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {7.4: {'batsman': 'MC Henriques', 'bowler': 'TM Head', 'non_striker': 'S Dhawan', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {7.5: {'batsman': 'MC Henriques', 'bowler': 'TM Head', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {7.6: {'batsman': 'S Dhawan', 'bowler': 'TM Head', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {8.1: {'batsman': 'S Dhawan', 'bowler': 'YS Chahal', 'non_striker': 'MC Henriques', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {8.2: {'batsman': 'S Dhawan', 'bowler': 'YS Chahal', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {8.3: {'batsman': 'MC Henriques', 'bowler': 'YS Chahal', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {8.4: {'batsman': 'S Dhawan', 'bowler': 'YS Chahal', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {8.5: {'batsman': 'MC Henriques', 'bowler': 'YS Chahal', 'non_striker': 'S Dhawan', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {8.6: {'batsman': 'MC Henriques', 'bowler': 'YS Chahal', 'non_striker': 'S Dhawan', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {9.1: {'batsman': 'S Dhawan', 'bowler': 'A Choudhary', 'non_striker': 'MC Henriques', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {9.2: {'batsman': 'S Dhawan', 'bowler': 'A Choudhary', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {9.3: {'batsman': 'MC Henriques', 'bowler': 'A Choudhary', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {9.4: {'batsman': 'S Dhawan', 'bowler': 'A Choudhary', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {9.5: {'batsman': 'MC Henriques', 'bowler': 'A Choudhary', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {9.6: {'batsman': 'S Dhawan', 'bowler': 'A Choudhary', 'non_striker': 'MC Henriques', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {10.1: {'batsman': 'MC Henriques', 'bowler': 'STR Binny', 'non_striker': 'S Dhawan', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {10.2: {'batsman': 'S Dhawan', 'bowler': 'STR Binny', 'non_striker': 'MC Henriques', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {10.3: {'batsman': 'S Dhawan', 'bowler': 'STR Binny', 'non_striker': 'MC Henriques', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'fielders': ['Sachin Baby'], 'kind': 'caught', 'player_out': 'S Dhawan'}}}
# {10.4: {'batsman': 'MC Henriques', 'bowler': 'STR Binny', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {10.5: {'batsman': 'Yuvraj Singh', 'bowler': 'STR Binny', 'non_striker': 'MC Henriques', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {10.6: {'batsman': 'Yuvraj Singh', 'bowler': 'STR Binny', 'non_striker': 'MC Henriques', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {11.1: {'batsman': 'MC Henriques', 'bowler': 'S Aravind', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {11.2: {'batsman': 'Yuvraj Singh', 'bowler': 'S Aravind', 'non_striker': 'MC Henriques', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {11.3: {'batsman': 'Yuvraj Singh', 'bowler': 'S Aravind', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {11.4: {'batsman': 'MC Henriques', 'bowler': 'S Aravind', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {11.5: {'batsman': 'Yuvraj Singh', 'bowler': 'S Aravind', 'non_striker': 'MC Henriques', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {11.6: {'batsman': 'Yuvraj Singh', 'bowler': 'S Aravind', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {12.1: {'batsman': 'Yuvraj Singh', 'bowler': 'A Choudhary', 'non_striker': 'MC Henriques', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {12.2: {'batsman': 'Yuvraj Singh', 'bowler': 'A Choudhary', 'non_striker': 'MC Henriques', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {12.3: {'batsman': 'Yuvraj Singh', 'bowler': 'A Choudhary', 'non_striker': 'MC Henriques', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {12.4: {'batsman': 'Yuvraj Singh', 'bowler': 'A Choudhary', 'non_striker': 'MC Henriques', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {12.5: {'batsman': 'Yuvraj Singh', 'bowler': 'A Choudhary', 'extras': {'wides': 1}, 'non_striker': 'MC Henriques', 'runs': {'batsman': 0, 'extras': 1, 'total': 1}}}
# {12.6: {'batsman': 'Yuvraj Singh', 'bowler': 'A Choudhary', 'non_striker': 'MC Henriques', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {12.7: {'batsman': 'Yuvraj Singh', 'bowler': 'A Choudhary', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {13.1: {'batsman': 'Yuvraj Singh', 'bowler': 'SR Watson', 'non_striker': 'MC Henriques', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {13.2: {'batsman': 'Yuvraj Singh', 'bowler': 'SR Watson', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {13.3: {'batsman': 'MC Henriques', 'bowler': 'SR Watson', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {13.4: {'batsman': 'Yuvraj Singh', 'bowler': 'SR Watson', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {13.5: {'batsman': 'MC Henriques', 'bowler': 'SR Watson', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {13.6: {'batsman': 'MC Henriques', 'bowler': 'SR Watson', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {14.1: {'batsman': 'MC Henriques', 'bowler': 'S Aravind', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {14.2: {'batsman': 'MC Henriques', 'bowler': 'S Aravind', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {14.3: {'batsman': 'Yuvraj Singh', 'bowler': 'S Aravind', 'non_striker': 'MC Henriques', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {14.4: {'batsman': 'Yuvraj Singh', 'bowler': 'S Aravind', 'non_striker': 'MC Henriques', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {14.5: {'batsman': 'MC Henriques', 'bowler': 'S Aravind', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {14.6: {'batsman': 'MC Henriques', 'bowler': 'S Aravind', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {15.1: {'batsman': 'MC Henriques', 'bowler': 'YS Chahal', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {15.2: {'batsman': 'MC Henriques', 'bowler': 'YS Chahal', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'fielders': ['Sachin Baby'], 'kind': 'caught', 'player_out': 'MC Henriques'}}}
# {15.3: {'batsman': 'Yuvraj Singh', 'bowler': 'YS Chahal', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {15.4: {'batsman': 'DJ Hooda', 'bowler': 'YS Chahal', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {15.5: {'batsman': 'Yuvraj Singh', 'bowler': 'YS Chahal', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {15.6: {'batsman': 'DJ Hooda', 'bowler': 'YS Chahal', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {16.1: {'batsman': 'DJ Hooda', 'bowler': 'TS Mills', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {16.2: {'batsman': 'Yuvraj Singh', 'bowler': 'TS Mills', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {16.3: {'batsman': 'Yuvraj Singh', 'bowler': 'TS Mills', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {16.4: {'batsman': 'Yuvraj Singh', 'bowler': 'TS Mills', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {16.5: {'batsman': 'DJ Hooda', 'bowler': 'TS Mills', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {16.6: {'batsman': 'DJ Hooda', 'bowler': 'TS Mills', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {17.1: {'batsman': 'DJ Hooda', 'bowler': 'A Choudhary', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {17.2: {'batsman': 'DJ Hooda', 'bowler': 'A Choudhary', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {17.3: {'batsman': 'Yuvraj Singh', 'bowler': 'A Choudhary', 'extras': {'wides': 1}, 'non_striker': 'DJ Hooda', 'runs': {'batsman': 0, 'extras': 1, 'total': 1}}}
# {17.4: {'batsman': 'Yuvraj Singh', 'bowler': 'A Choudhary', 'extras': {'wides': 1}, 'non_striker': 'DJ Hooda', 'runs': {'batsman': 0, 'extras': 1, 'total': 1}}}
# {17.5: {'batsman': 'Yuvraj Singh', 'bowler': 'A Choudhary', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {17.6: {'batsman': 'Yuvraj Singh', 'bowler': 'A Choudhary', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {17.7: {'batsman': 'DJ Hooda', 'bowler': 'A Choudhary', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {17.8: {'batsman': 'DJ Hooda', 'bowler': 'A Choudhary', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {18.1: {'batsman': 'DJ Hooda', 'bowler': 'TS Mills', 'non_striker': 'Yuvraj Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {18.2: {'batsman': 'Yuvraj Singh', 'bowler': 'TS Mills', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {18.3: {'batsman': 'Yuvraj Singh', 'bowler': 'TS Mills', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {18.4: {'batsman': 'Yuvraj Singh', 'bowler': 'TS Mills', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'kind': 'bowled', 'player_out': 'Yuvraj Singh'}}}
# {18.5: {'batsman': 'BCJ Cutting', 'bowler': 'TS Mills', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {18.6: {'batsman': 'DJ Hooda', 'bowler': 'TS Mills', 'non_striker': 'BCJ Cutting', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {19.1: {'batsman': 'BCJ Cutting', 'bowler': 'SR Watson', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {19.2: {'batsman': 'DJ Hooda', 'bowler': 'SR Watson', 'non_striker': 'BCJ Cutting', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {19.3: {'batsman': 'BCJ Cutting', 'bowler': 'SR Watson', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {19.4: {'batsman': 'BCJ Cutting', 'bowler': 'SR Watson', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {19.5: {'batsman': 'BCJ Cutting', 'bowler': 'SR Watson', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {19.6: {'batsman': 'BCJ Cutting', 'bowler': 'SR Watson', 'non_striker': 'DJ Hooda', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {0.1: {'batsman': 'CH Gayle', 'bowler': 'A Nehra', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {0.2: {'batsman': 'Mandeep Singh', 'bowler': 'A Nehra', 'non_striker': 'CH Gayle', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {0.3: {'batsman': 'Mandeep Singh', 'bowler': 'A Nehra', 'non_striker': 'CH Gayle', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {0.4: {'batsman': 'Mandeep Singh', 'bowler': 'A Nehra', 'non_striker': 'CH Gayle', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {0.5: {'batsman': 'Mandeep Singh', 'bowler': 'A Nehra', 'non_striker': 'CH Gayle', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {0.6: {'batsman': 'Mandeep Singh', 'bowler': 'A Nehra', 'non_striker': 'CH Gayle', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {1.1: {'batsman': 'CH Gayle', 'bowler': 'B Kumar', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {1.2: {'batsman': 'CH Gayle', 'bowler': 'B Kumar', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {1.3: {'batsman': 'CH Gayle', 'bowler': 'B Kumar', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {1.4: {'batsman': 'Mandeep Singh', 'bowler': 'B Kumar', 'non_striker': 'CH Gayle', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {1.5: {'batsman': 'Mandeep Singh', 'bowler': 'B Kumar', 'non_striker': 'CH Gayle', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {1.6: {'batsman': 'Mandeep Singh', 'bowler': 'B Kumar', 'non_striker': 'CH Gayle', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {2.1: {'batsman': 'CH Gayle', 'bowler': 'A Nehra', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {2.2: {'batsman': 'CH Gayle', 'bowler': 'A Nehra', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {2.3: {'batsman': 'CH Gayle', 'bowler': 'A Nehra', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {2.4: {'batsman': 'Mandeep Singh', 'bowler': 'A Nehra', 'non_striker': 'CH Gayle', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {2.5: {'batsman': 'Mandeep Singh', 'bowler': 'A Nehra', 'non_striker': 'CH Gayle', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {2.6: {'batsman': 'CH Gayle', 'bowler': 'A Nehra', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {3.1: {'batsman': 'Mandeep Singh', 'bowler': 'B Kumar', 'non_striker': 'CH Gayle', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {3.2: {'batsman': 'CH Gayle', 'bowler': 'B Kumar', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {3.3: {'batsman': 'CH Gayle', 'bowler': 'B Kumar', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {3.4: {'batsman': 'CH Gayle', 'bowler': 'B Kumar', 'extras': {'wides': 1}, 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 0, 'extras': 1, 'total': 1}}}
# {3.5: {'batsman': 'CH Gayle', 'bowler': 'B Kumar', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {3.6: {'batsman': 'CH Gayle', 'bowler': 'B Kumar', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {3.7: {'batsman': 'Mandeep Singh', 'bowler': 'B Kumar', 'non_striker': 'CH Gayle', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {4.1: {'batsman': 'CH Gayle', 'bowler': 'BCJ Cutting', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {4.2: {'batsman': 'CH Gayle', 'bowler': 'BCJ Cutting', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {4.3: {'batsman': 'CH Gayle', 'bowler': 'BCJ Cutting', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {4.4: {'batsman': 'CH Gayle', 'bowler': 'BCJ Cutting', 'extras': {'wides': 1}, 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 0, 'extras': 1, 'total': 1}}}
# {4.5: {'batsman': 'CH Gayle', 'bowler': 'BCJ Cutting', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {4.6: {'batsman': 'CH Gayle', 'bowler': 'BCJ Cutting', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {4.7: {'batsman': 'CH Gayle', 'bowler': 'BCJ Cutting', 'non_striker': 'Mandeep Singh', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {5.1: {'batsman': 'Mandeep Singh', 'bowler': 'Rashid Khan', 'non_striker': 'CH Gayle', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {5.2: {'batsman': 'Mandeep Singh', 'bowler': 'Rashid Khan', 'non_striker': 'CH Gayle', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {5.3: {'batsman': 'Mandeep Singh', 'bowler': 'Rashid Khan', 'non_striker': 'CH Gayle', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {5.4: {'batsman': 'Mandeep Singh', 'bowler': 'Rashid Khan', 'non_striker': 'CH Gayle', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'kind': 'bowled', 'player_out': 'Mandeep Singh'}}}
# {5.5: {'batsman': 'TM Head', 'bowler': 'Rashid Khan', 'non_striker': 'CH Gayle', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {5.6: {'batsman': 'TM Head', 'bowler': 'Rashid Khan', 'non_striker': 'CH Gayle', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {6.1: {'batsman': 'CH Gayle', 'bowler': 'DJ Hooda', 'non_striker': 'TM Head', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {6.2: {'batsman': 'CH Gayle', 'bowler': 'DJ Hooda', 'non_striker': 'TM Head', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {6.3: {'batsman': 'CH Gayle', 'bowler': 'DJ Hooda', 'non_striker': 'TM Head', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'fielders': ['DA Warner'], 'kind': 'caught', 'player_out': 'CH Gayle'}}}
# {6.4: {'batsman': 'TM Head', 'bowler': 'DJ Hooda', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {6.5: {'batsman': 'TM Head', 'bowler': 'DJ Hooda', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {6.6: {'batsman': 'KM Jadhav', 'bowler': 'DJ Hooda', 'non_striker': 'TM Head', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {7.1: {'batsman': 'TM Head', 'bowler': 'Rashid Khan', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {7.2: {'batsman': 'TM Head', 'bowler': 'Rashid Khan', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {7.3: {'batsman': 'TM Head', 'bowler': 'Rashid Khan', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {7.4: {'batsman': 'KM Jadhav', 'bowler': 'Rashid Khan', 'non_striker': 'TM Head', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {7.5: {'batsman': 'TM Head', 'bowler': 'Rashid Khan', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {7.6: {'batsman': 'KM Jadhav', 'bowler': 'Rashid Khan', 'non_striker': 'TM Head', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {8.1: {'batsman': 'TM Head', 'bowler': 'BCJ Cutting', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {8.2: {'batsman': 'KM Jadhav', 'bowler': 'BCJ Cutting', 'extras': {'wides': 1}, 'non_striker': 'TM Head', 'runs': {'batsman': 0, 'extras': 1, 'total': 1}}}
# {8.3: {'batsman': 'KM Jadhav', 'bowler': 'BCJ Cutting', 'non_striker': 'TM Head', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {8.4: {'batsman': 'KM Jadhav', 'bowler': 'BCJ Cutting', 'non_striker': 'TM Head', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {8.5: {'batsman': 'TM Head', 'bowler': 'BCJ Cutting', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {8.6: {'batsman': 'KM Jadhav', 'bowler': 'BCJ Cutting', 'non_striker': 'TM Head', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {8.7: {'batsman': 'KM Jadhav', 'bowler': 'BCJ Cutting', 'non_striker': 'TM Head', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {9.1: {'batsman': 'KM Jadhav', 'bowler': 'MC Henriques', 'extras': {'noballs': 1}, 'non_striker': 'TM Head', 'runs': {'batsman': 1, 'extras': 1, 'total': 2}}}
# {9.2: {'batsman': 'TM Head', 'bowler': 'MC Henriques', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {9.3: {'batsman': 'TM Head', 'bowler': 'MC Henriques', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {9.4: {'batsman': 'KM Jadhav', 'bowler': 'MC Henriques', 'non_striker': 'TM Head', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {9.5: {'batsman': 'TM Head', 'bowler': 'MC Henriques', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {9.6: {'batsman': 'TM Head', 'bowler': 'MC Henriques', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {9.7: {'batsman': 'KM Jadhav', 'bowler': 'MC Henriques', 'non_striker': 'TM Head', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {10.1: {'batsman': 'TM Head', 'bowler': 'A Nehra', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {10.2: {'batsman': 'KM Jadhav', 'bowler': 'A Nehra', 'extras': {'wides': 1}, 'non_striker': 'TM Head', 'runs': {'batsman': 0, 'extras': 1, 'total': 1}}}
# {10.3: {'batsman': 'KM Jadhav', 'bowler': 'A Nehra', 'non_striker': 'TM Head', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {10.4: {'batsman': 'TM Head', 'bowler': 'A Nehra', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {10.5: {'batsman': 'KM Jadhav', 'bowler': 'A Nehra', 'non_striker': 'TM Head', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {10.6: {'batsman': 'KM Jadhav', 'bowler': 'A Nehra', 'non_striker': 'TM Head', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {10.7: {'batsman': 'KM Jadhav', 'bowler': 'A Nehra', 'non_striker': 'TM Head', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {11.1: {'batsman': 'KM Jadhav', 'bowler': 'MC Henriques', 'non_striker': 'TM Head', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {11.2: {'batsman': 'TM Head', 'bowler': 'MC Henriques', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {11.3: {'batsman': 'TM Head', 'bowler': 'MC Henriques', 'non_striker': 'KM Jadhav', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {11.4: {'batsman': 'KM Jadhav', 'bowler': 'MC Henriques', 'non_striker': 'TM Head', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}, 'wicket': {'fielders': ['BCJ Cutting'], 'kind': 'run out', 'player_out': 'KM Jadhav'}}}
# {11.5: {'batsman': 'SR Watson', 'bowler': 'MC Henriques', 'non_striker': 'TM Head', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {11.6: {'batsman': 'TM Head', 'bowler': 'MC Henriques', 'non_striker': 'SR Watson', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {12.1: {'batsman': 'TM Head', 'bowler': 'Rashid Khan', 'non_striker': 'SR Watson', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {12.2: {'batsman': 'SR Watson', 'bowler': 'Rashid Khan', 'non_striker': 'TM Head', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {12.3: {'batsman': 'SR Watson', 'bowler': 'Rashid Khan', 'non_striker': 'TM Head', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {12.4: {'batsman': 'TM Head', 'bowler': 'Rashid Khan', 'non_striker': 'SR Watson', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {12.5: {'batsman': 'TM Head', 'bowler': 'Rashid Khan', 'non_striker': 'SR Watson', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'fielders': ['Yuvraj Singh'], 'kind': 'caught', 'player_out': 'TM Head'}}}
# {12.6: {'batsman': 'SR Watson', 'bowler': 'Rashid Khan', 'non_striker': 'Sachin Baby', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {13.1: {'batsman': 'Sachin Baby', 'bowler': 'Bipul Sharma', 'non_striker': 'SR Watson', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {13.2: {'batsman': 'Sachin Baby', 'bowler': 'Bipul Sharma', 'non_striker': 'SR Watson', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {13.3: {'batsman': 'SR Watson', 'bowler': 'Bipul Sharma', 'non_striker': 'Sachin Baby', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {13.4: {'batsman': 'Sachin Baby', 'bowler': 'Bipul Sharma', 'non_striker': 'SR Watson', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'fielders': ['MC Henriques'], 'kind': 'caught', 'player_out': 'Sachin Baby'}}}
# {13.5: {'batsman': 'SR Watson', 'bowler': 'Bipul Sharma', 'non_striker': 'STR Binny', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {13.6: {'batsman': 'STR Binny', 'bowler': 'Bipul Sharma', 'non_striker': 'SR Watson', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {14.1: {'batsman': 'STR Binny', 'bowler': 'Rashid Khan', 'non_striker': 'SR Watson', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {14.2: {'batsman': 'SR Watson', 'bowler': 'Rashid Khan', 'non_striker': 'STR Binny', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {14.3: {'batsman': 'STR Binny', 'bowler': 'Rashid Khan', 'non_striker': 'SR Watson', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {14.4: {'batsman': 'STR Binny', 'bowler': 'Rashid Khan', 'non_striker': 'SR Watson', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {14.5: {'batsman': 'STR Binny', 'bowler': 'Rashid Khan', 'non_striker': 'SR Watson', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {14.6: {'batsman': 'SR Watson', 'bowler': 'Rashid Khan', 'non_striker': 'STR Binny', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {15.1: {'batsman': 'STR Binny', 'bowler': 'BCJ Cutting', 'non_striker': 'SR Watson', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {15.2: {'batsman': 'STR Binny', 'bowler': 'BCJ Cutting', 'non_striker': 'SR Watson', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {15.3: {'batsman': 'STR Binny', 'bowler': 'BCJ Cutting', 'non_striker': 'SR Watson', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {15.4: {'batsman': 'SR Watson', 'bowler': 'BCJ Cutting', 'non_striker': 'STR Binny', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {15.5: {'batsman': 'SR Watson', 'bowler': 'BCJ Cutting', 'non_striker': 'STR Binny', 'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}
# {15.6: {'batsman': 'SR Watson', 'bowler': 'BCJ Cutting', 'non_striker': 'STR Binny', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {16.1: {'batsman': 'SR Watson', 'bowler': 'B Kumar', 'non_striker': 'STR Binny', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {16.2: {'batsman': 'STR Binny', 'bowler': 'B Kumar', 'non_striker': 'SR Watson', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {16.3: {'batsman': 'SR Watson', 'bowler': 'B Kumar', 'non_striker': 'STR Binny', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {16.4: {'batsman': 'SR Watson', 'bowler': 'B Kumar', 'non_striker': 'STR Binny', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {16.5: {'batsman': 'STR Binny', 'bowler': 'B Kumar', 'non_striker': 'SR Watson', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'fielders': ['Yuvraj Singh'], 'kind': 'caught', 'player_out': 'STR Binny'}}}
# {16.6: {'batsman': 'S Aravind', 'bowler': 'B Kumar', 'non_striker': 'SR Watson', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {17.1: {'batsman': 'SR Watson', 'bowler': 'A Nehra', 'non_striker': 'S Aravind', 'runs': {'batsman': 2, 'extras': 0, 'total': 2}}}
# {17.2: {'batsman': 'SR Watson', 'bowler': 'A Nehra', 'non_striker': 'S Aravind', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {17.3: {'batsman': 'SR Watson', 'bowler': 'A Nehra', 'non_striker': 'S Aravind', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'fielders': ['MC Henriques'], 'kind': 'caught', 'player_out': 'SR Watson'}}}
# {17.4: {'batsman': 'S Aravind', 'bowler': 'A Nehra', 'non_striker': 'TS Mills', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'kind': 'bowled', 'player_out': 'S Aravind'}}}
# {17.5: {'batsman': 'YS Chahal', 'bowler': 'A Nehra', 'non_striker': 'TS Mills', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {17.6: {'batsman': 'YS Chahal', 'bowler': 'A Nehra', 'non_striker': 'TS Mills', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {18.1: {'batsman': 'TS Mills', 'bowler': 'B Kumar', 'extras': {'legbyes': 1}, 'non_striker': 'YS Chahal', 'runs': {'batsman': 0, 'extras': 1, 'total': 1}}}
# {18.2: {'batsman': 'YS Chahal', 'bowler': 'B Kumar', 'non_striker': 'TS Mills', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {18.3: {'batsman': 'YS Chahal', 'bowler': 'B Kumar', 'non_striker': 'TS Mills', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {18.4: {'batsman': 'TS Mills', 'bowler': 'B Kumar', 'non_striker': 'YS Chahal', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {18.5: {'batsman': 'TS Mills', 'bowler': 'B Kumar', 'non_striker': 'YS Chahal', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'fielders': ['DA Warner'], 'kind': 'caught', 'player_out': 'TS Mills'}}}
# {18.6: {'batsman': 'YS Chahal', 'bowler': 'B Kumar', 'non_striker': 'A Choudhary', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {19.1: {'batsman': 'YS Chahal', 'bowler': 'BCJ Cutting', 'non_striker': 'A Choudhary', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}}}
# {19.2: {'batsman': 'YS Chahal', 'bowler': 'BCJ Cutting', 'non_striker': 'A Choudhary', 'runs': {'batsman': 1, 'extras': 0, 'total': 1}}}
# {19.3: {'batsman': 'A Choudhary', 'bowler': 'BCJ Cutting', 'non_striker': 'YS Chahal', 'runs': {'batsman': 6, 'extras': 0, 'total': 6}}}
# {19.4: {'batsman': 'A Choudhary', 'bowler': 'BCJ Cutting', 'non_striker': 'YS Chahal', 'runs': {'batsman': 0, 'extras': 0, 'total': 0}, 'wicket': {'fielders': ['CJ Jordan (sub)'], 'kind': 'run out', 'player_out': 'YS Chahal'}}}

# %%
for player_name in unique_player_names:
    players_with_same_surname = players[players.player_name.str.contains(player_name.split(" ")[-1])]
    best_match_name = get_best_possible_name_match(player_name, players_with_same_surname)
    update_players("player_display_name", player_name, "player_name", best_match_name)
# Out:
# ('Aravind', 95)
# ('Sreenath Aravind', 86)
# ('N Choudhary', 91)
# ('Narendra Choudhary', 90)
# ('Fahad Choudhary', 86)
# ('Vikram Choudhary', 86)
# ('Vinay Choudhary', 86)
# ('Satyam Choudhary', 86)
# ('Pradeep Choudhary', 86)
# ('Nitesh Choudhary', 86)
# ('Nishu Choudhary', 86)
# ('Kishan Choudhary', 86)
# ('Akash Choudhary', 86)
# ('Richard Mills', 86)
# ('Frederick Mills', 86)
# ('Andrew Mills', 86)
# ('Stu Mills', 82)
# ('Tymal Mills', 74)
# ('Shikhar Dhawan', 86)
# ('Rashid Khan', 100)
# ('Kurtley Watson', 86)
# ('Matthew Watson', 86)
# ('Frederic Watson', 86)
# ('William Watson', 86)
# ('Ryan Watson', 80)
# ('Todd Watson', 76)
# ('Helen Watson', 76)
# ('George Watson', 76)
# ('Dane Watson', 76)
# ('Robert Watson', 76)
# ('John Watson', 76)
# ('James Watson', 76)
# ('David Watson', 76)
# ('Ashley Watson', 76)
# ('Aaron Watson', 76)
# ('Shane Watson', 76)
# ('Ashish Nehra', 86)
# ('Broderick Warner', 86)
# ('William Warner', 86)
# ('David Warner', 86)
# ('Yuvraj Singh', 100)
# ('Ben Cutting', 82)
# ('Satyajit Jadhav', 86)
# ('Narendra Jadhav', 86)
# ('Himanshu Jadhav', 86)
# ('Dheeraj Jadhav', 86)
# ('Avinash Jadhav', 86)
# ('Ashutosh Jadhav', 86)
# ('SG Jadhav', 78)
# ('PD Jadhav', 78)
# ('Rohit Jadhav', 76)
# ('Rahul Jadhav', 76)
# ('Kedar Jadhav', 76)
# ('Mandeep Singh', 100)
# ('Sachin Hooda', 86)
# ('Kuldeep Hooda', 86)
# ('Deepak Hooda', 86)
# ('Benjamin Head', 86)
# ('Travis Head', 86)
# ('Moises Henriques', 82)
# ('Juvaunie Gayle', 86)
# ('Juvaunie Gayle', 86)
# ('Chris Gayle', 84)
# ('Stuart Binny', 86)
# ('Sachin Baby', 100)
# ('Yuzvendra Chahal', 86)
# ('Bipul Sharma', 100)
# ('Vikram Kumar', 86)
# ('Pallav Kumar', 86)
# ('Karan Kumar', 86)
# ('Nayan Kumar', 86)
# ('Gangashetty Arvind Kumar', 86)
# ('A Kumar', 86)
# ('Arnav Kumar', 86)
# ('Arjun Kumar', 86)
# ('Ankit Kumar', 86)
# ('Ankit Kumar', 86)
# ('GK Anil Kumar', 86)
# ('Kumar Boresa', 86)
